# %% [markdown]
# # SKEKB Beam Beam Test

# %% [markdown]
# ## Python Setup

# %%
import sys

import xobjects as xo
import xtrack as xt
import xfields as xf
import xpart as xp

from xtrack.slicing import Teapot, Strategy

from cpymad.madx import Madx

import numpy as np
import scipy.constants as cst
import matplotlib.pyplot as plt

# %% [markdown]
# ## User Variables

# %%
########################################
# Simulation Settings
########################################
n_turns             = int(1E2)
n_macroparticles    = int(1E5)
n_slices            = int(101)

########################################
# File Paths
########################################
ler_path            = "/Users/jack/Desktop/*Thesis/Analysis/superkekb/no_sol/sler_1707_80_1_nosol_simple.seq"
her_path            = "/Users/jack/Desktop/*Thesis/Analysis/superkekb/no_sol/sher_5781_60_1_nosol_simple.seq"

########################################
# Computation Mode
########################################
context = xo.ContextCpu(omp_num_threads='auto')

# %% [markdown]
# ## Machine Parameters

# %% [markdown]
# ### Pre LS1 Parameters

# %%
########################################
# HER Parameters
########################################
her_params = {
    'energy':           7.007,
    'p0c':              7.007E9,
    'bunch_intensity':  3.07E10,
    'n_bunches':        2249,
    'beta_x':           60E-3,
    'beta_y':           1.0E-3,
    'physemit_x':       4.59E-9,
    'physemit_y':       4.62E-11,
    'lattemit_y':       1.00E-11, #Guess
    'Qx':               45.532,
    'Qy':               43.573,
    'sigma_delta':      1.00E-3,
    'sigma_z':          5.10E-3,
    'phi':              41.5E-3,
    'circumference':    3016.315,
}

########################################
# LER Parameters
########################################
ler_params = {
    'energy':           4.00,
    'p0c':              4.0E9,
    'bunch_intensity':  3.69E10,
    'n_bunches':        2249,
    'beta_x':           80E-3,
    'beta_y':           1.0E-3,
    'physemit_x':       4.01E-9,
    'physemit_y':       4.62E-11,
    'lattemit_y':       1.00E-11, #Guess
    'Qx':               44.525,
    'Qy':               46.589,
    'sigma_delta':      1.00E-3,
    'sigma_z':          4.60E-3,
    'phi':              -41.5E-3,
    'circumference':    3016.315,
}

########################################
# Constants
########################################
mass0               = xp.ELECTRON_MASS_EV

# %% [markdown]
# ## Load LER

# %%
mad = Madx(
    stdout=sys.stdout # Needs to be set to sys.stdout or breaks
)
print("MADX Spawned")
mad.input(
f"""
    SET, FORMAT="19.15f";
    # !option, echo;
    option, update_from_parent=true; // new option in mad-x as of 2/2019

    BEAM, PARTICLE=POSITRON, ENERGY={ler_params['energy']};

    CALL, FILE="{ler_path}";

    USE, SEQUENCE=ASC;
    
    SXT_ON = 1;
    RF_ON =1;
        
    USE,SEQUENCE=ASC;
        TWISS;

"""
)
ler = xt.Line.from_madx_sequence(
        mad.sequence['ASC'],
        allow_thick=True,
        deferred_expressions=True,
    )
print("Line Built from MADX Sequence")
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.01  (64 bit, Darwin)      +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2023.12.04               +
#   + Execution date: 2024.05.13 20:59:12      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# MADX Spawned
# !
#
# !SAD2MADX V0.4.1 (11/5/2018)
#
# !Conversion of seq_ler at Sat Apr 27 10:13:23 CEST 2024
#
# !
#
# AXISAD =-2.3105151911690732e-11; BXISAD =.08000000000342304; AYISAD =-9.234472148971401e-11; BYISAD =.0010000000000005705; EXISAD =2.802972170610218e-13; EPXISAD =2.262517074610412e-13; EYISAD =2.650075255569153e-17; EPYISAD =-9.846063661244911e-16;
#
# K1QC1LP = -5.064472726622586;
#
# LQC1LP = .34;
#
# K1QC2LP = 2.1009027988160134;
#
# LQC2LP = .41;
#
# LQKALP = .3444;
#
# ANGLEBLC1LP1 = -.02478873839787652;
#
# LBLC1LP1 = 1.6031209539205753;
#
# ANGLEBLC1LP2 = -.009702723135905122;
#
# LBLC1LP2 = 2.2353772314445624;
#
# LQKBLP = .3444;
#
# LZDS1LP = .25;
#
# K1QLC1LP = -.29843291935174393;
#
# LQLC1LP = .58372;
#
# LQKCLP = .3444;
#
# LZDS2LP = .25;
#
# K1QLC2LP = .19559495104159527;
#
# LQLC2LP = .58372;
#
# LQKDLP = .3444;
#
# ANGLEBLC2LP = .06326079250957768;
#
# LBLC2LP = 4.158960424893555;
#
# LQKELP = .3444;
#
# K1QLC3LP = -.2559492061193723;
#
# LQLC3LP = .58372;
#
# K2SLYTLP1 = 7.267557494720084;
#
# LSLYTLP1 = .334;
#
# ANGLEBLY2LP = .063881983389;
#
# LBLY2LP = 4.158946737560165;
#
# ANGLEBLY3LP = -.035987255932;
#
# LBLY3LP = 2.230169651542091;
#
# K1QLY2LP = .24368170388109975;
#
# LQLY2LP = .58372;
#
# ANGLEBLY5LP = -.025938554101;
#
# LBLY5LP = 4.159537390524958;
#
# K1QLY1LP = -.32558647083932357;
#
# LQLY1LP = .58372;
#
# K2SLYTLP2 = 7.267557494720084;
#
# LSLYTLP2 = .334;
#
# K1QLB1LP = -.2941236664805043;
#
# LQLB1LP = .58372;
#
# ANGLEBLB2LP = .013166969342;
#
# LBLB2LP = .8934835456997886;
#
# K1QLB2LP = .2943640721921469;
#
# LQLB2LP = .58372;
#
# LZDS3LP = .25;
#
# K1QLB3LP = -.5602151289427114;
#
# LQLB3LP = .57638;
#
# ANGLEBLB3LP = -.002460947938;
#
# LBLB3LP = .8934897745328506;
#
# K1QLB4LP = .3305099054803673;
#
# LQLB4LP = .58372;
#
# K2SLXTLP = 1.7840348941642343;
#
# LSLXTLP = .334;
#
# ANGLEBLX2LP = -.032281894571;
#
# LBLX2LP = 2.230193158285929;
#
# K1QLX1LP = -.4117200131887915;
#
# LQLX1LP = .57638;
#
# ANGLEBLX4LP = .048492589608;
#
# LBLX4LP = 4.159246447131632;
#
# K1QLX2LP = .4173735378945428;
#
# LQLX2LP = .57638;
#
# K1QLA2LP = .31778997218328187;
#
# LQLA2LP = .57638;
#
# ANGLEBLA1LP = .033783658523;
#
# LBLA1LP = 3.9614826028511065;
#
# K1QLA3LP = -.27163249116902044;
#
# LQLA3LP = .57638;
#
# ANGLEBLA2LP = .051594425739;
#
# LBLA2LP = 4.159192643035774;
#
# K1QLA4LP = .2609118410347671;
#
# LQLA4LP = .46078;
#
# K1QLA5LP = -.14603352487087115;
#
# LQLA5LP = .46078;
#
# ANGLEBLA6LP = .020728487127;
#
# LBLA6LP = 2.2302500715018443;
#
# K1QLA6LP = .3347571374126481;
#
# LQLA6LP = .46078;
#
# LZDS4LP = .25;
#
# K1QLA7LP = -.3534575805481645;
#
# LQLA7LP = .46227;
#
# K1QLA8LP = .33051111610097994;
#
# LQLA8LP = .46227;
#
# K1QLA9LP = -.2517341068942393;
#
# LQLA9LP = .46227;
#
# K2SD3TLP = -18.794561470168777;
#
# LSD3TLP = .334;
#
# ANGLEB2P = .0560998688141;
#
# LB2P = 4.159108552981661;
#
# K1QF2P = .3909017987079817;
#
# LQF2P = .46227;
#
# K1QD1P = -.4321068331463837;
#
# LQD1P = .46078;
#
# K1QD3P = -.41743295856886364;
#
# LQD3P = .46227;
#
# K1QF4P = .2601671709990238;
#
# LQF4P = .46227;
#
# K2SF4TLP = 7.399104254281607;
#
# LSF4TLP = .334;
#
# K1QEAP = .26928106960622383;
#
# LQEAP = .46227;
#
# K1QD5P = -.41368820698506964;
#
# LQD5P = .46227;
#
# K1QF6P = .4265986873717402;
#
# LQF6P = .46078;
#
# K2SD5TLP = -2.9718509940550986;
#
# LSD5TLP = .334;
#
# K2SF6TLP = 2.866175672712398;
#
# LSF6TLP = .334;
#
# K2SD7TLP = -.688622754491018;
#
# LSD7TLP = .334;
#
# K1QT1TNP = -.5466448821260227;
#
# LQT1TNP = .46227;
#
# K1QT2TNP = .2770554444958605;
#
# LQT2TNP = .46227;
#
# K2SF8TNP = 2.2508863538139545;
#
# LSF8TNP = .334;
#
# K1QTATNP = .20553594383492624;
#
# LQTATNP = .46227;
#
# K1QT3TNP = -.3532253602502577;
#
# LQT3TNP = .46227;
#
# K1QT4TNP = .2640859203179678;
#
# LQT4TNP = .46227;
#
# K1QT5TNP = -.19623195718962927;
#
# LQT5TNP = .46227;
#
# K2SD7NRP = -15.912278785676518;
#
# LSD7NRP = .334;
#
# K2SF6NRP = .6626792099298138;
#
# LSF6NRP = .334;
#
# K2SD5NRP = -15.726135961757517;
#
# LSD5NRP = .334;
#
# K2SF4NRP = 1.5298062614905936;
#
# LSF4NRP = .334;
#
# K2SD3NRP = -13.105310734078612;
#
# LSD3NRP = .334;
#
# K2SF2NRP = .48088446728991613;
#
# LSF2NRP = .334;
#
# K1QS2NP = .07945648846994181;
#
# LQS2NP = .46227;
#
# K1QSBNP = .2962409004477903;
#
# LQSBNP = .46227;
#
# K1QS1NP = -.5704820191424925;
#
# LQS1NP = .46227;
#
# ANGLEBS2NP = .0280499344;
#
# LBS2NP = .8934607087515162;
#
# K1QW8NRP = .40527905989409263;
#
# LQW8NRP = .46078;
#
# K1QW7NRP = -.6221052249533401;
#
# LQW7NRP = .46078;
#
# K1QW6NRP = .38797725825556667;
#
# LQW6NRP = .46078;
#
# K1QW5NRP = -.233624811675854;
#
# LQW5NRP = .46078;
#
# K1QW4NRP = .38535889964191156;
#
# LQW4NRP = .46078;
#
# K1QW3NRP = -.27779533078258606;
#
# LQW3NRP = .46078;
#
# K1QW2NRP = .2763166806284995;
#
# LQW2NRP = .46078;
#
# K1QDWNP = -.2813557316045724;
#
# LQDWNP = .46078;
#
# K1QFWNP = .32120773971491745;
#
# LQFWNP = .46078;
#
# K1QW2NLP = .3047606502343852;
#
# LQW2NLP = .46078;
#
# K1QW3NLP = -.2933401341833413;
#
# LQW3NLP = .46078;
#
# K1QW4NLP = .3853599677763792;
#
# LQW4NLP = .46078;
#
# K1QW5NLP = -.41236649010807763;
#
# LQW5NLP = .46078;
#
# K1QW6NLP = .39964954122574764;
#
# LQW6NLP = .46078;
#
# K1QW7NLP = -.6883131458331525;
#
# LQW7NLP = .46078;
#
# K1QW8NLP = .3904329819783845;
#
# LQW8NLP = .46078;
#
# K2SF2NLP = 2.719068857997599;
#
# LSF2NLP = .334;
#
# K2SD3NLP = -11.600070569026984;
#
# LSD3NLP = .334;
#
# K2SF4NLP = 5.146451590252834;
#
# LSF4NLP = .334;
#
# K2SD5NLP = -3.234484272828853;
#
# LSD5NLP = .334;
#
# K2SF6NLP = 5.4059103360218455;
#
# LSF6NLP = .334;
#
# K2SD7NLP = -16.229579040275414;
#
# LSD7NLP = .334;
#
# K1QT1NFP = -.5466448821260227;
#
# LQT1NFP = .46227;
#
# K1QT2NFP = .2770554444958605;
#
# LQT2NFP = .46227;
#
# K2SF8NFP = 5.74556351948735;
#
# LSF8NFP = .334;
#
# K1QTANFP = .20553594383492624;
#
# LQTANFP = .46227;
#
# K1QT3NFP = -.3532253602502577;
#
# LQT3NFP = .46227;
#
# K1QT4NFP = .2640859203179678;
#
# LQT4NFP = .46227;
#
# K1QT5NFP = -.19623195718962927;
#
# LQT5NFP = .46227;
#
# K2SD7FRP = -18.69540407725143;
#
# LSD7FRP = .334;
#
# K2SF6FRP = .2671020157378267;
#
# LSF6FRP = .334;
#
# K2SD5FRP = -14.360330035530328;
#
# LSD5FRP = .334;
#
# K2SF4FRP = .5401167557835922;
#
# LSF4FRP = .334;
#
# K2SD3FRP = -.688622754491018;
#
# LSD3FRP = .334;
#
# K2SF2FRP = 9.925963410480705;
#
# LSF2FRP = .334;
#
# K1QS2FRP = .03969849016409304;
#
# LQS2FRP = .46227;
#
# K1QSBFRP = .2711488049091228;
#
# LQSBFRP = .46227;
#
# K1QS1FRP = -.2847439274591755;
#
# LQS1FRP = .46227;
#
# ANGLEBS2FRP = .02804993440705;
#
# LBS2FRP = .8934607087515015;
#
# ANGLEBSWFRP = .0050369430792;
#
# LBSWFRP = .8934890554772935;
#
# K1QR6P = .04993525349222694;
#
# LQR6P = .46078;
#
# K1QR5P = -.05888264339534382;
#
# LQR5P = .46078;
#
# K1QR4P = .2745905838765622;
#
# LQR4P = .46078;
#
# K1QR3P = -.2706236960084244;
#
# LQR3P = .58372;
#
# K1QR2P = .18104941241099626;
#
# LQR2P = .58372;
#
# K1QR1P = -.37652775008732164;
#
# LQR1P = .58372;
#
# FREQCAFFRP = 508.8797790984871;
#
# VOLTCAFFRP = .41454545454545455;
#
# FREQCAEFRP = 508.8797790984871;
#
# VOLTCAEFRP = .41454545454545455;
#
# K1QFRP = .3003055797805449;
#
# LQFRP = .58372;
#
# FREQCADFRP = 508.8797790984871;
#
# VOLTCADFRP = .41454545454545455;
#
# FREQCACFRP = 508.8797790984871;
#
# VOLTCACFRP = .41454545454545455;
#
# K1QDRP = -.29596091261240104;
#
# LQDRP = .58372;
#
# FREQCABFRP = 508.8797790984871;
#
# VOLTCABFRP = .41454545454545455;
#
# FREQCAAFRP = 508.8797790984871;
#
# VOLTCAAFRP = .41454545454545455;
#
# K1QV4P = .18733147123946794;
#
# LQV4P = .58372;
#
# LFZTFBKP1 = .55;
#
# LFZTFBKP2 = .55;
#
# K1QV3P = -.42574680984038055;
#
# LQV3P = .46078;
#
# K1QV2P = .5878614444976273;
#
# LQV2P = .46078;
#
# K1QV1P = -.4774019873421979;
#
# LQV1P = .46078;
#
# ANGLEBV2P = -.0112;
#
# LBV2P = 1.3999926826781401;
#
# TILTBV2P = 1.5707963267948966;
#
# ANGLEBV1P = .0112;
#
# LBV1P = 1.3999926826781401;
#
# TILTBV1P = 1.5707963267948966;
#
# LFZLFBKP1 = .88;
#
# LFZLFBKP2 = .88;
#
# FREQCAAFLP = 508.8797790984871;
#
# VOLTCAAFLP = .41454545454545455;
#
# FREQCABFLP = 508.8797790984871;
#
# VOLTCABFLP = .41454545454545455;
#
# FREQCACFLP = 508.8797790984871;
#
# VOLTCACFLP = .41454545454545455;
#
# FREQCADFLP = 508.8797790984871;
#
# VOLTCADFLP = .41454545454545455;
#
# K1QI2P = .26467795404296635;
#
# LQI2P = .58372;
#
# FREQCAEFLP = 508.8797790984871;
#
# VOLTCAEFLP = .41454545454545455;
#
# FREQCAFFLP = 508.8797790984871;
#
# VOLTCAFFLP = .41454545454545455;
#
# K1QI3P = -.3812598295316595;
#
# LQI3P = .58372;
#
# LFQABP = .35;
#
# K1QI4P = .5033621570595175;
#
# LQI4P = .46078;
#
# K1QI5P = -.5001127959804639;
#
# LQI5P = .46078;
#
# K1QI6P = .3113688028334224;
#
# LQI6P = .58372;
#
# LQKI6P = .3444;
#
# K1QI7P = -.03672195186232613;
#
# LQI7P = .46078;
#
# K1QI8P = .09265170784754954;
#
# LQI8P = .46078;
#
# ANGLEBSWFLP = -.005036943051;
#
# LBSWFLP = .43149954385438755;
#
# ANGLEBS2FLP = .02804993440705;
#
# LBS2FLP = .8934607087515015;
#
# K1QS1FLP = -.36189520697714456;
#
# LQS1FLP = .46227;
#
# K1QSBFLP = .195293757705134;
#
# LQSBFLP = .46227;
#
# K1QS2FLP = .10623823281871245;
#
# LQS2FLP = .46227;
#
# K2SF2FLP = 3.644620342358542;
#
# LSF2FLP = .334;
#
# K2SD3FLP = -12.020273157628656;
#
# LSD3FLP = .334;
#
# K2SF4FLP = 3.771090565289925;
#
# LSF4FLP = .334;
#
# K2SD5FLP = -4.901868009306966;
#
# LSD5FLP = .334;
#
# K2SF6FLP = .3279336755195833;
#
# LSF6FLP = .334;
#
# K2SD7FLP = -19.20647514632074;
#
# LSD7FLP = .334;
#
# K1QT1FOP = -.5479353341564305;
#
# LQT1FOP = .46227;
#
# K1QT2FOP = .28375492797200863;
#
# LQT2FOP = .46227;
#
# K2SF8FOP = 4.156515394357803;
#
# LSF8FOP = .334;
#
# K1QTAFOP = .20073019022398253;
#
# LQTAFOP = .46227;
#
# K1QT3FOP = -.3738932937204895;
#
# LQT3FOP = .46227;
#
# K1QT4FOP = .26256478273083156;
#
# LQT4FOP = .46227;
#
# K1QT5FOP = -.13627139910384584;
#
# LQT5FOP = .46227;
#
# K2SD7ORP = -10.07723399639649;
#
# LSD7ORP = .334;
#
# K2SF6ORP = 3.012157841954166;
#
# LSF6ORP = .334;
#
# K2SD5ORP = -5.486736072698627;
#
# LSD5ORP = .334;
#
# K2SF4ORP = 6.829100677047477;
#
# LSF4ORP = .334;
#
# K2SD3ORP = -10.378688513681615;
#
# LSD3ORP = .334;
#
# K2SF2ORP = 4.198220405445408;
#
# LSF2ORP = .334;
#
# LQS2OP = .46078;
#
# K1QSBOP = .34407339486699645;
#
# LQSBOP = .46078;
#
# K1QS1OP = -.5791352746003049;
#
# LQS1OP = .46078;
#
# ANGLEBS2OP = .0280499344;
#
# LBS2OP = .8934607087515162;
#
# K1QW8ORP = .37768866751697105;
#
# LQW8ORP = .46078;
#
# K1QW7ORP = -.6094125882367382;
#
# LQW7ORP = .46078;
#
# K1QW6ORP = .33537413937527555;
#
# LQW6ORP = .46078;
#
# K1QW5ORP = -.1742915052053357;
#
# LQW5ORP = .58372;
#
# FREQCAFORP = 508.8797790984871;
#
# VOLTCAFORP = .41454545454545455;
#
# FREQCAEORP = 508.8797790984871;
#
# VOLTCAEORP = .41454545454545455;
#
# K1QW4ORP = .22833818455675034;
#
# LQW4ORP = .58372;
#
# FREQCADORP = 508.8797790984871;
#
# VOLTCADORP = .41454545454545455;
#
# FREQCACORP = 508.8797790984871;
#
# VOLTCACORP = .41454545454545455;
#
# K1QW3ORP = -.26170946560260727;
#
# LQW3ORP = .58372;
#
# FREQCABORP = 508.8797790984871;
#
# VOLTCABORP = .41454545454545455;
#
# FREQCAAORP = 508.8797790984871;
#
# VOLTCAAORP = .41454545454545455;
#
# K1QW2ORP = .3012626618042;
#
# LQW2ORP = .58372;
#
# K1QDWOP = -.28548976053890335;
#
# LQDWOP = .46078;
#
# K1QFWOP = .3398243310469721;
#
# LQFWOP = .46078;
#
# K1QW2OLP = .32720352503600875;
#
# LQW2OLP = .46078;
#
# K1QW3OLP = -.39612871460042215;
#
# LQW3OLP = .46078;
#
# K1QW4OLP = .2941937302736885;
#
# LQW4OLP = .46078;
#
# K1QW5OLP = -.29358763738758453;
#
# LQW5OLP = .46078;
#
# K1QW6OLP = .3351020506101292;
#
# LQW6OLP = .46078;
#
# K1QW7OLP = -.5818253811151216;
#
# LQW7OLP = .46078;
#
# K1QW8OLP = .3671543727487433;
#
# LQW8OLP = .46078;
#
# K2SF2OLP = 10.723030842584008;
#
# LSF2OLP = .334;
#
# K2SD3OLP = -12.469808551799664;
#
# LSD3OLP = .334;
#
# K2SF4OLP = 7.062819464090822;
#
# LSF4OLP = .334;
#
# K2SD5OLP = -3.3702410581400803;
#
# LSD5OLP = .334;
#
# K2SF6OLP = 3.149949802966722;
#
# LSF6OLP = .334;
#
# K2SD7OLP = -16.50978887693855;
#
# LSD7OLP = .334;
#
# K1QT1OTP = -.5479353341564305;
#
# LQT1OTP = .46227;
#
# K1QT2OTP = .28375492797200863;
#
# LQT2OTP = .46227;
#
# K2SF8OTP = 2.7465356572383133;
#
# LSF8OTP = .334;
#
# K1QTAOTP = .20073019022398253;
#
# LQTAOTP = .46227;
#
# K1QT3OTP = -.3738932937204895;
#
# LQT3OTP = .46227;
#
# K1QT4OTP = .26256478273083156;
#
# LQT4OTP = .46227;
#
# K1QT5OTP = -.13627139910384584;
#
# LQT5OTP = .46227;
#
# K2SD7TRP = -23.907121691699512;
#
# LSD7TRP = .334;
#
# K2SF6TRP = 1.8061111146199904;
#
# LSF6TRP = .334;
#
# K2SD5TRP = -6.945515240593215;
#
# LSD5TRP = .334;
#
# K2SF4TRP = .3729606132239841;
#
# LSF4TRP = .334;
#
# K2SD3TRP = -5.454174357474445;
#
# LSD3TRP = .334;
#
# K1QLA9RP = -.5409119771975867;
#
# LQLA9RP = .46078;
#
# K1QLA8RP = .43786003732077183;
#
# LQLA8RP = .46078;
#
# LZDS4RP = .25;
#
# K1QLA7RP = -.3650307448647872;
#
# LQLA7RP = .46078;
#
# ANGLEBLA6RP = .0504439544;
#
# LBLA6RP = 3.961250978424405;
#
# K1QLA6RP = .42062985151005733;
#
# LQLA6RP = .46078;
#
# K1QLA5RP = -.5078277736367988;
#
# LQLA5RP = .46078;
#
# K1QLA4RP = .5187291932147673;
#
# LQLA4RP = .46078;
#
# K1QLA3RP = -.09706939832395658;
#
# LQLA3RP = .57638;
#
# ANGLEBLA2RP = .012542883934;
#
# LBLA2RP = .8934841430379843;
#
# K1QLA2RP = .3539378087894065;
#
# LQLA2RP = .57638;
#
# K2SLXTRP = 1.813641636766925;
#
# LSLXTRP = .334;
#
# ANGLEBLX2RP = .020872024666;
#
# LBLX2RP = 2.2302495166084344;
#
# K1QLX1RP = -.47598013695715474;
#
# LQLX1RP = .57638;
#
# ANGLEBLX4RP = .045831818115;
#
# LBLX4RP = 3.961324271186949;
#
# K1QLX2RP = .4478252775669689;
#
# LQLX2RP = .57638;
#
# K1QLB4RP = .3393057764795778;
#
# LQLB4RP = .58372;
#
# ANGLEBLB3RP = -.051999894948;
#
# LBLB3RP = 4.159185363383046;
#
# K1QLB3RP = -.4815300100216222;
#
# LQLB3RP = .57638;
#
# LZDS3RP = .25;
#
# K1QLB2RP = .2984582099352889;
#
# LQLB2RP = .58372;
#
# ANGLEBLB2RP = -.032996104916;
#
# LBLB2RP = 2.2301888258564673;
#
# K1QLB1RP = -.30680613920482225;
#
# LQLB1RP = .58372;
#
# K2SLYTRP1 = 7.042385071114856;
#
# LSLYTRP1 = .334;
#
# ANGLEBLY2RP = .060849539296;
#
# LBLY2RP = 4.159012287566443;
#
# ANGLEBLY3RP = -.01871887742;
#
# LBLY3RP = 2.2302574382457774;
#
# K1QLY2RP = .28050743375278797;
#
# LQLY2RP = .58372;
#
# ANGLEBLY5RP = -.063981331637;
#
# LBLY5RP = 4.158944536115564;
#
# K1QLY1RP = -.347057264908748;
#
# LQLY1RP = .58372;
#
# K2SLYTRP2 = 7.042385071114856;
#
# LSLYTRP2 = .334;
#
# K1QLC3RP = -.2816061903353231;
#
# LQLC3RP = .58372;
#
# LQKERP = .3444;
#
# ANGLEBLC2RP = .0614132794203416;
#
# LBLC2RP = 4.159000342770337;
#
# LQKDRP = .3444;
#
# K1QLC2RP = .19216053597015292;
#
# LQLC2RP = .58372;
#
# LZDS2RP = .25;
#
# LQKCRP = .3444;
#
# K1QLC1RP = -.3191998332254137;
#
# LQLC1RP = .58372;
#
# LZDS1RP = .25;
#
# LQKBRP = .3444;
#
# ANGLEBLC1RP = -.027796300060003793;
#
# LBLC1RP = 2.2353140366995747;
#
# ANGLEBLCWRP = -.014907437619134638;
#
# LBLCWRP = 2.235365301156549;
#
# LQKARP = .3444;
#
# K1QC2RP = 2.108619705279287;
#
# LQC2RP = .41;
#
# K1QC1RP = -5.071050383456693;
#
# LQC1RP = .34;
#
#
#
# IP : MARKER;
#
# QC1LP : QUADRUPOLE, K1:= K1QC1LP, L:= LQC1LP;
#
# QC2LP : QUADRUPOLE, K1:= K1QC2LP, L:= LQC2LP;
#
# QKALP : QUADRUPOLE, L:= LQKALP;
#
# BLC1LP1 : RBEND, ANGLE:= ANGLEBLC1LP1, E1:=  .0000000000 * ANGLEBLC1LP1, E2:=  .0000000000 * ANGLEBLC1LP1, L:= LBLC1LP1;
#
# BLC1LP2 : RBEND, ANGLE:= ANGLEBLC1LP2, E1:=  .0000000000 * ANGLEBLC1LP2, E2:=  .0000000000 * ANGLEBLC1LP2, L:= LBLC1LP2;
#
# QKBLP : QUADRUPOLE, L:= LQKBLP;
#
# ZDS1LP : QUADRUPOLE, L:= LZDS1LP;
#
# QLC1LP : QUADRUPOLE, K1:= K1QLC1LP, L:= LQLC1LP;
#
# MQLC1LP : MONITOR;
#
# QKCLP : QUADRUPOLE, L:= LQKCLP;
#
# ZDS2LP : QUADRUPOLE, L:= LZDS2LP;
#
# QLC2LP : QUADRUPOLE, K1:= K1QLC2LP, L:= LQLC2LP;
#
# MQLC2LP : MONITOR;
#
# QKDLP : QUADRUPOLE, L:= LQKDLP;
#
# BLC2LP : RBEND, ANGLE:= ANGLEBLC2LP, E1:=  .0000000000 * ANGLEBLC2LP, E2:=  .0000000000 * ANGLEBLC2LP, L:= LBLC2LP;
#
# QKELP : QUADRUPOLE, L:= LQKELP;
#
# QLC3LP : QUADRUPOLE, K1:= K1QLC3LP, L:= LQLC3LP;
#
# MQLC3LP : MONITOR;
#
# SLYTLP1 : SEXTUPOLE, K2:= K2SLYTLP1, L:= LSLYTLP1;
#
# BLY2LP : RBEND, ANGLE:= ANGLEBLY2LP, E1:=  .0000000000 * ANGLEBLY2LP, E2:=  .0000000000 * ANGLEBLY2LP, L:= LBLY2LP;
#
# BLY3LP : RBEND, ANGLE:= ANGLEBLY3LP, E1:=  .0000000000 * ANGLEBLY3LP, E2:=  .0000000000 * ANGLEBLY3LP, L:= LBLY3LP;
#
# MQLY2LP1 : MONITOR;
#
# QLY2LP : QUADRUPOLE, K1:= K1QLY2LP, L:= LQLY2LP;
#
# BLY5LP : RBEND, ANGLE:= ANGLEBLY5LP, E1:=  .0000000000 * ANGLEBLY5LP, E2:=  .0000000000 * ANGLEBLY5LP, L:= LBLY5LP;
#
# MQLY1LP : MONITOR;
#
# QLY1LP : QUADRUPOLE, K1:= K1QLY1LP, L:= LQLY1LP;
#
# MQLY2LP2 : MONITOR;
#
# SLYTLP2 : SEXTUPOLE, K2:= K2SLYTLP2, L:= LSLYTLP2;
#
# MQLB1LP : MONITOR;
#
# QLB1LP : QUADRUPOLE, K1:= K1QLB1LP, L:= LQLB1LP;
#
# BLB2LP : RBEND, ANGLE:= ANGLEBLB2LP, E1:=  .0000000000 * ANGLEBLB2LP, E2:=  .0000000000 * ANGLEBLB2LP, L:= LBLB2LP;
#
# QLB2LP : QUADRUPOLE, K1:= K1QLB2LP, L:= LQLB2LP;
#
# MQLB2LP : MONITOR;
#
# ZDS3LP : QUADRUPOLE, L:= LZDS3LP;
#
# QLB3LP : QUADRUPOLE, K1:= K1QLB3LP, L:= LQLB3LP;
#
# MQLB3LP : MONITOR;
#
# BLB3LP : RBEND, ANGLE:= ANGLEBLB3LP, E1:=  .0000000000 * ANGLEBLB3LP, E2:=  .0000000000 * ANGLEBLB3LP, L:= LBLB3LP;
#
# QLB4LP : QUADRUPOLE, K1:= K1QLB4LP, L:= LQLB4LP;
#
# MQLB4LP : MONITOR;
#
# SLXTLP : SEXTUPOLE, K2:= K2SLXTLP, L:= LSLXTLP;
#
# BLX2LP : RBEND, ANGLE:= ANGLEBLX2LP, E1:=  .0000000000 * ANGLEBLX2LP, E2:=  .0000000000 * ANGLEBLX2LP, L:= LBLX2LP;
#
# MQLX1LP1 : MONITOR;
#
# QLX1LP : QUADRUPOLE, K1:= K1QLX1LP, L:= LQLX1LP;
#
# BLX4LP : RBEND, ANGLE:= ANGLEBLX4LP, E1:=  .0000000000 * ANGLEBLX4LP, E2:=  .0000000000 * ANGLEBLX4LP, L:= LBLX4LP;
#
# MQLX2LP : MONITOR;
#
# QLX2LP : QUADRUPOLE, K1:= K1QLX2LP, L:= LQLX2LP;
#
# MQLX1LP2 : MONITOR;
#
# MQLA2LP : MONITOR;
#
# QLA2LP : QUADRUPOLE, K1:= K1QLA2LP, L:= LQLA2LP;
#
# BLA1LP : RBEND, ANGLE:= ANGLEBLA1LP, E1:=  .0000000000 * ANGLEBLA1LP, E2:=  .0000000000 * ANGLEBLA1LP, L:= LBLA1LP;
#
# MQLA3LP : MONITOR;
#
# QLA3LP : QUADRUPOLE, K1:= K1QLA3LP, L:= LQLA3LP;
#
# BLA2LP : RBEND, ANGLE:= ANGLEBLA2LP, E1:=  .0000000000 * ANGLEBLA2LP, E2:=  .0000000000 * ANGLEBLA2LP, L:= LBLA2LP;
#
# MQLA4LP : MONITOR;
#
# QLA4LP : QUADRUPOLE, K1:= K1QLA4LP, L:= LQLA4LP;
#
# QLA5LP : QUADRUPOLE, K1:= K1QLA5LP, L:= LQLA5LP;
#
# MQLA5LP : MONITOR;
#
# BLA6LP : RBEND, ANGLE:= ANGLEBLA6LP, E1:=  .0000000000 * ANGLEBLA6LP, E2:=  .0000000000 * ANGLEBLA6LP, L:= LBLA6LP;
#
# MQLA6LP : MONITOR;
#
# QLA6LP : QUADRUPOLE, K1:= K1QLA6LP, L:= LQLA6LP;
#
# ZDS4LP : QUADRUPOLE, L:= LZDS4LP;
#
# MQLA7LP : MONITOR;
#
# QLA7LP : QUADRUPOLE, K1:= K1QLA7LP, L:= LQLA7LP;
#
# MQLA8LP : MONITOR;
#
# QLA8LP : QUADRUPOLE, K1:= K1QLA8LP, L:= LQLA8LP;
#
# QLA9LP : QUADRUPOLE, K1:= K1QLA9LP, L:= LQLA9LP;
#
# MQLA9LP : MONITOR;
#
# PTSULM : MARKER;
#
# SD3TLP : SEXTUPOLE, K2:= K2SD3TLP, L:= LSD3TLP;
#
# DB2P : MULTIPOLE;
#
# B2P : RBEND, ANGLE:= ANGLEB2P, E1:=  .0000000000 * ANGLEB2P, E2:=  .0000000000 * ANGLEB2P, L:= LB2P;
#
# QF2P : QUADRUPOLE, K1:= K1QF2P, L:= LQF2P;
#
# MQF2P1 : MONITOR;
#
# MQD1P1 : MONITOR;
#
# QD1P : QUADRUPOLE, K1:= K1QD1P, L:= LQD1P;
#
# MQF2P2 : MONITOR;
#
# MQD3P2 : MONITOR;
#
# QD3P : QUADRUPOLE, K1:= K1QD3P, L:= LQD3P;
#
# QF4P : QUADRUPOLE, K1:= K1QF4P, L:= LQF4P;
#
# MQF4P2 : MONITOR;
#
# SF4TLP : SEXTUPOLE, K2:= K2SF4TLP, L:= LSF4TLP;
#
# MQEAP3 : MONITOR;
#
# QEAP : QUADRUPOLE, K1:= K1QEAP, L:= LQEAP;
#
# MQD5P3 : MONITOR;
#
# QD5P : QUADRUPOLE, K1:= K1QD5P, L:= LQD5P;
#
# QF6P : QUADRUPOLE, K1:= K1QF6P, L:= LQF6P;
#
# MQF6P2 : MONITOR;
#
# MQD5P4 : MONITOR;
#
# MQEAP4 : MONITOR;
#
# MQF4P3 : MONITOR;
#
# MQD3P3 : MONITOR;
#
# SD5TLP : SEXTUPOLE, K2:= K2SD5TLP, L:= LSD5TLP;
#
# MQF2P3 : MONITOR;
#
# MQD1P2 : MONITOR;
#
# MQF2P4 : MONITOR;
#
# MQD3P4 : MONITOR;
#
# MQF4P4 : MONITOR;
#
# SF6TLP : SEXTUPOLE, K2:= K2SF6TLP, L:= LSF6TLP;
#
# MQEAP5 : MONITOR;
#
# MQD5P5 : MONITOR;
#
# MQF6P3 : MONITOR;
#
# MQD5P6 : MONITOR;
#
# MQEAP6 : MONITOR;
#
# MQF4P5 : MONITOR;
#
# MQD3P5 : MONITOR;
#
# SD7TLP : SEXTUPOLE, K2:= K2SD7TLP, L:= LSD7TLP;
#
# MQF2P5 : MONITOR;
#
# MQD1P3 : MONITOR;
#
# MQF2P6 : MONITOR;
#
# MQT1TNP1 : MONITOR;
#
# QT1TNP : QUADRUPOLE, K1:= K1QT1TNP, L:= LQT1TNP;
#
# QT2TNP : QUADRUPOLE, K1:= K1QT2TNP, L:= LQT2TNP;
#
# MQT2TNP1 : MONITOR;
#
# SF8TNP : SEXTUPOLE, K2:= K2SF8TNP, L:= LSF8TNP;
#
# MQTATNP1 : MONITOR;
#
# QTATNP : QUADRUPOLE, K1:= K1QTATNP, L:= LQTATNP;
#
# MQT3TNP1 : MONITOR;
#
# QT3TNP : QUADRUPOLE, K1:= K1QT3TNP, L:= LQT3TNP;
#
# QT4TNP : QUADRUPOLE, K1:= K1QT4TNP, L:= LQT4TNP;
#
# MQT4TNP1 : MONITOR;
#
# QT5TNP : QUADRUPOLE, K1:= K1QT5TNP, L:= LQT5TNP;
#
# MQT5TNP : MONITOR;
#
# MQT4TNP2 : MONITOR;
#
# MQT3TNP2 : MONITOR;
#
# MQTATNP2 : MONITOR;
#
# MQT2TNP2 : MONITOR;
#
# MQT1TNP2 : MONITOR;
#
# SD7NRP : SEXTUPOLE, K2:= K2SD7NRP, L:= LSD7NRP;
#
# MQF2P7 : MONITOR;
#
# MQD1P4 : MONITOR;
#
# MQF2P8 : MONITOR;
#
# MQD3P6 : MONITOR;
#
# MQF4P6 : MONITOR;
#
# SF6NRP : SEXTUPOLE, K2:= K2SF6NRP, L:= LSF6NRP;
#
# MQEAP7 : MONITOR;
#
# MQD5P7 : MONITOR;
#
# MQF6P4 : MONITOR;
#
# MQD5P8 : MONITOR;
#
# MQEAP8 : MONITOR;
#
# MQF4P7 : MONITOR;
#
# MQD3P7 : MONITOR;
#
# SD5NRP : SEXTUPOLE, K2:= K2SD5NRP, L:= LSD5NRP;
#
# MQF2P9 : MONITOR;
#
# MQD1P5 : MONITOR;
#
# MQF2P10 : MONITOR;
#
# MQD3P8 : MONITOR;
#
# MQF4P8 : MONITOR;
#
# SF4NRP : SEXTUPOLE, K2:= K2SF4NRP, L:= LSF4NRP;
#
# MQEAP9 : MONITOR;
#
# MQD5P9 : MONITOR;
#
# MQF6P5 : MONITOR;
#
# MQD5P10 : MONITOR;
#
# MQEAP10 : MONITOR;
#
# MQF4P9 : MONITOR;
#
# MQD3P9 : MONITOR;
#
# SD3NRP : SEXTUPOLE, K2:= K2SD3NRP, L:= LSD3NRP;
#
# MQF2P11 : MONITOR;
#
# MQD1P6 : MONITOR;
#
# MQF2P12 : MONITOR;
#
# MQD3P10 : MONITOR;
#
# MQF4P10 : MONITOR;
#
# SF2NRP : SEXTUPOLE, K2:= K2SF2NRP, L:= LSF2NRP;
#
# MQEAP11 : MONITOR;
#
# MQD5P11 : MONITOR;
#
# MQF6P6 : MONITOR;
#
# MQD5P12 : MONITOR;
#
# MQEAP12 : MONITOR;
#
# MQS2NP1 : MONITOR;
#
# QS2NP : QUADRUPOLE, K1:= K1QS2NP, L:= LQS2NP;
#
# QSBNP : QUADRUPOLE, K1:= K1QSBNP, L:= LQSBNP;
#
# MQSBNP1 : MONITOR;
#
# MQS1NP1 : MONITOR;
#
# QS1NP : QUADRUPOLE, K1:= K1QS1NP, L:= LQS1NP;
#
# BS2NP : RBEND, ANGLE:= ANGLEBS2NP, E1:=  .0000000000 * ANGLEBS2NP, E2:=  .0000000000 * ANGLEBS2NP, L:= LBS2NP;
#
# PNIKRM : MARKER;
#
# QW8NRP : QUADRUPOLE, K1:= K1QW8NRP, L:= LQW8NRP;
#
# MQW8NRP : MONITOR;
#
# QW7NRP : QUADRUPOLE, K1:= K1QW7NRP, L:= LQW7NRP;
#
# MQW7NRP : MONITOR;
#
# QW6NRP : QUADRUPOLE, K1:= K1QW6NRP, L:= LQW6NRP;
#
# MQW6NRP : MONITOR;
#
# QW5NRP : QUADRUPOLE, K1:= K1QW5NRP, L:= LQW5NRP;
#
# MQW5NRP : MONITOR;
#
# QW4NRP : QUADRUPOLE, K1:= K1QW4NRP, L:= LQW4NRP;
#
# MQW4NRP : MONITOR;
#
# QW3NRP : QUADRUPOLE, K1:= K1QW3NRP, L:= LQW3NRP;
#
# MQW3NRP : MONITOR;
#
# QW2NRP : QUADRUPOLE, K1:= K1QW2NRP, L:= LQW2NRP;
#
# MQW2NRP : MONITOR;
#
# PQDWNC : MARKER;
#
# QDWNP : QUADRUPOLE, K1:= K1QDWNP, L:= LQDWNP;
#
# MQDWNP1 : MONITOR;
#
# QFWNP : QUADRUPOLE, K1:= K1QFWNP, L:= LQFWNP;
#
# MQFWNP1 : MONITOR;
#
# MQDWNP2 : MONITOR;
#
# MQFWNP2 : MONITOR;
#
# MQDWNP3 : MONITOR;
#
# MQFWNP3 : MONITOR;
#
# MQDWNP4 : MONITOR;
#
# MQFWNP4 : MONITOR;
#
# MQDWNP5 : MONITOR;
#
# MQFWNP5 : MONITOR;
#
# MQDWNP6 : MONITOR;
#
# QW2NLP : QUADRUPOLE, K1:= K1QW2NLP, L:= LQW2NLP;
#
# MQW2NLP : MONITOR;
#
# QW3NLP : QUADRUPOLE, K1:= K1QW3NLP, L:= LQW3NLP;
#
# MQW3NLP : MONITOR;
#
# QW4NLP : QUADRUPOLE, K1:= K1QW4NLP, L:= LQW4NLP;
#
# MQW4NLP : MONITOR;
#
# MQW5NLP : MONITOR;
#
# QW5NLP : QUADRUPOLE, K1:= K1QW5NLP, L:= LQW5NLP;
#
# MQW6NLP : MONITOR;
#
# QW6NLP : QUADRUPOLE, K1:= K1QW6NLP, L:= LQW6NLP;
#
# MQW7NLP : MONITOR;
#
# QW7NLP : QUADRUPOLE, K1:= K1QW7NLP, L:= LQW7NLP;
#
# MQW8NLP : MONITOR;
#
# QW8NLP : QUADRUPOLE, K1:= K1QW8NLP, L:= LQW8NLP;
#
# PNIKLM : MARKER;
#
# MQS1NP2 : MONITOR;
#
# MQSBNP2 : MONITOR;
#
# MQS2NP2 : MONITOR;
#
# SF2NLP : SEXTUPOLE, K2:= K2SF2NLP, L:= LSF2NLP;
#
# MQEAP13 : MONITOR;
#
# MQD5P13 : MONITOR;
#
# MQF6P7 : MONITOR;
#
# MQD5P14 : MONITOR;
#
# MQEAP14 : MONITOR;
#
# MQF4P11 : MONITOR;
#
# MQD3P11 : MONITOR;
#
# SD3NLP : SEXTUPOLE, K2:= K2SD3NLP, L:= LSD3NLP;
#
# MQF2P13 : MONITOR;
#
# MQD1P7 : MONITOR;
#
# MQF2P14 : MONITOR;
#
# MQD3P12 : MONITOR;
#
# MQF4P12 : MONITOR;
#
# SF4NLP : SEXTUPOLE, K2:= K2SF4NLP, L:= LSF4NLP;
#
# MQEAP15 : MONITOR;
#
# MQD5P15 : MONITOR;
#
# MQF6P8 : MONITOR;
#
# MQD5P16 : MONITOR;
#
# MQEAP16 : MONITOR;
#
# MQF4P13 : MONITOR;
#
# MQD3P13 : MONITOR;
#
# SD5NLP : SEXTUPOLE, K2:= K2SD5NLP, L:= LSD5NLP;
#
# MQF2P15 : MONITOR;
#
# MQD1P8 : MONITOR;
#
# MQF2P16 : MONITOR;
#
# MQD3P14 : MONITOR;
#
# MQF4P14 : MONITOR;
#
# SF6NLP : SEXTUPOLE, K2:= K2SF6NLP, L:= LSF6NLP;
#
# MQEAP17 : MONITOR;
#
# MQD5P17 : MONITOR;
#
# MQF6P9 : MONITOR;
#
# MQD5P18 : MONITOR;
#
# MQEAP18 : MONITOR;
#
# MQF4P15 : MONITOR;
#
# MQD3P15 : MONITOR;
#
# SD7NLP : SEXTUPOLE, K2:= K2SD7NLP, L:= LSD7NLP;
#
# MQF2P17 : MONITOR;
#
# MQD1P9 : MONITOR;
#
# MQF2P18 : MONITOR;
#
# MQT1NFP1 : MONITOR;
#
# QT1NFP : QUADRUPOLE, K1:= K1QT1NFP, L:= LQT1NFP;
#
# QT2NFP : QUADRUPOLE, K1:= K1QT2NFP, L:= LQT2NFP;
#
# MQT2NFP1 : MONITOR;
#
# SF8NFP : SEXTUPOLE, K2:= K2SF8NFP, L:= LSF8NFP;
#
# MQTANFP1 : MONITOR;
#
# QTANFP : QUADRUPOLE, K1:= K1QTANFP, L:= LQTANFP;
#
# MQT3NFP1 : MONITOR;
#
# QT3NFP : QUADRUPOLE, K1:= K1QT3NFP, L:= LQT3NFP;
#
# QT4NFP : QUADRUPOLE, K1:= K1QT4NFP, L:= LQT4NFP;
#
# MQT4NFP1 : MONITOR;
#
# QT5NFP : QUADRUPOLE, K1:= K1QT5NFP, L:= LQT5NFP;
#
# MQT5NFP : MONITOR;
#
# MQT4NFP2 : MONITOR;
#
# MQT3NFP2 : MONITOR;
#
# MQTANFP2 : MONITOR;
#
# MQT2NFP2 : MONITOR;
#
# MQT1NFP2 : MONITOR;
#
# SD7FRP : SEXTUPOLE, K2:= K2SD7FRP, L:= LSD7FRP;
#
# MQF2P19 : MONITOR;
#
# MQD1P10 : MONITOR;
#
# MQF2P20 : MONITOR;
#
# MQD3P16 : MONITOR;
#
# MQF4P16 : MONITOR;
#
# SF6FRP : SEXTUPOLE, K2:= K2SF6FRP, L:= LSF6FRP;
#
# MQEAP19 : MONITOR;
#
# MQD5P19 : MONITOR;
#
# MQF6P10 : MONITOR;
#
# MQD5P20 : MONITOR;
#
# MQEAP20 : MONITOR;
#
# MQF4P17 : MONITOR;
#
# MQD3P17 : MONITOR;
#
# SD5FRP : SEXTUPOLE, K2:= K2SD5FRP, L:= LSD5FRP;
#
# MQF2P21 : MONITOR;
#
# MQD1P11 : MONITOR;
#
# MQF2P22 : MONITOR;
#
# MQD3P18 : MONITOR;
#
# MQF4P18 : MONITOR;
#
# SF4FRP : SEXTUPOLE, K2:= K2SF4FRP, L:= LSF4FRP;
#
# MQEAP21 : MONITOR;
#
# MQD5P21 : MONITOR;
#
# MQF6P11 : MONITOR;
#
# MQD5P22 : MONITOR;
#
# MQEAP22 : MONITOR;
#
# MQF4P19 : MONITOR;
#
# MQD3P19 : MONITOR;
#
# SD3FRP : SEXTUPOLE, K2:= K2SD3FRP, L:= LSD3FRP;
#
# MQF2P23 : MONITOR;
#
# MQD1P12 : MONITOR;
#
# MQF2P24 : MONITOR;
#
# MQD3P20 : MONITOR;
#
# MQF4P20 : MONITOR;
#
# SF2FRP : SEXTUPOLE, K2:= K2SF2FRP, L:= LSF2FRP;
#
# MQEAP23 : MONITOR;
#
# MQD5P23 : MONITOR;
#
# MQF6P12 : MONITOR;
#
# MQD5P24 : MONITOR;
#
# MQEAP24 : MONITOR;
#
# MQS2FRP : MONITOR;
#
# QS2FRP : QUADRUPOLE, K1:= K1QS2FRP, L:= LQS2FRP;
#
# QSBFRP : QUADRUPOLE, K1:= K1QSBFRP, L:= LQSBFRP;
#
# MQSBFRP : MONITOR;
#
# MQS1FRP : MONITOR;
#
# QS1FRP : QUADRUPOLE, K1:= K1QS1FRP, L:= LQS1FRP;
#
# BS2FRP : RBEND, ANGLE:= ANGLEBS2FRP, E1:=  .0000000000 * ANGLEBS2FRP, E2:=  .0000000000 * ANGLEBS2FRP, L:= LBS2FRP;
#
# BSWFRP : RBEND, ANGLE:= ANGLEBSWFRP, E1:=  .0000000000 * ANGLEBSWFRP, E2:=  .0000000000 * ANGLEBSWFRP, L:= LBSWFRP;
#
# PFUJRM : MARKER;
#
# QR6P : QUADRUPOLE, K1:= K1QR6P, L:= LQR6P;
#
# MQR6P : MONITOR;
#
# QR5P : QUADRUPOLE, K1:= K1QR5P, L:= LQR5P;
#
# MQR5P : MONITOR;
#
# QR4P : QUADRUPOLE, K1:= K1QR4P, L:= LQR4P;
#
# MQR4P : MONITOR;
#
# QR3P : QUADRUPOLE, K1:= K1QR3P, L:= LQR3P;
#
# MQR3P : MONITOR;
#
# QR2P : QUADRUPOLE, K1:= K1QR2P, L:= LQR2P;
#
# MQR2P : MONITOR;
#
# QR1P : QUADRUPOLE, K1:= K1QR1P, L:= LQR1P;
#
# MQR1P : MONITOR;
#
# CAFFRP : RFCAVITY, FREQ:= FREQCAFFRP, VOLT:= VOLTCAFFRP;
#
# CAEFRP : RFCAVITY, FREQ:= FREQCAEFRP, VOLT:= VOLTCAEFRP;
#
# QFRP : QUADRUPOLE, K1:= K1QFRP, L:= LQFRP;
#
# MQFRP1 : MONITOR;
#
# CADFRP : RFCAVITY, FREQ:= FREQCADFRP, VOLT:= VOLTCADFRP;
#
# CACFRP : RFCAVITY, FREQ:= FREQCACFRP, VOLT:= VOLTCACFRP;
#
# QDRP : QUADRUPOLE, K1:= K1QDRP, L:= LQDRP;
#
# MQDRP1 : MONITOR;
#
# MQFRP2 : MONITOR;
#
# CABFRP : RFCAVITY, FREQ:= FREQCABFRP, VOLT:= VOLTCABFRP;
#
# MQDRP2 : MONITOR;
#
# CAAFRP : RFCAVITY, FREQ:= FREQCAAFRP, VOLT:= VOLTCAAFRP;
#
# QV4P : QUADRUPOLE, K1:= K1QV4P, L:= LQV4P;
#
# MQV4P1 : MONITOR;
#
# FZTFBKP1 : QUADRUPOLE, L:= LFZTFBKP1;
#
# FZTFBKP2 : QUADRUPOLE, L:= LFZTFBKP2;
#
# QV3P : QUADRUPOLE, K1:= K1QV3P, L:= LQV3P;
#
# MQV3P1 : MONITOR;
#
# MQV2P1 : MONITOR;
#
# QV2P : QUADRUPOLE, K1:= K1QV2P, L:= LQV2P;
#
# MQV1P1 : MONITOR;
#
# QV1P : QUADRUPOLE, K1:= K1QV1P, L:= LQV1P;
#
# PFBMON1 : MARKER;
#
# BV2P : RBEND, ANGLE:= ANGLEBV2P, E1:=  -.500000000 * ANGLEBV2P, E2:=  .5000000000 * ANGLEBV2P, L:= LBV2P, TILT:= TILTBV2P;
#
# BV1P : RBEND, ANGLE:= ANGLEBV1P, E1:=  .5000000000 * ANGLEBV1P, E2:=  -.500000000 * ANGLEBV1P, L:= LBV1P, TILT:= TILTBV1P;
#
# PMID : MARKER;
#
# PFBMON2 : MARKER;
#
# MQV1P2 : MONITOR;
#
# MQV2P2 : MONITOR;
#
# MQV3P2 : MONITOR;
#
# FZLFBKP1 : QUADRUPOLE, L:= LFZLFBKP1;
#
# FZLFBKP2 : QUADRUPOLE, L:= LFZLFBKP2;
#
# MQV4P2 : MONITOR;
#
# CAAFLP : RFCAVITY, FREQ:= FREQCAAFLP, VOLT:= VOLTCAAFLP;
#
# MQDRP3 : MONITOR;
#
# CABFLP : RFCAVITY, FREQ:= FREQCABFLP, VOLT:= VOLTCABFLP;
#
# MQFRP3 : MONITOR;
#
# MQDRP4 : MONITOR;
#
# CACFLP : RFCAVITY, FREQ:= FREQCACFLP, VOLT:= VOLTCACFLP;
#
# CADFLP : RFCAVITY, FREQ:= FREQCADFLP, VOLT:= VOLTCADFLP;
#
# MQI2P : MONITOR;
#
# QI2P : QUADRUPOLE, K1:= K1QI2P, L:= LQI2P;
#
# CAEFLP : RFCAVITY, FREQ:= FREQCAEFLP, VOLT:= VOLTCAEFLP;
#
# CAFFLP : RFCAVITY, FREQ:= FREQCAFFLP, VOLT:= VOLTCAFFLP;
#
# MQI3P : MONITOR;
#
# QI3P : QUADRUPOLE, K1:= K1QI3P, L:= LQI3P;
#
# PDCCT : MARKER;
#
# PCT : MARKER;
#
# FQABP : QUADRUPOLE, L:= LFQABP;
#
# MQI4P : MONITOR;
#
# QI4P : QUADRUPOLE, K1:= K1QI4P, L:= LQI4P;
#
# MQI5P : MONITOR;
#
# QI5P : QUADRUPOLE, K1:= K1QI5P, L:= LQI5P;
#
# INJECTIO : MARKER;
#
# QI6P : QUADRUPOLE, K1:= K1QI6P, L:= LQI6P;
#
# MQI6P : MONITOR;
#
# QKI6P : QUADRUPOLE, L:= LQKI6P;
#
# MQI7P : MONITOR;
#
# QI7P : QUADRUPOLE, K1:= K1QI7P, L:= LQI7P;
#
# QI8P : QUADRUPOLE, K1:= K1QI8P, L:= LQI8P;
#
# MQI8P : MONITOR;
#
# PFUJLM : MARKER;
#
# BSWFLP : RBEND, ANGLE:= ANGLEBSWFLP, E1:=  .0000000000 * ANGLEBSWFLP, E2:=  .0000000000 * ANGLEBSWFLP, L:= LBSWFLP;
#
# BS2FLP : RBEND, ANGLE:= ANGLEBS2FLP, E1:=  .0000000000 * ANGLEBS2FLP, E2:=  .0000000000 * ANGLEBS2FLP, L:= LBS2FLP;
#
# QS1FLP : QUADRUPOLE, K1:= K1QS1FLP, L:= LQS1FLP;
#
# MQS1FLP : MONITOR;
#
# MQSBFLP : MONITOR;
#
# QSBFLP : QUADRUPOLE, K1:= K1QSBFLP, L:= LQSBFLP;
#
# PDUMP1 : MARKER;
#
# PDUMP2 : MARKER;
#
# QS2FLP : QUADRUPOLE, K1:= K1QS2FLP, L:= LQS2FLP;
#
# MQS2FLP : MONITOR;
#
# SF2FLP : SEXTUPOLE, K2:= K2SF2FLP, L:= LSF2FLP;
#
# MQEAP25 : MONITOR;
#
# MQD5P25 : MONITOR;
#
# MQF6P13 : MONITOR;
#
# MQD5P26 : MONITOR;
#
# MQEAP26 : MONITOR;
#
# MQF4P21 : MONITOR;
#
# MQD3P21 : MONITOR;
#
# SD3FLP : SEXTUPOLE, K2:= K2SD3FLP, L:= LSD3FLP;
#
# MQF2P25 : MONITOR;
#
# MQD1P13 : MONITOR;
#
# MQF2P26 : MONITOR;
#
# MQD3P22 : MONITOR;
#
# MQF4P22 : MONITOR;
#
# SF4FLP : SEXTUPOLE, K2:= K2SF4FLP, L:= LSF4FLP;
#
# MQEAP27 : MONITOR;
#
# MQD5P27 : MONITOR;
#
# MQF6P14 : MONITOR;
#
# MQD5P28 : MONITOR;
#
# MQEAP28 : MONITOR;
#
# MQF4P23 : MONITOR;
#
# MQD3P23 : MONITOR;
#
# SD5FLP : SEXTUPOLE, K2:= K2SD5FLP, L:= LSD5FLP;
#
# MQF2P27 : MONITOR;
#
# MQD1P14 : MONITOR;
#
# MQF2P28 : MONITOR;
#
# MQD3P24 : MONITOR;
#
# MQF4P24 : MONITOR;
#
# SF6FLP : SEXTUPOLE, K2:= K2SF6FLP, L:= LSF6FLP;
#
# MQEAP29 : MONITOR;
#
# MQD5P29 : MONITOR;
#
# MQF6P15 : MONITOR;
#
# MQD5P30 : MONITOR;
#
# MQEAP30 : MONITOR;
#
# MQF4P25 : MONITOR;
#
# MQD3P25 : MONITOR;
#
# SD7FLP : SEXTUPOLE, K2:= K2SD7FLP, L:= LSD7FLP;
#
# MQF2P29 : MONITOR;
#
# MQD1P15 : MONITOR;
#
# MQF2P30 : MONITOR;
#
# MQT1FOP1 : MONITOR;
#
# QT1FOP : QUADRUPOLE, K1:= K1QT1FOP, L:= LQT1FOP;
#
# QT2FOP : QUADRUPOLE, K1:= K1QT2FOP, L:= LQT2FOP;
#
# MQT2FOP1 : MONITOR;
#
# SF8FOP : SEXTUPOLE, K2:= K2SF8FOP, L:= LSF8FOP;
#
# MQTAFOP1 : MONITOR;
#
# QTAFOP : QUADRUPOLE, K1:= K1QTAFOP, L:= LQTAFOP;
#
# MQT3FOP1 : MONITOR;
#
# QT3FOP : QUADRUPOLE, K1:= K1QT3FOP, L:= LQT3FOP;
#
# QT4FOP : QUADRUPOLE, K1:= K1QT4FOP, L:= LQT4FOP;
#
# MQT4FOP1 : MONITOR;
#
# QT5FOP : QUADRUPOLE, K1:= K1QT5FOP, L:= LQT5FOP;
#
# MQT5FOP : MONITOR;
#
# MQT4FOP2 : MONITOR;
#
# MQT3FOP2 : MONITOR;
#
# MQTAFOP2 : MONITOR;
#
# MQT2FOP2 : MONITOR;
#
# MQT1FOP2 : MONITOR;
#
# SD7ORP : SEXTUPOLE, K2:= K2SD7ORP, L:= LSD7ORP;
#
# MQF2P31 : MONITOR;
#
# MQD1P16 : MONITOR;
#
# MQF2P32 : MONITOR;
#
# MQD3P26 : MONITOR;
#
# MQF4P26 : MONITOR;
#
# SF6ORP : SEXTUPOLE, K2:= K2SF6ORP, L:= LSF6ORP;
#
# MQEAP31 : MONITOR;
#
# MQD5P31 : MONITOR;
#
# MQF6P16 : MONITOR;
#
# MQD5P32 : MONITOR;
#
# MQEAP32 : MONITOR;
#
# MQF4P27 : MONITOR;
#
# MQD3P27 : MONITOR;
#
# SD5ORP : SEXTUPOLE, K2:= K2SD5ORP, L:= LSD5ORP;
#
# MQF2P33 : MONITOR;
#
# MQD1P17 : MONITOR;
#
# MQF2P34 : MONITOR;
#
# MQD3P28 : MONITOR;
#
# MQF4P28 : MONITOR;
#
# SF4ORP : SEXTUPOLE, K2:= K2SF4ORP, L:= LSF4ORP;
#
# MQEAP33 : MONITOR;
#
# MQD5P33 : MONITOR;
#
# MQF6P17 : MONITOR;
#
# MQD5P34 : MONITOR;
#
# MQEAP34 : MONITOR;
#
# MQF4P29 : MONITOR;
#
# MQD3P29 : MONITOR;
#
# SD3ORP : SEXTUPOLE, K2:= K2SD3ORP, L:= LSD3ORP;
#
# MQF2P35 : MONITOR;
#
# MQD1P18 : MONITOR;
#
# MQF2P36 : MONITOR;
#
# MQD3P30 : MONITOR;
#
# MQF4P30 : MONITOR;
#
# SF2ORP : SEXTUPOLE, K2:= K2SF2ORP, L:= LSF2ORP;
#
# MQEAP35 : MONITOR;
#
# MQD5P35 : MONITOR;
#
# MQF6P18 : MONITOR;
#
# MQD5P36 : MONITOR;
#
# MQEAP36 : MONITOR;
#
# MQS2OP1 : MONITOR;
#
# QS2OP : QUADRUPOLE, L:= LQS2OP;
#
# QSBOP : QUADRUPOLE, K1:= K1QSBOP, L:= LQSBOP;
#
# MQSBOP1 : MONITOR;
#
# MQS1OP1 : MONITOR;
#
# QS1OP : QUADRUPOLE, K1:= K1QS1OP, L:= LQS1OP;
#
# BS2OP : RBEND, ANGLE:= ANGLEBS2OP, E1:=  .0000000000 * ANGLEBS2OP, E2:=  .0000000000 * ANGLEBS2OP, L:= LBS2OP;
#
# POHORM : MARKER;
#
# QW8ORP : QUADRUPOLE, K1:= K1QW8ORP, L:= LQW8ORP;
#
# MQW8ORP : MONITOR;
#
# QW7ORP : QUADRUPOLE, K1:= K1QW7ORP, L:= LQW7ORP;
#
# MQW7ORP : MONITOR;
#
# QW6ORP : QUADRUPOLE, K1:= K1QW6ORP, L:= LQW6ORP;
#
# MQW6ORP : MONITOR;
#
# QW5ORP : QUADRUPOLE, K1:= K1QW5ORP, L:= LQW5ORP;
#
# MQW5ORP : MONITOR;
#
# CAFORP : RFCAVITY, FREQ:= FREQCAFORP, VOLT:= VOLTCAFORP;
#
# CAEORP : RFCAVITY, FREQ:= FREQCAEORP, VOLT:= VOLTCAEORP;
#
# QW4ORP : QUADRUPOLE, K1:= K1QW4ORP, L:= LQW4ORP;
#
# MQW4ORP : MONITOR;
#
# CADORP : RFCAVITY, FREQ:= FREQCADORP, VOLT:= VOLTCADORP;
#
# CACORP : RFCAVITY, FREQ:= FREQCACORP, VOLT:= VOLTCACORP;
#
# QW3ORP : QUADRUPOLE, K1:= K1QW3ORP, L:= LQW3ORP;
#
# MQW3ORP : MONITOR;
#
# CABORP : RFCAVITY, FREQ:= FREQCABORP, VOLT:= VOLTCABORP;
#
# CAAORP : RFCAVITY, FREQ:= FREQCAAORP, VOLT:= VOLTCAAORP;
#
# QW2ORP : QUADRUPOLE, K1:= K1QW2ORP, L:= LQW2ORP;
#
# MQW2ORP : MONITOR;
#
# PQDWOC : MARKER;
#
# QDWOP : QUADRUPOLE, K1:= K1QDWOP, L:= LQDWOP;
#
# MQDWOP1 : MONITOR;
#
# QFWOP : QUADRUPOLE, K1:= K1QFWOP, L:= LQFWOP;
#
# MQFWOP1 : MONITOR;
#
# MQDWOP2 : MONITOR;
#
# MQFWOP2 : MONITOR;
#
# MQDWOP3 : MONITOR;
#
# MQFWOP3 : MONITOR;
#
# MQDWOP4 : MONITOR;
#
# MQFWOP4 : MONITOR;
#
# MQDWOP5 : MONITOR;
#
# MQFWOP5 : MONITOR;
#
# MQDWOP6 : MONITOR;
#
# QW2OLP : QUADRUPOLE, K1:= K1QW2OLP, L:= LQW2OLP;
#
# MQW2OLP : MONITOR;
#
# QW3OLP : QUADRUPOLE, K1:= K1QW3OLP, L:= LQW3OLP;
#
# MQW3OLP : MONITOR;
#
# QW4OLP : QUADRUPOLE, K1:= K1QW4OLP, L:= LQW4OLP;
#
# MQW4OLP : MONITOR;
#
# MQW5OLP : MONITOR;
#
# QW5OLP : QUADRUPOLE, K1:= K1QW5OLP, L:= LQW5OLP;
#
# MQW6OLP : MONITOR;
#
# QW6OLP : QUADRUPOLE, K1:= K1QW6OLP, L:= LQW6OLP;
#
# MQW7OLP : MONITOR;
#
# QW7OLP : QUADRUPOLE, K1:= K1QW7OLP, L:= LQW7OLP;
#
# MQW8OLP : MONITOR;
#
# QW8OLP : QUADRUPOLE, K1:= K1QW8OLP, L:= LQW8OLP;
#
# POHOLM : MARKER;
#
# MQS1OP2 : MONITOR;
#
# MQSBOP2 : MONITOR;
#
# MQS2OP2 : MONITOR;
#
# SF2OLP : SEXTUPOLE, K2:= K2SF2OLP, L:= LSF2OLP;
#
# MQEAP37 : MONITOR;
#
# MQD5P37 : MONITOR;
#
# MQF6P19 : MONITOR;
#
# MQD5P38 : MONITOR;
#
# MQEAP38 : MONITOR;
#
# MQF4P31 : MONITOR;
#
# MQD3P31 : MONITOR;
#
# SD3OLP : SEXTUPOLE, K2:= K2SD3OLP, L:= LSD3OLP;
#
# MQF2P37 : MONITOR;
#
# MQD1P19 : MONITOR;
#
# MQF2P38 : MONITOR;
#
# MQD3P32 : MONITOR;
#
# MQF4P32 : MONITOR;
#
# SF4OLP : SEXTUPOLE, K2:= K2SF4OLP, L:= LSF4OLP;
#
# MQEAP39 : MONITOR;
#
# MQD5P39 : MONITOR;
#
# MQF6P20 : MONITOR;
#
# MQD5P40 : MONITOR;
#
# MQEAP40 : MONITOR;
#
# MQF4P33 : MONITOR;
#
# MQD3P33 : MONITOR;
#
# SD5OLP : SEXTUPOLE, K2:= K2SD5OLP, L:= LSD5OLP;
#
# MQF2P39 : MONITOR;
#
# MQD1P20 : MONITOR;
#
# MQF2P40 : MONITOR;
#
# MQD3P34 : MONITOR;
#
# MQF4P34 : MONITOR;
#
# SF6OLP : SEXTUPOLE, K2:= K2SF6OLP, L:= LSF6OLP;
#
# MQEAP41 : MONITOR;
#
# MQD5P41 : MONITOR;
#
# MQF6P21 : MONITOR;
#
# MQD5P42 : MONITOR;
#
# MQEAP42 : MONITOR;
#
# MQF4P35 : MONITOR;
#
# MQD3P35 : MONITOR;
#
# SD7OLP : SEXTUPOLE, K2:= K2SD7OLP, L:= LSD7OLP;
#
# MQF2P41 : MONITOR;
#
# MQD1P21 : MONITOR;
#
# MQF2P42 : MONITOR;
#
# MQT1OTP1 : MONITOR;
#
# QT1OTP : QUADRUPOLE, K1:= K1QT1OTP, L:= LQT1OTP;
#
# QT2OTP : QUADRUPOLE, K1:= K1QT2OTP, L:= LQT2OTP;
#
# MQT2OTP1 : MONITOR;
#
# SF8OTP : SEXTUPOLE, K2:= K2SF8OTP, L:= LSF8OTP;
#
# MQTAOTP1 : MONITOR;
#
# QTAOTP : QUADRUPOLE, K1:= K1QTAOTP, L:= LQTAOTP;
#
# MQT3OTP1 : MONITOR;
#
# QT3OTP : QUADRUPOLE, K1:= K1QT3OTP, L:= LQT3OTP;
#
# QT4OTP : QUADRUPOLE, K1:= K1QT4OTP, L:= LQT4OTP;
#
# MQT4OTP1 : MONITOR;
#
# QT5OTP : QUADRUPOLE, K1:= K1QT5OTP, L:= LQT5OTP;
#
# MQT5OTP : MONITOR;
#
# MQT4OTP2 : MONITOR;
#
# MQT3OTP2 : MONITOR;
#
# MQTAOTP2 : MONITOR;
#
# MQT2OTP2 : MONITOR;
#
# MQT1OTP2 : MONITOR;
#
# SD7TRP : SEXTUPOLE, K2:= K2SD7TRP, L:= LSD7TRP;
#
# MQF2P43 : MONITOR;
#
# MQD1P22 : MONITOR;
#
# MQF2P44 : MONITOR;
#
# MQD3P36 : MONITOR;
#
# MQF4P36 : MONITOR;
#
# SF6TRP : SEXTUPOLE, K2:= K2SF6TRP, L:= LSF6TRP;
#
# MQEAP43 : MONITOR;
#
# MQD5P43 : MONITOR;
#
# MQF6P22 : MONITOR;
#
# MQD5P44 : MONITOR;
#
# MQEAP44 : MONITOR;
#
# MQF4P37 : MONITOR;
#
# MQD3P37 : MONITOR;
#
# SD5TRP : SEXTUPOLE, K2:= K2SD5TRP, L:= LSD5TRP;
#
# MQF2P45 : MONITOR;
#
# MQD1P23 : MONITOR;
#
# MQF2P46 : MONITOR;
#
# MQD3P38 : MONITOR;
#
# MQF4P38 : MONITOR;
#
# SF4TRP : SEXTUPOLE, K2:= K2SF4TRP, L:= LSF4TRP;
#
# MQEAP45 : MONITOR;
#
# MQD5P45 : MONITOR;
#
# MQF6P23 : MONITOR;
#
# MQD5P46 : MONITOR;
#
# MQEAP46 : MONITOR;
#
# MQF4P39 : MONITOR;
#
# MQD3P39 : MONITOR;
#
# SD3TRP : SEXTUPOLE, K2:= K2SD3TRP, L:= LSD3TRP;
#
# MQF2P47 : MONITOR;
#
# MQD1P24 : MONITOR;
#
# MQF2P48 : MONITOR;
#
# PTSURM : MARKER;
#
# MQLA9RP : MONITOR;
#
# QLA9RP : QUADRUPOLE, K1:= K1QLA9RP, L:= LQLA9RP;
#
# MQLA8RP : MONITOR;
#
# QLA8RP : QUADRUPOLE, K1:= K1QLA8RP, L:= LQLA8RP;
#
# ZDS4RP : QUADRUPOLE, L:= LZDS4RP;
#
# MQLA7RP : MONITOR;
#
# QLA7RP : QUADRUPOLE, K1:= K1QLA7RP, L:= LQLA7RP;
#
# BLA6RP : RBEND, ANGLE:= ANGLEBLA6RP, E1:=  .0000000000 * ANGLEBLA6RP, E2:=  .0000000000 * ANGLEBLA6RP, L:= LBLA6RP;
#
# MQLA6RP : MONITOR;
#
# QLA6RP : QUADRUPOLE, K1:= K1QLA6RP, L:= LQLA6RP;
#
# QLA5RP : QUADRUPOLE, K1:= K1QLA5RP, L:= LQLA5RP;
#
# MQLA5RP : MONITOR;
#
# QLA4RP : QUADRUPOLE, K1:= K1QLA4RP, L:= LQLA4RP;
#
# MQLA4RP : MONITOR;
#
# QLA3RP : QUADRUPOLE, K1:= K1QLA3RP, L:= LQLA3RP;
#
# MQLA3RP : MONITOR;
#
# BLA2RP : RBEND, ANGLE:= ANGLEBLA2RP, E1:=  .0000000000 * ANGLEBLA2RP, E2:=  .0000000000 * ANGLEBLA2RP, L:= LBLA2RP;
#
# QLA2RP : QUADRUPOLE, K1:= K1QLA2RP, L:= LQLA2RP;
#
# MQLA2RP : MONITOR;
#
# SLXTRP : SEXTUPOLE, K2:= K2SLXTRP, L:= LSLXTRP;
#
# BLX2RP : RBEND, ANGLE:= ANGLEBLX2RP, E1:=  .0000000000 * ANGLEBLX2RP, E2:=  .0000000000 * ANGLEBLX2RP, L:= LBLX2RP;
#
# MQLX1RP1 : MONITOR;
#
# QLX1RP : QUADRUPOLE, K1:= K1QLX1RP, L:= LQLX1RP;
#
# BLX4RP : RBEND, ANGLE:= ANGLEBLX4RP, E1:=  .0000000000 * ANGLEBLX4RP, E2:=  .0000000000 * ANGLEBLX4RP, L:= LBLX4RP;
#
# MQLX2RP : MONITOR;
#
# QLX2RP : QUADRUPOLE, K1:= K1QLX2RP, L:= LQLX2RP;
#
# MQLX1RP2 : MONITOR;
#
# MQLB4RP : MONITOR;
#
# QLB4RP : QUADRUPOLE, K1:= K1QLB4RP, L:= LQLB4RP;
#
# BLB3RP : RBEND, ANGLE:= ANGLEBLB3RP, E1:=  .0000000000 * ANGLEBLB3RP, E2:=  .0000000000 * ANGLEBLB3RP, L:= LBLB3RP;
#
# QLB3RP : QUADRUPOLE, K1:= K1QLB3RP, L:= LQLB3RP;
#
# MQLB3RP : MONITOR;
#
# ZDS3RP : QUADRUPOLE, L:= LZDS3RP;
#
# QLB2RP : QUADRUPOLE, K1:= K1QLB2RP, L:= LQLB2RP;
#
# MQLB2RP : MONITOR;
#
# BLB2RP : RBEND, ANGLE:= ANGLEBLB2RP, E1:=  .0000000000 * ANGLEBLB2RP, E2:=  .0000000000 * ANGLEBLB2RP, L:= LBLB2RP;
#
# QLB1RP : QUADRUPOLE, K1:= K1QLB1RP, L:= LQLB1RP;
#
# MQLB1RP : MONITOR;
#
# SLYTRP1 : SEXTUPOLE, K2:= K2SLYTRP1, L:= LSLYTRP1;
#
# BLY2RP : RBEND, ANGLE:= ANGLEBLY2RP, E1:=  .0000000000 * ANGLEBLY2RP, E2:=  .0000000000 * ANGLEBLY2RP, L:= LBLY2RP;
#
# BLY3RP : RBEND, ANGLE:= ANGLEBLY3RP, E1:=  .0000000000 * ANGLEBLY3RP, E2:=  .0000000000 * ANGLEBLY3RP, L:= LBLY3RP;
#
# MQLY2RP1 : MONITOR;
#
# QLY2RP : QUADRUPOLE, K1:= K1QLY2RP, L:= LQLY2RP;
#
# BLY5RP : RBEND, ANGLE:= ANGLEBLY5RP, E1:=  .0000000000 * ANGLEBLY5RP, E2:=  .0000000000 * ANGLEBLY5RP, L:= LBLY5RP;
#
# MQLY1RP : MONITOR;
#
# QLY1RP : QUADRUPOLE, K1:= K1QLY1RP, L:= LQLY1RP;
#
# MQLY2RP2 : MONITOR;
#
# SLYTRP2 : SEXTUPOLE, K2:= K2SLYTRP2, L:= LSLYTRP2;
#
# MQLC3RP : MONITOR;
#
# QLC3RP : QUADRUPOLE, K1:= K1QLC3RP, L:= LQLC3RP;
#
# QKERP : QUADRUPOLE, L:= LQKERP;
#
# BLC2RP : RBEND, ANGLE:= ANGLEBLC2RP, E1:=  .0000000000 * ANGLEBLC2RP, E2:=  .0000000000 * ANGLEBLC2RP, L:= LBLC2RP;
#
# QKDRP : QUADRUPOLE, L:= LQKDRP;
#
# MQLC2RP : MONITOR;
#
# QLC2RP : QUADRUPOLE, K1:= K1QLC2RP, L:= LQLC2RP;
#
# ZDS2RP : QUADRUPOLE, L:= LZDS2RP;
#
# QKCRP : QUADRUPOLE, L:= LQKCRP;
#
# MQLC1RP : MONITOR;
#
# QLC1RP : QUADRUPOLE, K1:= K1QLC1RP, L:= LQLC1RP;
#
# ZDS1RP : QUADRUPOLE, L:= LZDS1RP;
#
# QKBRP : QUADRUPOLE, L:= LQKBRP;
#
# BLC1RP : RBEND, ANGLE:= ANGLEBLC1RP, E1:=  .0000000000 * ANGLEBLC1RP, E2:=  .0000000000 * ANGLEBLC1RP, L:= LBLC1RP;
#
# BLCWRP : RBEND, ANGLE:= ANGLEBLCWRP, E1:=  .0000000000 * ANGLEBLCWRP, E2:=  .0000000000 * ANGLEBLCWRP, L:= LBLCWRP;
#
# QKARP : QUADRUPOLE, L:= LQKARP;
#
# QC2RP : QUADRUPOLE, K1:= K1QC2RP, L:= LQC2RP;
#
# QC1RP : QUADRUPOLE, K1:= K1QC1RP, L:= LQC1RP;
#
#
#
# ASC: SEQUENCE, REFER = CENTRE, L = 3016.30649898794;
#
# IP.1: IP, at = 0;
#
# QC1LP.1: QC1LP, at = .935;
#
# QC2LP.1: QC2LP, at = 1.9250000000000003;
#
# QKALP.1: QKALP, at = 4.801273889355694;
#
# BLC1LP1.1: BLC1LP1, at = 6.28814358285195;
#
# BLC1LP2.1: BLC1LP2, at = 8.653288225764065;
#
# QKBLP.1: QKBLP, at = 10.50530320577414;
#
# ZDS1LP.1: ZDS1LP, at = 12.44041320577414;
#
# QLC1LP.1: QLC1LP, at = 14.290324315285138;
#
# MQLC1LP.1: MQLC1LP, at = 14.740324315285138;
#
# QKCLP.1: QKCLP, at = 15.049054315285138;
#
# ZDS2LP.1: ZDS2LP, at = 19.185558558239137;
#
# QLC2LP.1: QLC2LP, at = 20.675138558239137;
#
# MQLC2LP.1: MQLC2LP, at = 21.125138558239136;
#
# QKDLP.1: QKDLP, at = 21.423868558239135;
#
# BLC2LP.1: BLC2LP, at = 24.25551578233017;
#
# QKELP.1: QKELP, at = 27.087163006421203;
#
# QLC3LP.1: QLC3LP, at = 28.235893006421204;
#
# MQLC3LP.1: MQLC3LP, at = 28.685893006421203;
#
# SLYTLP1.1: SLYTLP1, at = 29.0947530064212;
#
# BLY2LP.1: BLY2LP, at = 31.93953032895628;
#
# BLY3LP.1: BLY3LP, at = 39.519518634362356;
#
# MQLY2LP1.1: MQLY2LP1, at = 41.176523634362354;
#
# QLY2LP.1: QLY2LP, at = 41.62652363436236;
#
# BLY5LP.1: BLY5LP, at = 44.59315671030769;
#
# MQLY1LP.1: MQLY1LP, at = 47.429789786253025;
#
# QLY1LP.1: QLY1LP, at = 47.87978978625303;
#
# BLY5LP.2: BLY5LP, at = 51.16642286219836;
#
# QLY2LP.2: QLY2LP, at = 54.13305593814369;
#
# MQLY2LP2.1: MQLY2LP2, at = 54.583055938143694;
#
# BLY3LP.2: BLY3LP, at = 56.2400609381437;
#
# BLY2LP.2: BLY2LP, at = 63.820049243549775;
#
# SLYTLP2.1: SLYTLP2, at = 66.66482656608486;
#
# MQLB1LP.1: MQLB1LP, at = 67.07368656608486;
#
# QLB1LP.1: QLB1LP, at = 67.52368656608486;
#
# BLB2LP.1: BLB2LP, at = 69.16229156608486;
#
# QLB2LP.1: QLB2LP, at = 73.80017714238586;
#
# MQLB2LP.1: MQLB2LP, at = 74.25017714238587;
#
# ZDS3LP.1: ZDS3LP, at = 82.96911393525886;
#
# QLB3LP.1: QLB3LP, at = 83.82208393525886;
#
# MQLB3LP.1: MQLB3LP, at = 84.27208393525886;
#
# BLB3LP.1: BLB3LP, at = 92.61295846540085;
#
# QLB4LP.1: QLB4LP, at = 93.93156346540084;
#
# MQLB4LP.1: MQLB4LP, at = 94.38156346540084;
#
# SLXTLP.1: SLXTLP, at = 94.79042346540085;
#
# BLX2LP.1: BLX2LP, at = 96.65256846540085;
#
# MQLX1LP1.1: MQLX1LP1, at = 100.53286922181583;
#
# QLX1LP.1: QLX1LP, at = 100.98286922181583;
#
# BLX4LP.1: BLX4LP, at = 103.94950438913611;
#
# MQLX2LP.1: MQLX2LP, at = 106.58613955645637;
#
# QLX2LP.1: QLX2LP, at = 107.03613955645638;
#
# BLX4LP.2: BLX4LP, at = 110.12277472377664;
#
# QLX1LP.2: QLX1LP, at = 113.08940989109692;
#
# MQLX1LP2.1: MQLX1LP2, at = 113.53940989109692;
#
# BLX2LP.2: BLX2LP, at = 117.4197106475119;
#
# SLXTLP.2: SLXTLP, at = 119.2818556475119;
#
# MQLA2LP.1: MQLA2LP, at = 119.69071564751191;
#
# QLA2LP.1: QLA2LP, at = 120.14071564751191;
#
# BLA1LP.1: BLA1LP, at = 123.00737544165104;
#
# MQLA3LP.1: MQLA3LP, at = 129.42746048343116;
#
# QLA3LP.1: QLA3LP, at = 129.87746048343115;
#
# BLA2LP.1: BLA2LP, at = 132.84409603759553;
#
# MQLA4LP.1: MQLA4LP, at = 136.6072650975679;
#
# QLA4LP.1: QLA4LP, at = 137.0072650975679;
#
# QLA5LP.1: QLA5LP, at = 139.8135966224639;
#
# MQLA5LP.1: MQLA5LP, at = 140.2135966224639;
#
# BLA6LP.1: BLA6LP, at = 142.77717002749893;
#
# MQLA6LP.1: MQLA6LP, at = 144.42270502749892;
#
# QLA6LP.1: QLA6LP, at = 144.82270502749893;
#
# BLA6LP.2: BLA6LP, at = 146.86824002749893;
#
# ZDS4LP.1: ZDS4LP, at = 152.29153102073593;
#
# MQLA7LP.1: MQLA7LP, at = 152.91752102073593;
#
# QLA7LP.1: QLA7LP, at = 153.31752102073594;
#
# MQLA8LP.1: MQLA8LP, at = 159.63395058035493;
#
# QLA8LP.1: QLA8LP, at = 160.03395058035494;
#
# QLA9LP.1: QLA9LP, at = 162.64433686659396;
#
# MQLA9LP.1: MQLA9LP, at = 163.04433686659397;
#
# PTSULM.1: PTSULM, at = 163.32233686659396;
#
# SD3TLP.1: SD3TLP, at = 163.48933686659396;
#
# DB2P.1: DB2P, at = 166.30122808084369;
#
# B2P.1: B2P, at = 168.38105508084368;
#
# DB2P.2: DB2P, at = 170.46088208084367;
#
# QF2P.1: QF2P, at = 171.9327975767843;
#
# MQF2P1.1: MQF2P1, at = 172.33279757678432;
#
# MQD1P1.1: MQD1P1, at = 178.42607709872271;
#
# QD1P.1: QD1P, at = 178.82607709872272;
#
# MQF2P2.1: MQF2P2, at = 185.31935662066113;
#
# QF2P.2: QF2P, at = 185.71935662066113;
#
# DB2P.3: DB2P, at = 187.19127211660177;
#
# B2P.2: B2P, at = 189.27109911660176;
#
# DB2P.4: DB2P, at = 191.35092611660176;
#
# SD3TLP.2: SD3TLP, at = 194.16281733085148;
#
# MQD3P2.1: MQD3P2, at = 194.60781733085147;
#
# QD3P.1: QD3P, at = 195.00781733085148;
#
# QF4P.1: QF4P, at = 200.2297216098367;
#
# MQF4P2.1: MQF4P2, at = 200.6297216098367;
#
# SF4TLP.1: SF4TLP, at = 201.0747216098367;
#
# MQEAP3.1: MQEAP3, at = 204.8643915284261;
#
# QEAP.1: QEAP, at = 205.2643915284261;
#
# MQD5P3.1: MQD5P3, at = 209.89906144701553;
#
# QD5P.1: QD5P, at = 210.29906144701553;
#
# DB2P.5: DB2P, at = 211.55057839457686;
#
# B2P.3: B2P, at = 213.63040539457685;
#
# DB2P.6: DB2P, at = 215.71023239457685;
#
# QF6P.1: QF6P, at = 216.89847463089518;
#
# MQF6P2.1: MQF6P2, at = 217.29847463089519;
#
# DB2P.7: DB2P, at = 218.0867168672135;
#
# B2P.4: B2P, at = 220.1665438672135;
#
# DB2P.8: DB2P, at = 222.2463708672135;
#
# QD5P.2: QD5P, at = 223.49788781477483;
#
# MQD5P4.1: MQD5P4, at = 223.89788781477483;
#
# QEAP.2: QEAP, at = 228.53255773336426;
#
# MQEAP4.1: MQEAP4, at = 228.93255773336426;
#
# SF4TLP.2: SF4TLP, at = 232.72222765195366;
#
# MQF4P3.1: MQF4P3, at = 233.16722765195365;
#
# QF4P.2: QF4P, at = 233.56722765195366;
#
# QD3P.2: QD3P, at = 238.78913193093888;
#
# MQD3P3.1: MQD3P3, at = 239.18913193093888;
#
# SD5TLP.1: SD5TLP, at = 239.63413193093888;
#
# DB2P.9: DB2P, at = 242.4460231451886;
#
# B2P.5: B2P, at = 244.5258501451886;
#
# DB2P.10: DB2P, at = 246.6056771451886;
#
# QF2P.3: QF2P, at = 248.07759264112923;
#
# MQF2P3.1: MQF2P3, at = 248.47759264112923;
#
# MQD1P2.1: MQD1P2, at = 254.57087216306763;
#
# QD1P.2: QD1P, at = 254.97087216306764;
#
# MQF2P4.1: MQF2P4, at = 261.4641516850061;
#
# QF2P.4: QF2P, at = 261.86415168500605;
#
# DB2P.11: DB2P, at = 263.33606718094666;
#
# B2P.6: B2P, at = 265.4158941809467;
#
# DB2P.12: DB2P, at = 267.49572118094665;
#
# SD5TLP.2: SD5TLP, at = 270.30761239519643;
#
# MQD3P4.1: MQD3P4, at = 270.7526123951964;
#
# QD3P.3: QD3P, at = 271.1526123951964;
#
# QF4P.3: QF4P, at = 276.37451667418156;
#
# MQF4P4.1: MQF4P4, at = 276.77451667418154;
#
# SF6TLP.1: SF6TLP, at = 277.2195166741816;
#
# MQEAP5.1: MQEAP5, at = 281.009186592771;
#
# QEAP.3: QEAP, at = 281.409186592771;
#
# MQD5P5.1: MQD5P5, at = 286.0438565113604;
#
# QD5P.3: QD5P, at = 286.44385651136037;
#
# DB2P.13: DB2P, at = 287.69537345892167;
#
# B2P.7: B2P, at = 289.77520045892163;
#
# DB2P.14: DB2P, at = 291.85502745892165;
#
# QF6P.2: QF6P, at = 293.04326969524004;
#
# MQF6P3.1: MQF6P3, at = 293.44326969524;
#
# DB2P.15: DB2P, at = 294.2315119315584;
#
# B2P.8: B2P, at = 296.31133893155834;
#
# DB2P.16: DB2P, at = 298.39116593155836;
#
# QD5P.4: QD5P, at = 299.64268287911966;
#
# MQD5P6.1: MQD5P6, at = 300.04268287911964;
#
# QEAP.4: QEAP, at = 304.67735279770903;
#
# MQEAP6.1: MQEAP6, at = 305.077352797709;
#
# SF6TLP.2: SF6TLP, at = 308.8670227162985;
#
# MQF4P5.1: MQF4P5, at = 309.3120227162985;
#
# QF4P.4: QF4P, at = 309.71202271629846;
#
# QD3P.4: QD3P, at = 314.9339269952836;
#
# MQD3P5.1: MQD3P5, at = 315.3339269952836;
#
# SD7TLP.1: SD7TLP, at = 315.77892699528365;
#
# DB2P.17: DB2P, at = 318.5908182095334;
#
# B2P.9: B2P, at = 320.6706452095334;
#
# DB2P.18: DB2P, at = 322.75047220953337;
#
# QF2P.5: QF2P, at = 324.222387705474;
#
# MQF2P5.1: MQF2P5, at = 324.62238770547395;
#
# MQD1P3.1: MQD1P3, at = 330.7156672274124;
#
# QD1P.3: QD1P, at = 331.11566722741236;
#
# MQF2P6.1: MQF2P6, at = 337.6089467493508;
#
# QF2P.6: QF2P, at = 338.0089467493508;
#
# DB2P.19: DB2P, at = 339.4808622452914;
#
# B2P.10: B2P, at = 341.5606892452914;
#
# DB2P.20: DB2P, at = 343.6405162452914;
#
# SD7TLP.2: SD7TLP, at = 346.4524074595412;
#
# MQT1TNP1.1: MQT1TNP1, at = 346.89740745954117;
#
# QT1TNP.1: QT1TNP, at = 347.29740745954115;
#
# QT2TNP.1: QT2TNP, at = 352.2345674009808;
#
# MQT2TNP1.1: MQT2TNP1, at = 352.63456740098076;
#
# SF8TNP.1: SF8TNP, at = 353.07956740098075;
#
# MQTATNP1.1: MQTATNP1, at = 357.0045303380342;
#
# QTATNP.1: QTATNP, at = 357.4045303380342;
#
# MQT3TNP1.1: MQT3TNP1, at = 362.17449327508757;
#
# QT3TNP.1: QT3TNP, at = 362.57449327508755;
#
# DB2P.21: DB2P, at = 364.01744178465617;
#
# B2P.11: B2P, at = 366.0972687846562;
#
# DB2P.22: DB2P, at = 368.17709578465616;
#
# QT4TNP.1: QT4TNP, at = 370.09903568298677;
#
# MQT4TNP1.1: MQT4TNP1, at = 370.49903568298674;
#
# QT5TNP.1: QT5TNP, at = 377.11034364321694;
#
# MQT5TNP.1: MQT5TNP, at = 377.5103436432169;
#
# MQT4TNP2.1: MQT4TNP2, at = 383.7216516034472;
#
# QT4TNP.2: QT4TNP, at = 384.12165160344716;
#
# DB2P.23: DB2P, at = 386.04359150177777;
#
# B2P.12: B2P, at = 388.1234185017778;
#
# DB2P.24: DB2P, at = 390.20324550177776;
#
# QT3TNP.2: QT3TNP, at = 391.6461940113464;
#
# MQT3TNP2.1: MQT3TNP2, at = 392.04619401134636;
#
# QTATNP.2: QTATNP, at = 396.81615694839974;
#
# MQTATNP2.1: MQTATNP2, at = 397.2161569483997;
#
# SF8TNP.2: SF8TNP, at = 401.1411198854531;
#
# MQT2TNP2.1: MQT2TNP2, at = 401.5861198854532;
#
# QT2TNP.2: QT2TNP, at = 401.98611988545315;
#
# QT1TNP.2: QT1TNP, at = 406.9232798268928;
#
# MQT1TNP2.1: MQT1TNP2, at = 407.32327982689276;
#
# SD7NRP.1: SD7NRP, at = 407.7682798268928;
#
# DB2P.25: DB2P, at = 410.58017104114253;
#
# B2P.13: B2P, at = 412.65999804114256;
#
# DB2P.26: DB2P, at = 414.7398250411425;
#
# QF2P.7: QF2P, at = 416.21174053708313;
#
# MQF2P7.1: MQF2P7, at = 416.6117405370831;
#
# MQD1P4.1: MQD1P4, at = 422.70502005902154;
#
# QD1P.4: QD1P, at = 423.1050200590215;
#
# MQF2P8.1: MQF2P8, at = 429.59829958096;
#
# QF2P.8: QF2P, at = 429.99829958095995;
#
# DB2P.27: DB2P, at = 431.47021507690056;
#
# B2P.14: B2P, at = 433.5500420769006;
#
# DB2P.28: DB2P, at = 435.62986907690055;
#
# SD7NRP.2: SD7NRP, at = 438.44176029115033;
#
# MQD3P6.1: MQD3P6, at = 438.8867602911503;
#
# QD3P.5: QD3P, at = 439.2867602911503;
#
# QF4P.5: QF4P, at = 444.50866457013547;
#
# MQF4P6.1: MQF4P6, at = 444.90866457013544;
#
# SF6NRP.1: SF6NRP, at = 445.3536645701355;
#
# MQEAP7.1: MQEAP7, at = 449.1433344887249;
#
# QEAP.5: QEAP, at = 449.5433344887249;
#
# MQD5P7.1: MQD5P7, at = 454.1780044073143;
#
# QD5P.5: QD5P, at = 454.57800440731427;
#
# DB2P.29: DB2P, at = 455.82952135487557;
#
# B2P.15: B2P, at = 457.90934835487553;
#
# DB2P.30: DB2P, at = 459.98917535487556;
#
# QF6P.3: QF6P, at = 461.17741759119394;
#
# MQF6P4.1: MQF6P4, at = 461.5774175911939;
#
# DB2P.31: DB2P, at = 462.3656598275123;
#
# ...
#
# MQW6OLP.1: MQW6OLP, at = 2359.310483536613;
#
# QW6OLP.1: QW6OLP, at = 2359.7104835366126;
#
# MQW7OLP.1: MQW7OLP, at = 2364.02369838614;
#
# QW7OLP.1: QW7OLP, at = 2364.42369838614;
#
# MQW8OLP.1: MQW8OLP, at = 2368.736913235667;
#
# QW8OLP.1: QW8OLP, at = 2369.1369132356667;
#
# POHOLM.1: POHOLM, at = 2371.078667654125;
#
# BS2OP.3: BS2OP, at = 2371.525412654125;
#
# BS2OP.4: BS2OP, at = 2375.040175466872;
#
# QS1OP.2: QS1OP, at = 2376.7714026921203;
#
# MQS1OP2.1: MQS1OP2, at = 2377.17140269212;
#
# MQSBOP2.1: MQSBOP2, at = 2381.2613302526365;
#
# QSBOP.2: QSBOP, at = 2381.6613302526366;
#
# QS2OP.2: QS2OP, at = 2386.551257813152;
#
# MQS2OP2.1: MQS2OP2, at = 2386.9512578131516;
#
# SF2OLP.1: SF2OLP, at = 2387.3962578131514;
#
# MQEAP37.1: MQEAP37, at = 2391.185927731741;
#
# QEAP.35: QEAP, at = 2391.585927731741;
#
# MQD5P37.1: MQD5P37, at = 2396.2205976503305;
#
# QD5P.35: QD5P, at = 2396.6205976503306;
#
# DB2P.153: DB2P, at = 2397.872114597892;
#
# B2P.77: B2P, at = 2399.951941597892;
#
# DB2P.154: DB2P, at = 2402.031768597892;
#
# QF6P.18: QF6P, at = 2403.2200108342104;
#
# MQF6P19.1: MQF6P19, at = 2403.62001083421;
#
# DB2P.155: DB2P, at = 2404.408253070528;
#
# B2P.78: B2P, at = 2406.488080070528;
#
# DB2P.156: DB2P, at = 2408.5679070705282;
#
# QD5P.36: QD5P, at = 2409.8194240180896;
#
# MQD5P38.1: MQD5P38, at = 2410.2194240180897;
#
# QEAP.36: QEAP, at = 2414.8540939366794;
#
# MQEAP38.1: MQEAP38, at = 2415.2540939366795;
#
# SF2OLP.2: SF2OLP, at = 2419.043763855269;
#
# MQF4P31.1: MQF4P31, at = 2419.4887638552686;
#
# QF4P.30: QF4P, at = 2419.8887638552687;
#
# QD3P.30: QD3P, at = 2425.1106681342535;
#
# MQD3P31.1: MQD3P31, at = 2425.5106681342536;
#
# SD3OLP.1: SD3OLP, at = 2425.9556681342533;
#
# DB2P.157: DB2P, at = 2428.767559348503;
#
# B2P.79: B2P, at = 2430.847386348503;
#
# DB2P.158: DB2P, at = 2432.927213348503;
#
# QF2P.37: QF2P, at = 2434.3991288444436;
#
# MQF2P37.1: MQF2P37, at = 2434.7991288444437;
#
# MQD1P19.1: MQD1P19, at = 2440.8924083663824;
#
# QD1P.19: QD1P, at = 2441.292408366382;
#
# MQF2P38.1: MQF2P38, at = 2447.7856878883204;
#
# QF2P.38: QF2P, at = 2448.1856878883204;
#
# DB2P.159: DB2P, at = 2449.657603384261;
#
# B2P.80: B2P, at = 2451.737430384261;
#
# DB2P.160: DB2P, at = 2453.817257384261;
#
# SD3OLP.2: SD3OLP, at = 2456.6291485985107;
#
# MQD3P32.1: MQD3P32, at = 2457.0741485985104;
#
# QD3P.31: QD3P, at = 2457.4741485985105;
#
# QF4P.31: QF4P, at = 2462.6960528774953;
#
# MQF4P32.1: MQF4P32, at = 2463.0960528774954;
#
# SF4OLP.1: SF4OLP, at = 2463.541052877495;
#
# MQEAP39.1: MQEAP39, at = 2467.3307227960845;
#
# QEAP.37: QEAP, at = 2467.7307227960846;
#
# MQD5P39.1: MQD5P39, at = 2472.3653927146743;
#
# QD5P.37: QD5P, at = 2472.7653927146744;
#
# DB2P.161: DB2P, at = 2474.016909662236;
#
# B2P.81: B2P, at = 2476.096736662236;
#
# DB2P.162: DB2P, at = 2478.176563662236;
#
# QF6P.19: QF6P, at = 2479.3648058985536;
#
# MQF6P20.1: MQF6P20, at = 2479.7648058985537;
#
# DB2P.163: DB2P, at = 2480.553048134872;
#
# B2P.82: B2P, at = 2482.632875134872;
#
# DB2P.164: DB2P, at = 2484.712702134872;
#
# QD5P.38: QD5P, at = 2485.9642190824334;
#
# MQD5P40.1: MQD5P40, at = 2486.3642190824335;
#
# QEAP.38: QEAP, at = 2490.998889001023;
#
# MQEAP40.1: MQEAP40, at = 2491.3988890010232;
#
# SF4OLP.2: SF4OLP, at = 2495.1885589196127;
#
# MQF4P33.1: MQF4P33, at = 2495.6335589196124;
#
# QF4P.32: QF4P, at = 2496.0335589196125;
#
# QD3P.32: QD3P, at = 2501.255463198597;
#
# MQD3P33.1: MQD3P33, at = 2501.6554631985973;
#
# SD5OLP.1: SD5OLP, at = 2502.100463198597;
#
# DB2P.165: DB2P, at = 2504.9123544128465;
#
# B2P.83: B2P, at = 2506.9921814128465;
#
# DB2P.166: DB2P, at = 2509.0720084128466;
#
# QF2P.39: QF2P, at = 2510.5439239087873;
#
# MQF2P39.1: MQF2P39, at = 2510.9439239087874;
#
# MQD1P20.1: MQD1P20, at = 2517.037203430726;
#
# QD1P.20: QD1P, at = 2517.437203430726;
#
# MQF2P40.1: MQF2P40, at = 2523.930482952664;
#
# QF2P.40: QF2P, at = 2524.330482952664;
#
# DB2P.167: DB2P, at = 2525.802398448605;
#
# B2P.84: B2P, at = 2527.882225448605;
#
# DB2P.168: DB2P, at = 2529.962052448605;
#
# SD5OLP.2: SD5OLP, at = 2532.7739436628544;
#
# MQD3P34.1: MQD3P34, at = 2533.218943662854;
#
# QD3P.33: QD3P, at = 2533.6189436628542;
#
# QF4P.33: QF4P, at = 2538.840847941839;
#
# MQF4P34.1: MQF4P34, at = 2539.240847941839;
#
# SF6OLP.1: SF6OLP, at = 2539.685847941839;
#
# MQEAP41.1: MQEAP41, at = 2543.475517860428;
#
# QEAP.39: QEAP, at = 2543.8755178604283;
#
# MQD5P41.1: MQD5P41, at = 2548.510187779018;
#
# QD5P.39: QD5P, at = 2548.910187779018;
#
# DB2P.169: DB2P, at = 2550.1617047265795;
#
# B2P.85: B2P, at = 2552.2415317265795;
#
# DB2P.170: DB2P, at = 2554.3213587265795;
#
# QF6P.20: QF6P, at = 2555.509600962898;
#
# MQF6P21.1: MQF6P21, at = 2555.9096009628975;
#
# DB2P.171: DB2P, at = 2556.6978431992156;
#
# B2P.86: B2P, at = 2558.7776701992157;
#
# DB2P.172: DB2P, at = 2560.8574971992157;
#
# QD5P.40: QD5P, at = 2562.109014146777;
#
# MQD5P42.1: MQD5P42, at = 2562.509014146777;
#
# QEAP.40: QEAP, at = 2567.143684065367;
#
# MQEAP42.1: MQEAP42, at = 2567.543684065367;
#
# SF6OLP.2: SF6OLP, at = 2571.3333539839564;
#
# MQF4P35.1: MQF4P35, at = 2571.778353983956;
#
# QF4P.34: QF4P, at = 2572.178353983956;
#
# QD3P.34: QD3P, at = 2577.400258262941;
#
# MQD3P35.1: MQD3P35, at = 2577.800258262941;
#
# SD7OLP.1: SD7OLP, at = 2578.2452582629408;
#
# DB2P.173: DB2P, at = 2581.0571494771903;
#
# B2P.87: B2P, at = 2583.1369764771903;
#
# DB2P.174: DB2P, at = 2585.2168034771903;
#
# QF2P.41: QF2P, at = 2586.688718973131;
#
# MQF2P41.1: MQF2P41, at = 2587.088718973131;
#
# MQD1P21.1: MQD1P21, at = 2593.18199849507;
#
# QD1P.21: QD1P, at = 2593.5819984950695;
#
# MQF2P42.1: MQF2P42, at = 2600.075278017008;
#
# QF2P.42: QF2P, at = 2600.475278017008;
#
# DB2P.175: DB2P, at = 2601.9471935129486;
#
# B2P.88: B2P, at = 2604.0270205129486;
#
# DB2P.176: DB2P, at = 2606.1068475129487;
#
# SD7OLP.2: SD7OLP, at = 2608.918738727198;
#
# MQT1OTP1.1: MQT1OTP1, at = 2609.363738727198;
#
# QT1OTP.1: QT1OTP, at = 2609.763738727198;
#
# QT2OTP.1: QT2OTP, at = 2614.7010248343277;
#
# MQT2OTP1.1: MQT2OTP1, at = 2615.1010248343277;
#
# SF8OTP.1: SF8OTP, at = 2615.5460248343275;
#
# MQTAOTP1.1: MQTAOTP1, at = 2619.6334515970775;
#
# QTAOTP.1: QTAOTP, at = 2620.0334515970776;
#
# MQT3OTP1.1: MQT3OTP1, at = 2624.965878359828;
#
# QT3OTP.1: QT3OTP, at = 2625.365878359828;
#
# DB2P.177: DB2P, at = 2626.483773052309;
#
# B2P.89: B2P, at = 2628.563600052309;
#
# DB2P.178: DB2P, at = 2630.643427052309;
#
# QT4OTP.1: QT4OTP, at = 2632.005621015283;
#
# MQT4OTP1.1: MQT4OTP1, at = 2632.405621015283;
#
# QT5OTP.1: QT5OTP, at = 2639.121039992263;
#
# MQT5OTP.1: MQT5OTP, at = 2639.521039992263;
#
# MQT4OTP2.1: MQT4OTP2, at = 2645.836458969243;
#
# QT4OTP.2: QT4OTP, at = 2646.236458969243;
#
# DB2P.179: DB2P, at = 2647.5986529322167;
#
# B2P.90: B2P, at = 2649.6784799322168;
#
# DB2P.180: DB2P, at = 2651.758306932217;
#
# QT3OTP.2: QT3OTP, at = 2652.876201624698;
#
# MQT3OTP2.1: MQT3OTP2, at = 2653.276201624698;
#
# QTAOTP.2: QTAOTP, at = 2658.2086283874482;
#
# MQTAOTP2.1: MQTAOTP2, at = 2658.6086283874483;
#
# SF8OTP.2: SF8OTP, at = 2662.6960551501984;
#
# MQT2OTP2.1: MQT2OTP2, at = 2663.141055150198;
#
# QT2OTP.2: QT2OTP, at = 2663.541055150198;
#
# QT1OTP.2: QT1OTP, at = 2668.478341257328;
#
# MQT1OTP2.1: MQT1OTP2, at = 2668.878341257328;
#
# SD7TRP.1: SD7TRP, at = 2669.3233412573277;
#
# DB2P.181: DB2P, at = 2672.135232471577;
#
# B2P.91: B2P, at = 2674.215059471577;
#
# DB2P.182: DB2P, at = 2676.2948864715772;
#
# QF2P.43: QF2P, at = 2677.766801967518;
#
# MQF2P43.1: MQF2P43, at = 2678.166801967518;
#
# MQD1P22.1: MQD1P22, at = 2684.2600814894568;
#
# QD1P.22: QD1P, at = 2684.6600814894564;
#
# MQF2P44.1: MQF2P44, at = 2691.1533610113947;
#
# QF2P.44: QF2P, at = 2691.553361011395;
#
# DB2P.183: DB2P, at = 2693.0252765073355;
#
# B2P.92: B2P, at = 2695.1051035073356;
#
# DB2P.184: DB2P, at = 2697.1849305073356;
#
# SD7TRP.2: SD7TRP, at = 2699.996821721585;
#
# MQD3P36.1: MQD3P36, at = 2700.441821721585;
#
# QD3P.35: QD3P, at = 2700.841821721585;
#
# QF4P.35: QF4P, at = 2706.0637260005697;
#
# MQF4P36.1: MQF4P36, at = 2706.4637260005697;
#
# SF6TRP.1: SF6TRP, at = 2706.9087260005695;
#
# MQEAP43.1: MQEAP43, at = 2710.698395919159;
#
# QEAP.41: QEAP, at = 2711.098395919159;
#
# MQD5P43.1: MQD5P43, at = 2715.733065837748;
#
# QD5P.41: QD5P, at = 2716.1330658377483;
#
# DB2P.185: DB2P, at = 2717.3845827853097;
#
# B2P.93: B2P, at = 2719.4644097853097;
#
# DB2P.186: DB2P, at = 2721.5442367853097;
#
# QF6P.21: QF6P, at = 2722.732479021628;
#
# MQF6P22.1: MQF6P22, at = 2723.1324790216277;
#
# DB2P.187: DB2P, at = 2723.920721257946;
#
# B2P.94: B2P, at = 2726.000548257946;
#
# DB2P.188: DB2P, at = 2728.080375257946;
#
# QD5P.42: QD5P, at = 2729.3318922055073;
#
# MQD5P44.1: MQD5P44, at = 2729.7318922055074;
#
# QEAP.42: QEAP, at = 2734.366562124097;
#
# MQEAP44.1: MQEAP44, at = 2734.766562124097;
#
# SF6TRP.2: SF6TRP, at = 2738.5562320426866;
#
# MQF4P37.1: MQF4P37, at = 2739.0012320426863;
#
# QF4P.36: QF4P, at = 2739.4012320426864;
#
# QD3P.36: QD3P, at = 2744.623136321671;
#
# MQD3P37.1: MQD3P37, at = 2745.0231363216712;
#
# SD5TRP.1: SD5TRP, at = 2745.468136321671;
#
# DB2P.189: DB2P, at = 2748.2800275359205;
#
# B2P.95: B2P, at = 2750.3598545359205;
#
# DB2P.190: DB2P, at = 2752.4396815359205;
#
# QF2P.45: QF2P, at = 2753.911597031861;
#
# MQF2P45.1: MQF2P45, at = 2754.3115970318613;
#
# MQD1P23.1: MQD1P23, at = 2760.4048765538;
#
# QD1P.23: QD1P, at = 2760.8048765537997;
#
# MQF2P46.1: MQF2P46, at = 2767.298156075738;
#
# QF2P.46: QF2P, at = 2767.698156075738;
#
# DB2P.191: DB2P, at = 2769.170071571679;
#
# B2P.96: B2P, at = 2771.249898571679;
#
# DB2P.192: DB2P, at = 2773.329725571679;
#
# SD5TRP.2: SD5TRP, at = 2776.1416167859284;
#
# MQD3P38.1: MQD3P38, at = 2776.586616785928;
#
# QD3P.37: QD3P, at = 2776.986616785928;
#
# QF4P.37: QF4P, at = 2782.208521064913;
#
# MQF4P38.1: MQF4P38, at = 2782.608521064913;
#
# SF4TRP.1: SF4TRP, at = 2783.0535210649127;
#
# MQEAP45.1: MQEAP45, at = 2786.843190983502;
#
# QEAP.43: QEAP, at = 2787.2431909835022;
#
# MQD5P45.1: MQD5P45, at = 2791.8778609020915;
#
# QD5P.43: QD5P, at = 2792.2778609020916;
#
# DB2P.193: DB2P, at = 2793.529377849653;
#
# B2P.97: B2P, at = 2795.609204849653;
#
# DB2P.194: DB2P, at = 2797.689031849653;
#
# QF6P.22: QF6P, at = 2798.8772740859713;
#
# MQF6P23.1: MQF6P23, at = 2799.277274085971;
#
# DB2P.195: DB2P, at = 2800.065516322289;
#
# B2P.98: B2P, at = 2802.145343322289;
#
# DB2P.196: DB2P, at = 2804.225170322289;
#
# QD5P.44: QD5P, at = 2805.4766872698506;
#
# MQD5P46.1: MQD5P46, at = 2805.8766872698507;
#
# QEAP.44: QEAP, at = 2810.5113571884403;
#
# MQEAP46.1: MQEAP46, at = 2810.9113571884404;
#
# SF4TRP.2: SF4TRP, at = 2814.70102710703;
#
# MQF4P39.1: MQF4P39, at = 2815.1460271070296;
#
# QF4P.38: QF4P, at = 2815.5460271070297;
#
# QD3P.38: QD3P, at = 2820.7679313860144;
#
# MQD3P39.1: MQD3P39, at = 2821.1679313860145;
#
# SD3TRP.1: SD3TRP, at = 2821.612931386014;
#
# DB2P.197: DB2P, at = 2824.4248226002637;
#
# B2P.99: B2P, at = 2826.5046496002637;
#
# DB2P.198: DB2P, at = 2828.5844766002638;
#
# QF2P.47: QF2P, at = 2830.0563920962045;
#
# MQF2P47.1: MQF2P47, at = 2830.4563920962046;
#
# MQD1P24.1: MQD1P24, at = 2836.5496716181433;
#
# QD1P.24: QD1P, at = 2836.949671618143;
#
# MQF2P48.1: MQF2P48, at = 2843.4429511400813;
#
# QF2P.48: QF2P, at = 2843.8429511400814;
#
# DB2P.199: DB2P, at = 2845.314866636022;
#
# B2P.100: B2P, at = 2847.394693636022;
#
# DB2P.200: DB2P, at = 2849.474520636022;
#
# SD3TRP.2: SD3TRP, at = 2852.2864118502716;
#
# PTSURM.1: PTSURM, at = 2852.4534118502716;
#
# MQLA9RP.1: MQLA9RP, at = 2852.7314118502713;
#
# QLA9RP.1: QLA9RP, at = 2853.1314118502714;
#
# MQLA8RP.1: MQLA8RP, at = 2857.729881317297;
#
# QLA8RP.1: QLA8RP, at = 2858.129881317297;
#
# ZDS4RP.1: ZDS4RP, at = 2866.3987022517517;
#
# MQLA7RP.1: MQLA7RP, at = 2867.023952251752;
#
# QLA7RP.1: QLA7RP, at = 2867.423952251752;
#
# BLA6RP.1: BLA6RP, at = 2876.1389151426124;
#
# MQLA6RP.1: MQLA6RP, at = 2878.664106570156;
#
# QLA6RP.1: QLA6RP, at = 2879.0641065701557;
#
# BLA6RP.2: BLA6RP, at = 2881.9892979976994;
#
# QLA5RP.1: QLA5RP, at = 2885.382030342661;
#
# MQLA5RP.1: MQLA5RP, at = 2885.7820303426606;
#
# QLA4RP.1: QLA4RP, at = 2887.6185109446233;
#
# MQLA4RP.1: MQLA4RP, at = 2888.0185109446234;
#
# QLA3RP.1: QLA3RP, at = 2891.1886088360816;
#
# MQLA3RP.1: MQLA3RP, at = 2891.6386088360814;
#
# BLA2RP.1: BLA2RP, at = 2897.531354023773;
#
# QLA2RP.1: QLA2RP, at = 2899.93248009732;
#
# MQLA2RP.1: MQLA2RP, at = 2900.38248009732;
#
# SLXTRP.1: SLXTRP, at = 2900.79134009732;
#
# BLX2RP.1: BLX2RP, at = 2902.6534850973194;
#
# MQLX1RP1.1: MQLX1RP1, at = 2905.5336894710936;
#
# QLX1RP.1: QLX1RP, at = 2905.9836894710934;
#
# BLX4RP.1: BLX4RP, at = 2908.850350381725;
#
# MQLX2RP.1: MQLX2RP, at = 2911.3870112923564;
#
# QLX2RP.1: QLX2RP, at = 2911.8370112923567;
#
# BLX4RP.2: BLX4RP, at = 2914.823672202988;
#
# QLX1RP.2: QLX1RP, at = 2917.690333113619;
#
# MQLX1RP2.1: MQLX1RP2, at = 2918.1403331136194;
#
# BLX2RP.2: BLX2RP, at = 2921.020537487393;
#
# SLXTRP.2: SLXTRP, at = 2922.882682487393;
#
# MQLB4RP.1: MQLB4RP, at = 2923.291542487393;
#
# QLB4RP.1: QLB4RP, at = 2923.7415424873934;
#
# BLB3RP.1: BLB3RP, at = 2926.828178093899;
#
# QLB3RP.1: QLB3RP, at = 2935.6529930373117;
#
# MQLB3RP.1: MQLB3RP, at = 2936.1029930373115;
#
# ZDS3RP.1: ZDS3RP, at = 2937.0649330373117;
#
# QLB2RP.1: QLB2RP, at = 2949.0279954879115;
#
# MQLB2RP.1: MQLB2RP, at = 2949.477995487912;
#
# BLB2RP.1: BLB2RP, at = 2952.7734025445934;
#
# QLB1RP.1: QLB1RP, at = 2955.080407544593;
#
# MQLB1RP.1: MQLB1RP, at = 2955.5304075445933;
#
# SLYTRP1.1: SLYTRP1, at = 2955.9392675445933;
#
# BLY2RP.1: BLY2RP, at = 2958.784044395686;
#
# BLY3RP.1: BLY3RP, at = 2964.021210026077;
#
# MQLY2RP1.1: MQLY2RP1, at = 2965.6782150260765;
#
# QLY2RP.1: QLY2RP, at = 2966.1282150260768;
#
# BLY5RP.1: BLY5RP, at = 2969.094852364445;
#
# MQLY1RP.1: MQLY1RP, at = 2971.9314897028135;
#
# QLY1RP.1: QLY1RP, at = 2972.3814897028133;
#
# BLY5RP.2: BLY5RP, at = 2975.668127041182;
#
# QLY2RP.2: QLY2RP, at = 2978.6347643795507;
#
# MQLY2RP2.1: MQLY2RP2, at = 2979.0847643795505;
#
# BLY3RP.2: BLY3RP, at = 2980.7417693795505;
#
# BLY2RP.2: BLY2RP, at = 2985.978935009941;
#
# SLYTRP2.1: SLYTRP2, at = 2988.8237118610336;
#
# MQLC3RP.1: MQLC3RP, at = 2989.2325718610336;
#
# QLC3RP.1: QLC3RP, at = 2989.6825718610335;
#
# QKERP.1: QKERP, at = 2990.8313018610334;
#
# BLC2RP.1: BLC2RP, at = 2993.6629487980313;
#
# QKDRP.1: QKDRP, at = 2996.494595735029;
#
# MQLC2RP.1: MQLC2RP, at = 2996.793325735029;
#
# QLC2RP.1: QLC2RP, at = 2997.2433257350294;
#
# ZDS2RP.1: ZDS2RP, at = 2998.633135735029;
#
# QKCRP.1: QKCRP, at = 3002.2660127647378;
#
# MQLC1RP.1: MQLC1RP, at = 3002.574742764738;
#
# QLC1RP.1: QLC1RP, at = 3003.024742764738;
#
# ZDS1RP.1: ZDS1RP, at = 3004.6309055060233;
#
# QKBRP.1: QKBRP, at = 3005.0709055060233;
#
# BLC1RP.1: BLC1RP, at = 3006.922920341952;
#
# BLCWRP.1: BLCWRP, at = 3009.653210130682;
#
# QKARP.1: QKARP, at = 3011.505225099859;
#
# QC2RP.1: QC2RP, at = 3014.38149898794;
#
# QC1RP.1: QC1RP, at = 3015.37149898794;
#
# IP.2: IP, at = 3016.30649898794;
#
# ENDSEQUENCE;
#
# enter Twiss module
#
# iteration:   1 error:   0.000000E+00 deltap:   0.000000E+00
# orbit:   0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00
# ++++++ warning: TWCLORB:  Longitudinal plane might be unstable. Try change lag with 0.5. More information with the debug flag on.
#
# ++++++ table: summ
#
#              length              orbit5                alfa             gammatr
# 3016.306498987930354  -0.000000000000000   0.000305013343944  57.258580895405196
#
#                  q1                 dq1             betxmax               dxmax
#  44.614015065617743  -0.810436798308697 182.019325460169370   0.970023389365029
#
#               dxrms              xcomax              xcorms                  q2
#   0.402017183100334   0.000000000000000   0.000000000000000  46.255128097788770
#
#                 dq2             betymax               dymax               dyrms
#  -1.738218141636092 619.997937779290851   0.039818969674052   0.001799155613476
#
#              ycomax              ycorms              deltap             synch_1
#   0.000000000000000   0.000000000000000   0.000000000000000   0.000000000000000
#
#             synch_2             synch_3             synch_4             synch_5
#   0.000000000000000   0.000000000000000   0.000000000000000   0.000000000000000
#
#             synch_6             synch_8              nflips               dqmin
#   0.000000000000000   0.000000000000000   0.000000000000000   0.000000000002277
#
#         dqmin_phase
#   1.196615477936018
# Converting sequence "asc":   0%|          | 0/2629 [00:00<?, ?it/s]
# Line Built from MADX Sequence

# %% [markdown]
# ## Load HER

# %%
mad = Madx(
    stdout=sys.stdout # Needs to be set to sys.stdout or breaks
)
print("MADX Spawned")
mad.input(
f"""
    SET, FORMAT="19.15f";
    # !option, echo;
    option, update_from_parent=true; // new option in mad-x as of 2/2019

    BEAM, PARTICLE=POSITRON, ENERGY={her_params['energy']};

    CALL, FILE="{her_path}";

    USE, SEQUENCE=ASCE;
    
    SXT_ON = 1;
    RF_ON =1;
        
    USE,SEQUENCE=ASCE;
        TWISS;

"""
)
her = xt.Line.from_madx_sequence(
        mad.sequence['ASCE'],
        allow_thick=True,
        deferred_expressions=True,
    )
print("Line Built from MADX Sequence")
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.01  (64 bit, Darwin)      +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2023.12.04               +
#   + Execution date: 2024.05.13 20:59:17      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# MADX Spawned
# !
#
# !SAD2MADX V0.4.1 (11/5/2018)
#
# !Conversion of seq_her at Mon Apr 29 11:29:08 CEST 2024
#
# !
#
# AXISAD =-3.151932671210428e-11; BXISAD =.06000000000139228; AYISAD =-7.403821733277181e-11; BYISAD =.000999999999964614; EXISAD =6.162622182789366e-14; EPXISAD =5.19956330537099e-13; EYISAD =-8.409904814971869e-19; EPYISAD =3.9923543874263796e-14;
#
# K1QC1LPE = -.1575705826913016;
#
# LQC1LPE = .34;
#
# K1QC1LE = -3.038483975272519;
#
# LQC1LE = .38;
#
# K1QC2LE = 1.2128090028407266;
#
# LQC2LE = .54;
#
# LQKALE = .3444;
#
# K1QLC2LE = .0288552353674626;
#
# LQLC2LE = .53815;
#
# LQKBLE = .3444;
#
# ANGLEBLC1LE = -.005910469661515972;
#
# LBLC1LE = 3.6026247561264007;
#
# LQKCLE = .3444;
#
# K1QLC3LE = -.3081750281243421;
#
# LQLC3LE = .57004;
#
# K1QLC4LE = .13134094607571398;
#
# LQLC4LE = .57004;
#
# K1QLC5LE = -.17648021963195565;
#
# LQLC5LE = .57004;
#
# K1QLC7LE = -.08551711613044699;
#
# LQLC7LE = .57004;
#
# K2SLYTLE1 = 13.350911191758067;
#
# LSLYTLE1 = .6;
#
# K1QLY1LE = -.22468440665768794;
#
# LQLY1LE = .46227;
#
# K1QLY2LE = .37519376485527367;
#
# LQLY2LE = .57004;
#
# ANGLEBLY1LE = -.0270414185419;
#
# LBLY1LE = 3.9613083032418177;
#
# K1QLY3LE = -.3911768075511214;
#
# LQLY3LE = .57004;
#
# K2SLYTLE2 = 13.350911191758067;
#
# LSLYTLE2 = .6;
#
# K1QLB1LE = -.26941881375517507;
#
# LQLB1LE = .57004;
#
# K1QLB2LE = .43107930057364396;
#
# LQLB2LE = .57004;
#
# ANGLEBLB1LE = -.0229995677161288;
#
# LBLB1LE = 3.9613416873619807;
#
# K1QLB3LE = -.5331409292072025;
#
# LQLB3LE = 1.12349;
#
# K1QLB4LE = .4288633498298365;
#
# LQLB4LE = .57004;
#
# K2SLXTLE = 1.5552840634538205;
#
# LSLXTLE = .5;
#
# K1QLX1LE = -.538555754275921;
#
# LQLX1LE = .57004;
#
# ANGLEBLX2LE = .025928122149540763;
#
# LBLX2LE = 3.9613180367640344;
#
# K1QLX2LE = .4610195376265334;
#
# LQLX2LE = .57004;
#
# K1QLA2LE = .4931329028506771;
#
# LQLA2LE = .57004;
#
# K1QLA3LE = -.5091553924549155;
#
# LQLA3LE = .57004;
#
# K1QLA4LE = .5094431613569851;
#
# LQLA4LE = .55697;
#
# ANGLEBLA2LE = .02064206401238084;
#
# LBLA2LE = 5.902097213157272;
#
# K1QLA5LE = -.1726094081667978;
#
# LQLA5LE = .82615;
#
# K1QLA6LE = .2410810379035284;
#
# LQLA6LE = .82615;
#
# K1QLA7LE = -.2028106790268111;
#
# LQLA7LE = .82615;
#
# ANGLEBLA4LE = .06636583607087398;
#
# LBLA4LE = 5.9011189012442715;
#
# K1QLA8LE = .5495788895533648;
#
# LQLA8LE = .57004;
#
# K1QLA9LE = -.22762517540277188;
#
# LQLA9LE = .82615;
#
# K1QLA10LE = .23215745083338377;
#
# LQLA10LE = .82615;
#
# K1QF4E = .03442520389557341;
#
# LQF4E = 1.01523;
#
# K1QD3E = -.21167755864546642;
#
# LQD3E = .82615;
#
# K2SD3TLE = -7.561089682353109;
#
# LSD3TLE = 1.03;
#
# ANGLEB2E = .055742725957;
#
# LB2E = 5.901437878596205;
#
# K1QF2E = .3444179569224356;
#
# LQF2E = .55697;
#
# K1QD1E = -.2510277681068766;
#
# LQD1E = 1.01523;
#
# LSKBTLE = .3444;
#
# TILTSKBTLE = .5235987755982988;
#
# K2SF4TLE = 2.76275039017891;
#
# LSF4TLE = .334;
#
# K1QEAE = .22152058054151483;
#
# LQEAE = .82615;
#
# K1QD5E = -.21708612419240964;
#
# LQD5E = .82615;
#
# K1QF6E = .29325698810308315;
#
# LQF6E = .55697;
#
# K2SD5TLE = -1.361815946035056;
#
# LSD5TLE = 1.03;
#
# LSKCTLE = .3444;
#
# TILTSKCTLE = .5235987755982988;
#
# K2SF6TLE = 4.644241478543322;
#
# LSF6TLE = .334;
#
# K2SD7TLE = -8.943927183315347;
#
# LSD7TLE = 1.03;
#
# K1QT1TNE = -.04427480818934475;
#
# LQT1TNE = .82615;
#
# K1QT2TNE = -.14506099883213353;
#
# LQT2TNE = 1.01523;
#
# K2SF8TNE = 12.3336574720534;
#
# LSF8TNE = .334;
#
# K1QTATNE = .2755547272696145;
#
# LQTATNE = .82615;
#
# K1QT3TNE = -.13310360368168722;
#
# LQT3TNE = .82615;
#
# K1QT4TNE = -.055939392929909855;
#
# LQT4TNE = .82615;
#
# K1QTBTNE = .1844499760938607;
#
# LQTBTNE = .81735;
#
# K1QT5TNE = -.22166584410358636;
#
# LQT5TNE = .82615;
#
# K2SD7NRE = -.28069670850808554;
#
# LSD7NRE = 1.03;
#
# LSKCNRE = .3444;
#
# TILTSKCNRE = .5235987755982988;
#
# K2SF6NRE = 4.530054447178103;
#
# LSF6NRE = .334;
#
# K2SD5NRE = -.22688740587690734;
#
# LSD5NRE = 1.03;
#
# LSKBNRE = .3444;
#
# TILTSKBNRE = .5235987755982988;
#
# K2SF4NRE = 13.91077261476252;
#
# LSF4NRE = .334;
#
# K2SD3NRE = -4.332548205259363;
#
# LSD3NRE = 1.03;
#
# K2SF2NRE = 6.165593048458047;
#
# LSF2NRE = .334;
#
# K1QS4NE = .08783606674100737;
#
# LQS4NE = .82615;
#
# K1QSBNE = -.3090504655845013;
#
# LQSBNE = .82615;
#
# K1QS3NE = .21260957365166405;
#
# LQS3NE = .82615;
#
# K1QS2NE = .2573671001799734;
#
# LQS2NE = .55697;
#
# ANGLEBSWNRE = .005;
#
# LBSWNRE = 2.899996961465029;
#
# K1QR7NE = -.2519151255579341;
#
# LQR7NE = .82615;
#
# K1QR6NE = .19640691707989166;
#
# LQR6NE = 1.01523;
#
# K1QR5NE = -.11022987389108567;
#
# LQR5NE = 1.07992;
#
# K1QR4NE = .14391883628791483;
#
# LQR4NE = 1.07992;
#
# K1QR3NE = -.14461168409324165;
#
# LQR3NE = 1.07992;
#
# FREQCADNRE = 508.87839543246093;
#
# VOLTCADNRE = 1.2678571428571428;
#
# K1QR2NE = .1100596900322149;
#
# LQR2NE = 1.07992;
#
# FREQCACNRE = 508.87839543246093;
#
# VOLTCACNRE = 1.2678571428571428;
#
# K1QDRNE = -.11754528708316152;
#
# LQDRNE = 1.07992;
#
# FREQCABNRE = 508.87839543246093;
#
# VOLTCABNRE = 1.2678571428571428;
#
# K1QFRNE = .12173695001496825;
#
# LQFRNE = 1.07992;
#
# FREQCAANRE = 508.87839543246093;
#
# VOLTCAANRE = 1.2678571428571428;
#
# FREQCAANLE = 508.87839543246093;
#
# VOLTCAANLE = 1.2678571428571428;
#
# FREQCABNLE = 508.87839543246093;
#
# VOLTCABNLE = 1.2678571428571428;
#
# FREQCACNLE = 508.87839543246093;
#
# VOLTCACNLE = 1.2678571428571428;
#
# FREQCADNLE = 508.87839543246093;
#
# VOLTCADNLE = 1.2678571428571428;
#
# ANGLEBSWNLE = .005;
#
# LBSWNLE = 2.899996961465029;
#
# K2SF2NLE = 1.5179605159386407;
#
# LSF2NLE = .334;
#
# K2SD3NLE = -5.022073861737154;
#
# LSD3NLE = 1.03;
#
# LSKBNLE = .3444;
#
# TILTSKBNLE = .5235987755982988;
#
# K2SF4NLE = 1.8148201950613545;
#
# LSF4NLE = .334;
#
# K2SD5NLE = -4.597167307486429;
#
# LSD5NLE = 1.03;
#
# LSKCNLE = .3444;
#
# TILTSKCNLE = .5235987755982988;
#
# K2SF6NLE = .5497633925034361;
#
# LSF6NLE = .334;
#
# K2SD7NLE = -5.269911718310307;
#
# LSD7NLE = 1.03;
#
# K1QT1NFE = -.04427480818934475;
#
# LQT1NFE = .82615;
#
# K1QT2NFE = -.14506099883213353;
#
# LQT2NFE = 1.01523;
#
# K2SF8NFE = .26462904961001393;
#
# LSF8NFE = .334;
#
# K1QTANFE = .2755547272696145;
#
# LQTANFE = .82615;
#
# K1QT3NFE = -.13310360368168722;
#
# LQT3NFE = .82615;
#
# K1QT4NFE = -.055939392929909855;
#
# LQT4NFE = .82615;
#
# K1QTBNFE = .1844499760938607;
#
# LQTBNFE = .81735;
#
# K1QT5NFE = -.22166584410358636;
#
# LQT5NFE = .82615;
#
# K2SD7FRE = -4.799218318760189;
#
# LSD7FRE = 1.03;
#
# LSKCFRE = .3444;
#
# TILTSKCFRE = .5235987755982988;
#
# K2SF6FRE = 6.522202985581662;
#
# LSF6FRE = .334;
#
# K2SD5FRE = -3.897880257478182;
#
# LSD5FRE = 1.03;
#
# LSKBFRE = .3444;
#
# TILTSKBFRE = .5235987755982988;
#
# K2SF4FRE = 2.446915774539994;
#
# LSF4FRE = .334;
#
# K2SD3FRE = -.225104667012057;
#
# LSD3FRE = 1.03;
#
# K2SF2FRE = 7.800120255973837;
#
# LSF2FRE = .334;
#
# K1QS4FRE = -.12687510478057498;
#
# LQS4FRE = .82615;
#
# K1QSBFRE = .25399158681913037;
#
# LQSBFRE = .82615;
#
# K1QS3FRE = -.24004551224390774;
#
# LQS3FRE = .82615;
#
# K1QS2FRE = .489429222390013;
#
# LQS2FRE = .55697;
#
# ANGLEBSWFRE = .0085;
#
# LBSWFRE = .8914973162159654;
#
# K1QI7E = -.17219096304930928;
#
# LQI7E = 1.01523;
#
# K1QI6E = .08940341008868562;
#
# LQI6E = 1.01523;
#
# K1QI5E = -.09560283250513796;
#
# LQI5E = 1.01523;
#
# K1QI4E = .18134607428676905;
#
# LQI4E = .82615;
#
# K1QI3E = -.14034496041355324;
#
# LQI3E = 1.01523;
#
# K1QI2E = .23608100280964425;
#
# LQI2E = 1.01523;
#
# K1QX7RE = -.19418624770049028;
#
# LQX7RE = 1.07992;
#
# K1QX6RE = .1850290139818765;
#
# LQX6RE = 1.01523;
#
# K2SXABE = -12.917849292149173;
#
# LSXABE = .334;
#
# K1QX5RE = -.17589612642248412;
#
# LQX5RE = 1.01523;
#
# K1QX4RE = .19124395650839826;
#
# LQX4RE = 1.01523;
#
# ANGLEBX2E = -.0478825274504;
#
# LBX2E = 5.901638174760177;
#
# K1QX3RE = -.26316682729937135;
#
# LQX3RE = 1.01523;
#
# K1QX2RE = .37072539769871654;
#
# LQX2RE = .8168;
#
# K1QX2LE = .37072539769871665;
#
# LQX2LE = .8168;
#
# K1QX3LE = -.26316682729937174;
#
# LQX3LE = 1.01523;
#
# ANGLEBX1E = .0478825274504;
#
# LBX1E = 5.901638174760177;
#
# K1QX4LE = .20026683226156936;
#
# LQX4LE = 1.01523;
#
# K1QX5LE = -.17882889844887181;
#
# LQX5LE = 1.01523;
#
# LFZLFBKE2 = 1.56;
#
# LFZLFBKE1 = 1.56;
#
# K1QX6LE = .12966222706344288;
#
# LQX6LE = 1.01523;
#
# K1QX7LE = -.11292473199288729;
#
# LQX7LE = 1.01523;
#
# K1QM2E = .1137386133261201;
#
# LQM2E = 1.01523;
#
# K1QM3E = -.1431884354290174;
#
# LQM3E = 1.01523;
#
# LFZTFBKE2 = .55;
#
# LFZTFBKE1 = .55;
#
# K1QM4E = .19200089661287242;
#
# LQM4E = 1.01523;
#
# K1QM5E = -.21874468126557522;
#
# LQM5E = 1.01523;
#
# K1QM6E = .19027685286700538;
#
# LQM6E = 1.01523;
#
# K1QM7E = -.19376057506808603;
#
# LQM7E = 1.01523;
#
# ANGLEBSWFLE = .0015;
#
# LBSWFLE = 1.2389997640976644;
#
# K1QS2FLE = .46767745438230107;
#
# LQS2FLE = .55697;
#
# K1QS3FLE = -.19679778177055968;
#
# LQS3FLE = .82615;
#
# K1QSBFLE = .2357875488207664;
#
# LQSBFLE = .82615;
#
# K1QS4FLE = -.1792147870477623;
#
# LQS4FLE = .82615;
#
# K2SF2FLE = 6.865770759886453;
#
# LSF2FLE = .334;
#
# K2SD3FLE = -2.5149670455015607;
#
# LSD3FLE = 1.03;
#
# LSKBFLE = .3444;
#
# TILTSKBFLE = .5235987755982988;
#
# K2SF4FLE = 2.1969308341249016;
#
# LSF4FLE = .334;
#
# K2SD5FLE = -4.625933666592048;
#
# LSD5FLE = 1.03;
#
# LSKCFLE = .3444;
#
# TILTSKCFLE = .5235987755982988;
#
# K2SF6FLE = 8.952288883079989;
#
# LSF6FLE = .334;
#
# K2SD7FLE = -13.089750674081271;
#
# LSD7FLE = 1.03;
#
# K1QT1FOE = -.10078113935724653;
#
# LQT1FOE = .82615;
#
# K1QT2FOE = -.08620657016339625;
#
# LQT2FOE = 1.01523;
#
# K2SF8FOE = 12.136669104627424;
#
# LSF8FOE = .334;
#
# K1QTAFOE = .26160853614944957;
#
# LQTAFOE = .82615;
#
# K1QT3FOE = -.15689486818594509;
#
# LQT3FOE = .82615;
#
# K1QT4FOE = -.03361380446949256;
#
# LQT4FOE = .82615;
#
# K1QTBFOE = .16948276564528783;
#
# LQTBFOE = .81735;
#
# K1QT5FOE = -.21242593453842573;
#
# LQT5FOE = .82615;
#
# K2SD7ORE = -13.080455176187336;
#
# LSD7ORE = 1.03;
#
# K2SF6ORE = 1.6338193514982213;
#
# LSF6ORE = .334;
#
# K2SD5ORE = -3.7062291875805915;
#
# LSD5ORE = 1.03;
#
# K2SF4ORE = 11.940610548348442;
#
# LSF4ORE = .334;
#
# K2SD3ORE = -11.822677185790496;
#
# LSD3ORE = 1.03;
#
# K2SF2ORE = 3.551548902976283;
#
# LSF2ORE = .334;
#
# K1QS4OE = -.13151496309566368;
#
# LQS4OE = .82615;
#
# K1QSBOE = .20734948863075692;
#
# LQSBOE = .82615;
#
# K1QS3ORE = -.14922514987686414;
#
# LQS3ORE = .8168;
#
# ANGLEBS2ORE = .0278713629785;
#
# LBS2ORE = 2.2304878037125055;
#
# K1QS2ORE = .16669494011732364;
#
# LQS2ORE = .55697;
#
# ANGLEBSWORE = .005;
#
# LBSWORE = 2.899996961465029;
#
# K1QR7ORE = -.15120215457449293;
#
# LQR7ORE = .82615;
#
# K1QR6ORE = .13483558157933836;
#
# LQR6ORE = 1.01523;
#
# K1QR5ORE = -.2755826879511202;
#
# LQR5ORE = .46078;
#
# K1QR4ORE = .2839071220769797;
#
# LQR4ORE = .46078;
#
# K1QR3ORE = -.4434020801376016;
#
# LQR3ORE = .46078;
#
# K1QR2ORE = .39080354244244264;
#
# LQR2ORE = .46078;
#
# K1QDWOE = -.33898130123473685;
#
# LQDWOE = .46078;
#
# K1QFWOE = .3460217773467293;
#
# LQFWOE = .46078;
#
# K1QFROE = .13718257895818298;
#
# LQFROE = 1.07992;
#
# K1QDROE = -.15590249090434083;
#
# LQDROE = 1.07992;
#
# FREQCAAOLE = 508.87839543246093;
#
# VOLTCAAOLE = .5071428571428571;
#
# FREQCABOLE = 508.87839543246093;
#
# VOLTCABOLE = .5071428571428571;
#
# FREQCACOLE = 508.87839543246093;
#
# VOLTCACOLE = .5071428571428571;
#
# FREQCADOLE = 508.87839543246093;
#
# VOLTCADOLE = .5071428571428571;
#
# FREQCAEOLE = 508.87839543246093;
#
# VOLTCAEOLE = .5071428571428571;
#
# FREQCAFOLE = 508.87839543246093;
#
# VOLTCAFOLE = .5071428571428571;
#
# K1QR2OLE = .1661247229338364;
#
# LQR2OLE = 1.07992;
#
# FREQCAGOLE = 508.87839543246093;
#
# VOLTCAGOLE = .5071428571428571;
#
# FREQCAHOLE = 508.87839543246093;
#
# VOLTCAHOLE = .5071428571428571;
#
# K1QR3OLE = -.18826175357588973;
#
# LQR3OLE = 1.07992;
#
# K1QR4OLE = .18773213688360724;
#
# LQR4OLE = 1.07992;
#
# K1QR5OLE = -.12104372925777322;
#
# LQR5OLE = 1.07992;
#
# K1QR6OLE = .20457668591882458;
#
# LQR6OLE = 1.01523;
#
# K1QR7OLE = -.19149607382992656;
#
# LQR7OLE = .82615;
#
# ANGLEBSWOLE = .005;
#
# LBSWOLE = 2.899996961465029;
#
# K1QS2OLE = .16622003033738622;
#
# LQS2OLE = .55697;
#
# K1QS3OLE = -.149162827300915;
#
# LQS3OLE = .8168;
#
# K2SF2OLE = 13.695119396216997;
#
# LSF2OLE = .334;
#
# K2SD3OLE = -.33731721053182584;
#
# LSD3OLE = 1.03;
#
# K2SF4OLE = .9869913597677857;
#
# LSF4OLE = .334;
#
# K2SD5OLE = -1.6458581106967125;
#
# LSD5OLE = 1.03;
#
# K2SF6OLE = 1.1163083968916845;
#
# LSF6OLE = .334;
#
# K2SD7OLE = -5.201344668086793;
#
# LSD7OLE = 1.03;
#
# K1QT1OTE = -.10078113935724653;
#
# LQT1OTE = .82615;
#
# K1QT2OTE = -.08620657016339625;
#
# LQT2OTE = 1.01523;
#
# K2SF8OTE = 3.3392518163532854;
#
# LSF8OTE = .334;
#
# K1QTAOTE = .26160853614944957;
#
# LQTAOTE = .82615;
#
# K1QT3OTE = -.15689486818594509;
#
# LQT3OTE = .82615;
#
# K1QT4OTE = -.03361380446949256;
#
# LQT4OTE = .82615;
#
# K1QTBOTE = .16948276564528783;
#
# LQTBOTE = .81735;
#
# K1QT5OTE = -.21242593453842573;
#
# LQT5OTE = .82615;
#
# K2SD7TRE = -7.365809124147925;
#
# LSD7TRE = 1.03;
#
# K2SF6TRE = 5.500256872497464;
#
# LSF6TRE = .334;
#
# K2SD5TRE = -6.103388599058754;
#
# LSD5TRE = 1.03;
#
# K2SF4TRE = 5.338571861982961;
#
# LSF4TRE = .334;
#
# K2SD3TRE = -1.0153606559367112;
#
# LSD3TRE = 1.03;
#
# K1QLA10RE = .23937031920084914;
#
# LQLA10RE = .82615;
#
# K1QLA9RE = -.3067240184631713;
#
# LQLA9RE = .82615;
#
# ANGLEBLA6RE = .05014968645104352;
#
# LBLA6RE = 5.901583520059881;
#
# K1QLA8RE = .3393319044410583;
#
# LQLA8RE = .55697;
#
# K1QLA7RE = -.19495983738446077;
#
# LQLA7RE = .82615;
#
# K1QLA6RE = .2362647111661896;
#
# LQLA6RE = .82615;
#
# K1QLA5RE = -.2116405900163815;
#
# LQLA5RE = .82615;
#
# ANGLEBLA4RE = .04806871702456943;
#
# LBLA4RE = 5.901633781531524;
#
# K1QLA4RE = .37049833552956923;
#
# LQLA4RE = .55697;
#
# K1QLA3RE = -.41433121647416815;
#
# LQLA3RE = .57004;
#
# ANGLEBLA2RE = .03482804499496367;
#
# LBLA2RE = 3.9612287870136287;
#
# K1QLA2RE = .11065904549090987;
#
# LQLA2RE = .57004;
#
# K2SLXTRE = -5.133764054843855;
#
# LSLXTRE = .5;
#
# K1QLX2RE = .42365960899669197;
#
# LQLX2RE = .57004;
#
# K1QLX3RE = -.5734913998593257;
#
# LQLX3RE = .57004;
#
# ANGLEBLX1RE = -.02217879657566246;
#
# LBLX1RE = 3.9613478078728486;
#
# K1QLX4RE = .45790265012822506;
#
# LQLX4RE = .57004;
#
# K1QLB8RE = .23821727355607042;
#
# LQLB8RE = .57004;
#
# K1QLB7RE = -.5413223855608784;
#
# LQLB7RE = 1.12349;
#
# ANGLEBLB2RE = .023469631432;
#
# LBLB2RE = 3.9613380819351183;
#
# K1QLB4RE = .4591679262089736;
#
# LQLB4RE = .57004;
#
# K1QLB1RE = -.5172031410148002;
#
# LQLB1RE = .57004;
#
# K2SLYTRE1 = -15.31967309027399;
#
# LSLYTRE1 = .6;
#
# K1QLY2RE = .03454332741085993;
#
# LQLY2RE = .46227;
#
# K1QLY4RE = .3665393111666756;
#
# LQLY4RE = .57004;
#
# ANGLEBLY2RE = .027;
#
# LBLY2RE = 3.961308672690613;
#
# K1QLY5RE = -.3897719769313939;
#
# LQLY5RE = .57004;
#
# K2SLYTRE2 = -15.31967309027399;
#
# LSLYTRE2 = .6;
#
# K1QLC7RE = -.38896739335299696;
#
# LQLC7RE = .57004;
#
# K1QLC6RE = .21069372764515507;
#
# LQLC6RE = .57004;
#
# K1QLC5RE = -.13846364653233773;
#
# LQLC5RE = .57004;
#
# K1QLC3RE = -.26170085922993314;
#
# LQLC3RE = .57004;
#
# LQKCRE = .3444;
#
# ANGLEBLC2RE = .005919854610596752;
#
# LBLC2RE = 2.23594073508731;
#
# LQKBRE = .3444;
#
# K1QLC2RE = .06807693990589335;
#
# LQLC2RE = .53815;
#
# LQKARE = .3444;
#
# K1QC2RE = 1.3282396251071005;
#
# LQC2RE = .42;
#
# K1QC1RE = -2.8585712458306003;
#
# LQC1RE = .38;
#
# K1QC1RPE = -.1577503385686254;
#
# LQC1RPE = .34;
#
#
#
# IP : MARKER;
#
# QC1LPE : QUADRUPOLE, K1:= K1QC1LPE, L:= LQC1LPE;
#
# QC1LE : QUADRUPOLE, K1:= K1QC1LE, L:= LQC1LE;
#
# QC2LE : QUADRUPOLE, K1:= K1QC2LE, L:= LQC2LE;
#
# PIRL : MARKER;
#
# QKALE : QUADRUPOLE, L:= LQKALE;
#
# MQLC2LE : MONITOR;
#
# QLC2LE : QUADRUPOLE, K1:= K1QLC2LE, L:= LQLC2LE;
#
# QKBLE : QUADRUPOLE, L:= LQKBLE;
#
# BLC1LE : RBEND, ANGLE:= ANGLEBLC1LE, E1:=  .0000000000 * ANGLEBLC1LE, E2:=  .0000000000 * ANGLEBLC1LE, L:= LBLC1LE;
#
# QKCLE : QUADRUPOLE, L:= LQKCLE;
#
# QLC3LE : QUADRUPOLE, K1:= K1QLC3LE, L:= LQLC3LE;
#
# MQLC3LE : MONITOR;
#
# QLC4LE : QUADRUPOLE, K1:= K1QLC4LE, L:= LQLC4LE;
#
# MQLC4LE : MONITOR;
#
# MQLC5LE : MONITOR;
#
# QLC5LE : QUADRUPOLE, K1:= K1QLC5LE, L:= LQLC5LE;
#
# QLC7LE : QUADRUPOLE, K1:= K1QLC7LE, L:= LQLC7LE;
#
# MQLC7LE : MONITOR;
#
# SLYTLE1 : SEXTUPOLE, K2:= K2SLYTLE1, L:= LSLYTLE1;
#
# QLY1LE : QUADRUPOLE, K1:= K1QLY1LE, L:= LQLY1LE;
#
# MQLY1LE1 : MONITOR;
#
# MQLY2LE1 : MONITOR;
#
# QLY2LE : QUADRUPOLE, K1:= K1QLY2LE, L:= LQLY2LE;
#
# BLY1LE : RBEND, ANGLE:= ANGLEBLY1LE, E1:=  .0000000000 * ANGLEBLY1LE, E2:=  .0000000000 * ANGLEBLY1LE, L:= LBLY1LE;
#
# QLY3LE : QUADRUPOLE, K1:= K1QLY3LE, L:= LQLY3LE;
#
# MQLY3LE : MONITOR;
#
# MQLY2LE2 : MONITOR;
#
# MQLY1LE2 : MONITOR;
#
# SLYTLE2 : SEXTUPOLE, K2:= K2SLYTLE2, L:= LSLYTLE2;
#
# MQLB1LE : MONITOR;
#
# QLB1LE : QUADRUPOLE, K1:= K1QLB1LE, L:= LQLB1LE;
#
# MQLB2LE : MONITOR;
#
# QLB2LE : QUADRUPOLE, K1:= K1QLB2LE, L:= LQLB2LE;
#
# BLB1LE : RBEND, ANGLE:= ANGLEBLB1LE, E1:=  .0000000000 * ANGLEBLB1LE, E2:=  .0000000000 * ANGLEBLB1LE, L:= LBLB1LE;
#
# QLB3LE : QUADRUPOLE, K1:= K1QLB3LE, L:= LQLB3LE;
#
# MQLB3LE : MONITOR;
#
# QLB4LE : QUADRUPOLE, K1:= K1QLB4LE, L:= LQLB4LE;
#
# MQLB4LE : MONITOR;
#
# SLXTLE : SEXTUPOLE, K2:= K2SLXTLE, L:= LSLXTLE;
#
# MQLX1LE1 : MONITOR;
#
# QLX1LE : QUADRUPOLE, K1:= K1QLX1LE, L:= LQLX1LE;
#
# BLX2LE : RBEND, ANGLE:= ANGLEBLX2LE, E1:=  .0000000000 * ANGLEBLX2LE, E2:=  .0000000000 * ANGLEBLX2LE, L:= LBLX2LE;
#
# QLX2LE : QUADRUPOLE, K1:= K1QLX2LE, L:= LQLX2LE;
#
# MQLX2LE : MONITOR;
#
# MQLX1LE2 : MONITOR;
#
# MQLA2LE : MONITOR;
#
# QLA2LE : QUADRUPOLE, K1:= K1QLA2LE, L:= LQLA2LE;
#
# QLA3LE : QUADRUPOLE, K1:= K1QLA3LE, L:= LQLA3LE;
#
# MQLA3LE : MONITOR;
#
# MQLA4LE : MONITOR;
#
# QLA4LE : QUADRUPOLE, K1:= K1QLA4LE, L:= LQLA4LE;
#
# BLA2LE : RBEND, ANGLE:= ANGLEBLA2LE, E1:=  .0000000000 * ANGLEBLA2LE, E2:=  .0000000000 * ANGLEBLA2LE, L:= LBLA2LE;
#
# QLA5LE : QUADRUPOLE, K1:= K1QLA5LE, L:= LQLA5LE;
#
# MQLA5LE : MONITOR;
#
# QLA6LE : QUADRUPOLE, K1:= K1QLA6LE, L:= LQLA6LE;
#
# MQLA6LE : MONITOR;
#
# MQLA7LE : MONITOR;
#
# QLA7LE : QUADRUPOLE, K1:= K1QLA7LE, L:= LQLA7LE;
#
# BLA4LE : RBEND, ANGLE:= ANGLEBLA4LE, E1:=  .0000000000 * ANGLEBLA4LE, E2:=  .0000000000 * ANGLEBLA4LE, L:= LBLA4LE;
#
# QLA8LE : QUADRUPOLE, K1:= K1QLA8LE, L:= LQLA8LE;
#
# MQLA8LE : MONITOR;
#
# QLA9LE : QUADRUPOLE, K1:= K1QLA9LE, L:= LQLA9LE;
#
# MQLA9LE : MONITOR;
#
# MQLA10LE : MONITOR;
#
# QLA10LE : QUADRUPOLE, K1:= K1QLA10LE, L:= LQLA10LE;
#
# MQF4E1 : MONITOR;
#
# PTSULM : MARKER;
#
# QF4E : QUADRUPOLE, K1:= K1QF4E, L:= LQF4E;
#
# QD3E : QUADRUPOLE, K1:= K1QD3E, L:= LQD3E;
#
# MQD3E1 : MONITOR;
#
# SD3TLE : SEXTUPOLE, K2:= K2SD3TLE, L:= LSD3TLE;
#
# B2E : RBEND, ANGLE:= ANGLEB2E, E1:=  .0000000000 * ANGLEB2E, E2:=  .0000000000 * ANGLEB2E, L:= LB2E;
#
# QF2E : QUADRUPOLE, K1:= K1QF2E, L:= LQF2E;
#
# MQF2E1 : MONITOR;
#
# QD1E : QUADRUPOLE, K1:= K1QD1E, L:= LQD1E;
#
# MQD1E1 : MONITOR;
#
# MQF2E2 : MONITOR;
#
# MQD3E2 : MONITOR;
#
# SKBTLE : QUADRUPOLE, L:= LSKBTLE, TILT:= TILTSKBTLE;
#
# MQF4E2 : MONITOR;
#
# SF4TLE : SEXTUPOLE, K2:= K2SF4TLE, L:= LSF4TLE;
#
# QEAE : QUADRUPOLE, K1:= K1QEAE, L:= LQEAE;
#
# MQEAE3 : MONITOR;
#
# QD5E : QUADRUPOLE, K1:= K1QD5E, L:= LQD5E;
#
# MQD5E3 : MONITOR;
#
# MQF6E2 : MONITOR;
#
# QF6E : QUADRUPOLE, K1:= K1QF6E, L:= LQF6E;
#
# MQD5E4 : MONITOR;
#
# MQEAE4 : MONITOR;
#
# MQF4E3 : MONITOR;
#
# MQD3E3 : MONITOR;
#
# SD5TLE : SEXTUPOLE, K2:= K2SD5TLE, L:= LSD5TLE;
#
# MQF2E3 : MONITOR;
#
# MQD1E2 : MONITOR;
#
# MQF2E4 : MONITOR;
#
# MQD3E4 : MONITOR;
#
# SKCTLE : QUADRUPOLE, L:= LSKCTLE, TILT:= TILTSKCTLE;
#
# MQF4E4 : MONITOR;
#
# SF6TLE : SEXTUPOLE, K2:= K2SF6TLE, L:= LSF6TLE;
#
# MQEAE5 : MONITOR;
#
# MQD5E5 : MONITOR;
#
# MQF6E3 : MONITOR;
#
# MQD5E6 : MONITOR;
#
# MQEAE6 : MONITOR;
#
# MQF4E5 : MONITOR;
#
# MQD3E5 : MONITOR;
#
# SD7TLE : SEXTUPOLE, K2:= K2SD7TLE, L:= LSD7TLE;
#
# MQF2E5 : MONITOR;
#
# MQD1E3 : MONITOR;
#
# MQF2E6 : MONITOR;
#
# MQT1TNE1 : MONITOR;
#
# QT1TNE : QUADRUPOLE, K1:= K1QT1TNE, L:= LQT1TNE;
#
# QT2TNE : QUADRUPOLE, K1:= K1QT2TNE, L:= LQT2TNE;
#
# MQT2TNE1 : MONITOR;
#
# SF8TNE : SEXTUPOLE, K2:= K2SF8TNE, L:= LSF8TNE;
#
# QTATNE : QUADRUPOLE, K1:= K1QTATNE, L:= LQTATNE;
#
# MQTATNE1 : MONITOR;
#
# QT3TNE : QUADRUPOLE, K1:= K1QT3TNE, L:= LQT3TNE;
#
# MQT3TNE1 : MONITOR;
#
# MQT4TNE1 : MONITOR;
#
# QT4TNE : QUADRUPOLE, K1:= K1QT4TNE, L:= LQT4TNE;
#
# MQTBTNE1 : MONITOR;
#
# QTBTNE : QUADRUPOLE, K1:= K1QTBTNE, L:= LQTBTNE;
#
# MQT5TNE : MONITOR;
#
# QT5TNE : QUADRUPOLE, K1:= K1QT5TNE, L:= LQT5TNE;
#
# MQTBTNE2 : MONITOR;
#
# MQT4TNE2 : MONITOR;
#
# MQT3TNE2 : MONITOR;
#
# MQTATNE2 : MONITOR;
#
# MQT2TNE2 : MONITOR;
#
# MQT1TNE2 : MONITOR;
#
# SD7NRE : SEXTUPOLE, K2:= K2SD7NRE, L:= LSD7NRE;
#
# MQF2E7 : MONITOR;
#
# MQD1E4 : MONITOR;
#
# MQF2E8 : MONITOR;
#
# MQD3E6 : MONITOR;
#
# SKCNRE : QUADRUPOLE, L:= LSKCNRE, TILT:= TILTSKCNRE;
#
# MQF4E6 : MONITOR;
#
# SF6NRE : SEXTUPOLE, K2:= K2SF6NRE, L:= LSF6NRE;
#
# MQEAE7 : MONITOR;
#
# MQD5E7 : MONITOR;
#
# MQF6E4 : MONITOR;
#
# MQD5E8 : MONITOR;
#
# MQEAE8 : MONITOR;
#
# MQF4E7 : MONITOR;
#
# MQD3E7 : MONITOR;
#
# SD5NRE : SEXTUPOLE, K2:= K2SD5NRE, L:= LSD5NRE;
#
# MQF2E9 : MONITOR;
#
# MQD1E5 : MONITOR;
#
# MQF2E10 : MONITOR;
#
# MQD3E8 : MONITOR;
#
# SKBNRE : QUADRUPOLE, L:= LSKBNRE, TILT:= TILTSKBNRE;
#
# MQF4E8 : MONITOR;
#
# SF4NRE : SEXTUPOLE, K2:= K2SF4NRE, L:= LSF4NRE;
#
# MQEAE9 : MONITOR;
#
# MQD5E9 : MONITOR;
#
# MQF6E5 : MONITOR;
#
# MQD5E10 : MONITOR;
#
# MQEAE10 : MONITOR;
#
# MQF4E9 : MONITOR;
#
# MQD3E9 : MONITOR;
#
# SD3NRE : SEXTUPOLE, K2:= K2SD3NRE, L:= LSD3NRE;
#
# MQF2E11 : MONITOR;
#
# MQD1E6 : MONITOR;
#
# MQF2E12 : MONITOR;
#
# MQD3E10 : MONITOR;
#
# MQF4E10 : MONITOR;
#
# SF2NRE : SEXTUPOLE, K2:= K2SF2NRE, L:= LSF2NRE;
#
# MQEAE11 : MONITOR;
#
# MQD5E11 : MONITOR;
#
# MQF6E6 : MONITOR;
#
# MQD5E12 : MONITOR;
#
# MQEAE12 : MONITOR;
#
# MQS4NE1 : MONITOR;
#
# QS4NE : QUADRUPOLE, K1:= K1QS4NE, L:= LQS4NE;
#
# QSBNE : QUADRUPOLE, K1:= K1QSBNE, L:= LQSBNE;
#
# MQSBNE1 : MONITOR;
#
# MQS3NE1 : MONITOR;
#
# QS3NE : QUADRUPOLE, K1:= K1QS3NE, L:= LQS3NE;
#
# MQS2NE1 : MONITOR;
#
# QS2NE : QUADRUPOLE, K1:= K1QS2NE, L:= LQS2NE;
#
# BSWNRE : RBEND, ANGLE:= ANGLEBSWNRE, E1:=  .0000000000 * ANGLEBSWNRE, E2:=  .0000000000 * ANGLEBSWNRE, L:= LBSWNRE;
#
# PNIKRM : MARKER;
#
# MQR7NE1 : MONITOR;
#
# QR7NE : QUADRUPOLE, K1:= K1QR7NE, L:= LQR7NE;
#
# QR6NE : QUADRUPOLE, K1:= K1QR6NE, L:= LQR6NE;
#
# MQR6NE1 : MONITOR;
#
# QR5NE : QUADRUPOLE, K1:= K1QR5NE, L:= LQR5NE;
#
# MQR5NE1 : MONITOR;
#
# QR4NE : QUADRUPOLE, K1:= K1QR4NE, L:= LQR4NE;
#
# MQR4NE1 : MONITOR;
#
# QR3NE : QUADRUPOLE, K1:= K1QR3NE, L:= LQR3NE;
#
# MQR3NE1 : MONITOR;
#
# CADNRE : RFCAVITY, FREQ:= FREQCADNRE, VOLT:= VOLTCADNRE;
#
# QR2NE : QUADRUPOLE, K1:= K1QR2NE, L:= LQR2NE;
#
# MQR2NE1 : MONITOR;
#
# CACNRE : RFCAVITY, FREQ:= FREQCACNRE, VOLT:= VOLTCACNRE;
#
# QDRNE : QUADRUPOLE, K1:= K1QDRNE, L:= LQDRNE;
#
# MQDRNE1 : MONITOR;
#
# CABNRE : RFCAVITY, FREQ:= FREQCABNRE, VOLT:= VOLTCABNRE;
#
# QFRNE : QUADRUPOLE, K1:= K1QFRNE, L:= LQFRNE;
#
# MQFRNE1 : MONITOR;
#
# CAANRE : RFCAVITY, FREQ:= FREQCAANRE, VOLT:= VOLTCAANRE;
#
# MQDRNE2 : MONITOR;
#
# MQFRNE2 : MONITOR;
#
# MQDRNE3 : MONITOR;
#
# PQFRNI : MARKER;
#
# MQFRNE3 : MONITOR;
#
# MQDRNE4 : MONITOR;
#
# MQFRNE4 : MONITOR;
#
# MQDRNE5 : MONITOR;
#
# CAANLE : RFCAVITY, FREQ:= FREQCAANLE, VOLT:= VOLTCAANLE;
#
# MQFRNE5 : MONITOR;
#
# CABNLE : RFCAVITY, FREQ:= FREQCABNLE, VOLT:= VOLTCABNLE;
#
# MQDRNE6 : MONITOR;
#
# CACNLE : RFCAVITY, FREQ:= FREQCACNLE, VOLT:= VOLTCACNLE;
#
# MQR2NE2 : MONITOR;
#
# CADNLE : RFCAVITY, FREQ:= FREQCADNLE, VOLT:= VOLTCADNLE;
#
# MQR3NE2 : MONITOR;
#
# MQR4NE2 : MONITOR;
#
# MQR5NE2 : MONITOR;
#
# MQR6NE2 : MONITOR;
#
# MQR7NE2 : MONITOR;
#
# PNIKLM : MARKER;
#
# BSWNLE : RBEND, ANGLE:= ANGLEBSWNLE, E1:=  .0000000000 * ANGLEBSWNLE, E2:=  .0000000000 * ANGLEBSWNLE, L:= LBSWNLE;
#
# MQS2NE2 : MONITOR;
#
# MQS3NE2 : MONITOR;
#
# MQSBNE2 : MONITOR;
#
# MQS4NE2 : MONITOR;
#
# SF2NLE : SEXTUPOLE, K2:= K2SF2NLE, L:= LSF2NLE;
#
# MQEAE13 : MONITOR;
#
# MQD5E13 : MONITOR;
#
# MQF6E7 : MONITOR;
#
# MQD5E14 : MONITOR;
#
# MQEAE14 : MONITOR;
#
# MQF4E11 : MONITOR;
#
# MQD3E11 : MONITOR;
#
# SD3NLE : SEXTUPOLE, K2:= K2SD3NLE, L:= LSD3NLE;
#
# MQF2E13 : MONITOR;
#
# MQD1E7 : MONITOR;
#
# MQF2E14 : MONITOR;
#
# MQD3E12 : MONITOR;
#
# SKBNLE : QUADRUPOLE, L:= LSKBNLE, TILT:= TILTSKBNLE;
#
# MQF4E12 : MONITOR;
#
# SF4NLE : SEXTUPOLE, K2:= K2SF4NLE, L:= LSF4NLE;
#
# MQEAE15 : MONITOR;
#
# MQD5E15 : MONITOR;
#
# MQF6E8 : MONITOR;
#
# MQD5E16 : MONITOR;
#
# MQEAE16 : MONITOR;
#
# MQF4E13 : MONITOR;
#
# MQD3E13 : MONITOR;
#
# SD5NLE : SEXTUPOLE, K2:= K2SD5NLE, L:= LSD5NLE;
#
# MQF2E15 : MONITOR;
#
# MQD1E8 : MONITOR;
#
# MQF2E16 : MONITOR;
#
# MQD3E14 : MONITOR;
#
# SKCNLE : QUADRUPOLE, L:= LSKCNLE, TILT:= TILTSKCNLE;
#
# MQF4E14 : MONITOR;
#
# SF6NLE : SEXTUPOLE, K2:= K2SF6NLE, L:= LSF6NLE;
#
# MQEAE17 : MONITOR;
#
# MQD5E17 : MONITOR;
#
# MQF6E9 : MONITOR;
#
# MQD5E18 : MONITOR;
#
# MQEAE18 : MONITOR;
#
# MQF4E15 : MONITOR;
#
# MQD3E15 : MONITOR;
#
# SD7NLE : SEXTUPOLE, K2:= K2SD7NLE, L:= LSD7NLE;
#
# MQF2E17 : MONITOR;
#
# MQD1E9 : MONITOR;
#
# MQF2E18 : MONITOR;
#
# MQT1NFE1 : MONITOR;
#
# QT1NFE : QUADRUPOLE, K1:= K1QT1NFE, L:= LQT1NFE;
#
# QT2NFE : QUADRUPOLE, K1:= K1QT2NFE, L:= LQT2NFE;
#
# MQT2NFE1 : MONITOR;
#
# SF8NFE : SEXTUPOLE, K2:= K2SF8NFE, L:= LSF8NFE;
#
# QTANFE : QUADRUPOLE, K1:= K1QTANFE, L:= LQTANFE;
#
# MQTANFE1 : MONITOR;
#
# QT3NFE : QUADRUPOLE, K1:= K1QT3NFE, L:= LQT3NFE;
#
# MQT3NFE1 : MONITOR;
#
# MQT4NFE1 : MONITOR;
#
# QT4NFE : QUADRUPOLE, K1:= K1QT4NFE, L:= LQT4NFE;
#
# MQTBNFE1 : MONITOR;
#
# QTBNFE : QUADRUPOLE, K1:= K1QTBNFE, L:= LQTBNFE;
#
# MQT5NFE : MONITOR;
#
# QT5NFE : QUADRUPOLE, K1:= K1QT5NFE, L:= LQT5NFE;
#
# MQTBNFE2 : MONITOR;
#
# MQT4NFE2 : MONITOR;
#
# MQT3NFE2 : MONITOR;
#
# MQTANFE2 : MONITOR;
#
# MQT2NFE2 : MONITOR;
#
# MQT1NFE2 : MONITOR;
#
# SD7FRE : SEXTUPOLE, K2:= K2SD7FRE, L:= LSD7FRE;
#
# MQF2E19 : MONITOR;
#
# MQD1E10 : MONITOR;
#
# MQF2E20 : MONITOR;
#
# MQD3E16 : MONITOR;
#
# SKCFRE : QUADRUPOLE, L:= LSKCFRE, TILT:= TILTSKCFRE;
#
# MQF4E16 : MONITOR;
#
# SF6FRE : SEXTUPOLE, K2:= K2SF6FRE, L:= LSF6FRE;
#
# MQEAE19 : MONITOR;
#
# MQD5E19 : MONITOR;
#
# MQF6E10 : MONITOR;
#
# MQD5E20 : MONITOR;
#
# MQEAE20 : MONITOR;
#
# MQF4E17 : MONITOR;
#
# MQD3E17 : MONITOR;
#
# SD5FRE : SEXTUPOLE, K2:= K2SD5FRE, L:= LSD5FRE;
#
# MQF2E21 : MONITOR;
#
# MQD1E11 : MONITOR;
#
# MQF2E22 : MONITOR;
#
# MQD3E18 : MONITOR;
#
# SKBFRE : QUADRUPOLE, L:= LSKBFRE, TILT:= TILTSKBFRE;
#
# MQF4E18 : MONITOR;
#
# SF4FRE : SEXTUPOLE, K2:= K2SF4FRE, L:= LSF4FRE;
#
# MQEAE21 : MONITOR;
#
# MQD5E21 : MONITOR;
#
# MQF6E11 : MONITOR;
#
# MQD5E22 : MONITOR;
#
# MQEAE22 : MONITOR;
#
# MQF4E19 : MONITOR;
#
# MQD3E19 : MONITOR;
#
# SD3FRE : SEXTUPOLE, K2:= K2SD3FRE, L:= LSD3FRE;
#
# MQF2E23 : MONITOR;
#
# MQD1E12 : MONITOR;
#
# MQF2E24 : MONITOR;
#
# MQD3E20 : MONITOR;
#
# MQF4E20 : MONITOR;
#
# SF2FRE : SEXTUPOLE, K2:= K2SF2FRE, L:= LSF2FRE;
#
# MQEAE23 : MONITOR;
#
# MQD5E23 : MONITOR;
#
# MQF6E12 : MONITOR;
#
# MQD5E24 : MONITOR;
#
# MQEAE24 : MONITOR;
#
# MQS4FRE : MONITOR;
#
# QS4FRE : QUADRUPOLE, K1:= K1QS4FRE, L:= LQS4FRE;
#
# QSBFRE : QUADRUPOLE, K1:= K1QSBFRE, L:= LQSBFRE;
#
# MQSBFRE : MONITOR;
#
# MQS3FRE : MONITOR;
#
# QS3FRE : QUADRUPOLE, K1:= K1QS3FRE, L:= LQS3FRE;
#
# MQS2FRE : MONITOR;
#
# QS2FRE : QUADRUPOLE, K1:= K1QS2FRE, L:= LQS2FRE;
#
# BSWFRE : RBEND, ANGLE:= ANGLEBSWFRE, E1:=  .0000000000 * ANGLEBSWFRE, E2:=  .0000000000 * ANGLEBSWFRE, L:= LBSWFRE;
#
# PFUJRM : MARKER;
#
# QI7E : QUADRUPOLE, K1:= K1QI7E, L:= LQI7E;
#
# MQI7E : MONITOR;
#
# MQI6E : MONITOR;
#
# QI6E : QUADRUPOLE, K1:= K1QI6E, L:= LQI6E;
#
# QI5E : QUADRUPOLE, K1:= K1QI5E, L:= LQI5E;
#
# MQI5E : MONITOR;
#
# MQI4E : MONITOR;
#
# QI4E : QUADRUPOLE, K1:= K1QI4E, L:= LQI4E;
#
# INJECTIO : MARKER;
#
# QI3E : QUADRUPOLE, K1:= K1QI3E, L:= LQI3E;
#
# MQI3E : MONITOR;
#
# QI2E : QUADRUPOLE, K1:= K1QI2E, L:= LQI2E;
#
# MQI2E : MONITOR;
#
# PDUMP2 : MARKER;
#
# PDUMP1 : MARKER;
#
# QX7RE : QUADRUPOLE, K1:= K1QX7RE, L:= LQX7RE;
#
# MQX7RE : MONITOR;
#
# QX6RE : QUADRUPOLE, K1:= K1QX6RE, L:= LQX6RE;
#
# MQX6RE : MONITOR;
#
# SXABE : SEXTUPOLE, K2:= K2SXABE, L:= LSXABE;
#
# QX5RE : QUADRUPOLE, K1:= K1QX5RE, L:= LQX5RE;
#
# MQX5RE : MONITOR;
#
# QX4RE : QUADRUPOLE, K1:= K1QX4RE, L:= LQX4RE;
#
# MQX4RE : MONITOR;
#
# BX2E : RBEND, ANGLE:= ANGLEBX2E, E1:=  .0000000000 * ANGLEBX2E, E2:=  .0000000000 * ANGLEBX2E, L:= LBX2E;
#
# QX3RE : QUADRUPOLE, K1:= K1QX3RE, L:= LQX3RE;
#
# MQX3RE : MONITOR;
#
# QX2RE : QUADRUPOLE, K1:= K1QX2RE, L:= LQX2RE;
#
# MQX2RE : MONITOR;
#
# PMID : MARKER;
#
# MQX2LE : MONITOR;
#
# QX2LE : QUADRUPOLE, K1:= K1QX2LE, L:= LQX2LE;
#
# MQX3LE : MONITOR;
#
# QX3LE : QUADRUPOLE, K1:= K1QX3LE, L:= LQX3LE;
#
# BX1E : RBEND, ANGLE:= ANGLEBX1E, E1:=  .0000000000 * ANGLEBX1E, E2:=  .0000000000 * ANGLEBX1E, L:= LBX1E;
#
# MQX4LE : MONITOR;
#
# QX4LE : QUADRUPOLE, K1:= K1QX4LE, L:= LQX4LE;
#
# MQX5LE : MONITOR;
#
# QX5LE : QUADRUPOLE, K1:= K1QX5LE, L:= LQX5LE;
#
# FZLFBKE2 : QUADRUPOLE, L:= LFZLFBKE2;
#
# FZLFBKE1 : QUADRUPOLE, L:= LFZLFBKE1;
#
# MQX6LE : MONITOR;
#
# QX6LE : QUADRUPOLE, K1:= K1QX6LE, L:= LQX6LE;
#
# PFBMON2 : MARKER;
#
# PDCCT : MARKER;
#
# PCT : MARKER;
#
# MQX7LE : MONITOR;
#
# QX7LE : QUADRUPOLE, K1:= K1QX7LE, L:= LQX7LE;
#
# MQM2E : MONITOR;
#
# QM2E : QUADRUPOLE, K1:= K1QM2E, L:= LQM2E;
#
# PFBMON1 : MARKER;
#
# MQM3E : MONITOR;
#
# QM3E : QUADRUPOLE, K1:= K1QM3E, L:= LQM3E;
#
# FZTFBKE2 : QUADRUPOLE, L:= LFZTFBKE2;
#
# FZTFBKE1 : QUADRUPOLE, L:= LFZTFBKE1;
#
# MQM4E : MONITOR;
#
# QM4E : QUADRUPOLE, K1:= K1QM4E, L:= LQM4E;
#
# MQM5E : MONITOR;
#
# QM5E : QUADRUPOLE, K1:= K1QM5E, L:= LQM5E;
#
# MQM6E : MONITOR;
#
# QM6E : QUADRUPOLE, K1:= K1QM6E, L:= LQM6E;
#
# MQM7E : MONITOR;
#
# QM7E : QUADRUPOLE, K1:= K1QM7E, L:= LQM7E;
#
# PFUJLM : MARKER;
#
# BSWFLE : RBEND, ANGLE:= ANGLEBSWFLE, E1:=  .0000000000 * ANGLEBSWFLE, E2:=  .0000000000 * ANGLEBSWFLE, L:= LBSWFLE;
#
# MQS2FLE : MONITOR;
#
# QS2FLE : QUADRUPOLE, K1:= K1QS2FLE, L:= LQS2FLE;
#
# QS3FLE : QUADRUPOLE, K1:= K1QS3FLE, L:= LQS3FLE;
#
# MQS3FLE : MONITOR;
#
# MQSBFLE : MONITOR;
#
# QSBFLE : QUADRUPOLE, K1:= K1QSBFLE, L:= LQSBFLE;
#
# QS4FLE : QUADRUPOLE, K1:= K1QS4FLE, L:= LQS4FLE;
#
# MQS4FLE : MONITOR;
#
# SF2FLE : SEXTUPOLE, K2:= K2SF2FLE, L:= LSF2FLE;
#
# MQEAE25 : MONITOR;
#
# MQD5E25 : MONITOR;
#
# MQF6E13 : MONITOR;
#
# MQD5E26 : MONITOR;
#
# MQEAE26 : MONITOR;
#
# MQF4E21 : MONITOR;
#
# MQD3E21 : MONITOR;
#
# SD3FLE : SEXTUPOLE, K2:= K2SD3FLE, L:= LSD3FLE;
#
# MQF2E25 : MONITOR;
#
# MQD1E13 : MONITOR;
#
# MQF2E26 : MONITOR;
#
# MQD3E22 : MONITOR;
#
# SKBFLE : QUADRUPOLE, L:= LSKBFLE, TILT:= TILTSKBFLE;
#
# MQF4E22 : MONITOR;
#
# SF4FLE : SEXTUPOLE, K2:= K2SF4FLE, L:= LSF4FLE;
#
# MQEAE27 : MONITOR;
#
# MQD5E27 : MONITOR;
#
# MQF6E14 : MONITOR;
#
# MQD5E28 : MONITOR;
#
# MQEAE28 : MONITOR;
#
# MQF4E23 : MONITOR;
#
# MQD3E23 : MONITOR;
#
# SD5FLE : SEXTUPOLE, K2:= K2SD5FLE, L:= LSD5FLE;
#
# MQF2E27 : MONITOR;
#
# MQD1E14 : MONITOR;
#
# MQF2E28 : MONITOR;
#
# MQD3E24 : MONITOR;
#
# SKCFLE : QUADRUPOLE, L:= LSKCFLE, TILT:= TILTSKCFLE;
#
# MQF4E24 : MONITOR;
#
# SF6FLE : SEXTUPOLE, K2:= K2SF6FLE, L:= LSF6FLE;
#
# MQEAE29 : MONITOR;
#
# MQD5E29 : MONITOR;
#
# MQF6E15 : MONITOR;
#
# MQD5E30 : MONITOR;
#
# MQEAE30 : MONITOR;
#
# MQF4E25 : MONITOR;
#
# MQD3E25 : MONITOR;
#
# SD7FLE : SEXTUPOLE, K2:= K2SD7FLE, L:= LSD7FLE;
#
# MQF2E29 : MONITOR;
#
# MQD1E15 : MONITOR;
#
# MQF2E30 : MONITOR;
#
# MQT1FOE1 : MONITOR;
#
# QT1FOE : QUADRUPOLE, K1:= K1QT1FOE, L:= LQT1FOE;
#
# QT2FOE : QUADRUPOLE, K1:= K1QT2FOE, L:= LQT2FOE;
#
# MQT2FOE1 : MONITOR;
#
# SF8FOE : SEXTUPOLE, K2:= K2SF8FOE, L:= LSF8FOE;
#
# QTAFOE : QUADRUPOLE, K1:= K1QTAFOE, L:= LQTAFOE;
#
# MQTAFOE1 : MONITOR;
#
# QT3FOE : QUADRUPOLE, K1:= K1QT3FOE, L:= LQT3FOE;
#
# MQT3FOE1 : MONITOR;
#
# MQT4FOE1 : MONITOR;
#
# QT4FOE : QUADRUPOLE, K1:= K1QT4FOE, L:= LQT4FOE;
#
# MQTBFOE1 : MONITOR;
#
# QTBFOE : QUADRUPOLE, K1:= K1QTBFOE, L:= LQTBFOE;
#
# MQT5FOE : MONITOR;
#
# QT5FOE : QUADRUPOLE, K1:= K1QT5FOE, L:= LQT5FOE;
#
# MQTBFOE2 : MONITOR;
#
# MQT4FOE2 : MONITOR;
#
# MQT3FOE2 : MONITOR;
#
# MQTAFOE2 : MONITOR;
#
# MQT2FOE2 : MONITOR;
#
# MQT1FOE2 : MONITOR;
#
# SD7ORE : SEXTUPOLE, K2:= K2SD7ORE, L:= LSD7ORE;
#
# MQF2E31 : MONITOR;
#
# MQD1E16 : MONITOR;
#
# MQF2E32 : MONITOR;
#
# MQD3E26 : MONITOR;
#
# MQF4E26 : MONITOR;
#
# SF6ORE : SEXTUPOLE, K2:= K2SF6ORE, L:= LSF6ORE;
#
# MQEAE31 : MONITOR;
#
# MQD5E31 : MONITOR;
#
# MQF6E16 : MONITOR;
#
# MQD5E32 : MONITOR;
#
# MQEAE32 : MONITOR;
#
# MQF4E27 : MONITOR;
#
# MQD3E27 : MONITOR;
#
# SD5ORE : SEXTUPOLE, K2:= K2SD5ORE, L:= LSD5ORE;
#
# MQF2E33 : MONITOR;
#
# MQD1E17 : MONITOR;
#
# MQF2E34 : MONITOR;
#
# MQD3E28 : MONITOR;
#
# MQF4E28 : MONITOR;
#
# SF4ORE : SEXTUPOLE, K2:= K2SF4ORE, L:= LSF4ORE;
#
# MQEAE33 : MONITOR;
#
# MQD5E33 : MONITOR;
#
# MQF6E17 : MONITOR;
#
# MQD5E34 : MONITOR;
#
# MQEAE34 : MONITOR;
#
# MQF4E29 : MONITOR;
#
# MQD3E29 : MONITOR;
#
# SD3ORE : SEXTUPOLE, K2:= K2SD3ORE, L:= LSD3ORE;
#
# MQF2E35 : MONITOR;
#
# MQD1E18 : MONITOR;
#
# MQF2E36 : MONITOR;
#
# MQD3E30 : MONITOR;
#
# MQF4E30 : MONITOR;
#
# SF2ORE : SEXTUPOLE, K2:= K2SF2ORE, L:= LSF2ORE;
#
# MQEAE35 : MONITOR;
#
# MQD5E35 : MONITOR;
#
# MQF6E18 : MONITOR;
#
# MQD5E36 : MONITOR;
#
# MQEAE36 : MONITOR;
#
# MQS4OE1 : MONITOR;
#
# QS4OE : QUADRUPOLE, K1:= K1QS4OE, L:= LQS4OE;
#
# QSBOE : QUADRUPOLE, K1:= K1QSBOE, L:= LQSBOE;
#
# MQSBOE1 : MONITOR;
#
# MQS3ORE : MONITOR;
#
# QS3ORE : QUADRUPOLE, K1:= K1QS3ORE, L:= LQS3ORE;
#
# BS2ORE : RBEND, ANGLE:= ANGLEBS2ORE, E1:=  .0000000000 * ANGLEBS2ORE, E2:=  .0000000000 * ANGLEBS2ORE, L:= LBS2ORE;
#
# QS2ORE : QUADRUPOLE, K1:= K1QS2ORE, L:= LQS2ORE;
#
# MQS2ORE : MONITOR;
#
# BSWORE : RBEND, ANGLE:= ANGLEBSWORE, E1:=  .0000000000 * ANGLEBSWORE, E2:=  .0000000000 * ANGLEBSWORE, L:= LBSWORE;
#
# POHORM : MARKER;
#
# MQR7ORE : MONITOR;
#
# QR7ORE : QUADRUPOLE, K1:= K1QR7ORE, L:= LQR7ORE;
#
# QR6ORE : QUADRUPOLE, K1:= K1QR6ORE, L:= LQR6ORE;
#
# MQR6ORE : MONITOR;
#
# MQR5ORE : MONITOR;
#
# QR5ORE : QUADRUPOLE, K1:= K1QR5ORE, L:= LQR5ORE;
#
# MQR4ORE : MONITOR;
#
# QR4ORE : QUADRUPOLE, K1:= K1QR4ORE, L:= LQR4ORE;
#
# MQR3ORE : MONITOR;
#
# QR3ORE : QUADRUPOLE, K1:= K1QR3ORE, L:= LQR3ORE;
#
# MQR2ORE : MONITOR;
#
# QR2ORE : QUADRUPOLE, K1:= K1QR2ORE, L:= LQR2ORE;
#
# MQDWOE1 : MONITOR;
#
# QDWOE : QUADRUPOLE, K1:= K1QDWOE, L:= LQDWOE;
#
# MQFWOE : MONITOR;
#
# QFWOE : QUADRUPOLE, K1:= K1QFWOE, L:= LQFWOE;
#
# MQDWOE2 : MONITOR;
#
# MQFROE2 : MONITOR;
#
# QFROE : QUADRUPOLE, K1:= K1QFROE, L:= LQFROE;
#
# MQDROE3 : MONITOR;
#
# QDROE : QUADRUPOLE, K1:= K1QDROE, L:= LQDROE;
#
# MQFROE3 : MONITOR;
#
# PQFROI : MARKER;
#
# MQDROE4 : MONITOR;
#
# MQFROE4 : MONITOR;
#
# MQDROE5 : MONITOR;
#
# CAAOLE : RFCAVITY, FREQ:= FREQCAAOLE, VOLT:= VOLTCAAOLE;
#
# CABOLE : RFCAVITY, FREQ:= FREQCABOLE, VOLT:= VOLTCABOLE;
#
# MQFROE5 : MONITOR;
#
# CACOLE : RFCAVITY, FREQ:= FREQCACOLE, VOLT:= VOLTCACOLE;
#
# CADOLE : RFCAVITY, FREQ:= FREQCADOLE, VOLT:= VOLTCADOLE;
#
# MQDROE6 : MONITOR;
#
# CAEOLE : RFCAVITY, FREQ:= FREQCAEOLE, VOLT:= VOLTCAEOLE;
#
# CAFOLE : RFCAVITY, FREQ:= FREQCAFOLE, VOLT:= VOLTCAFOLE;
#
# MQR2OLE : MONITOR;
#
# QR2OLE : QUADRUPOLE, K1:= K1QR2OLE, L:= LQR2OLE;
#
# CAGOLE : RFCAVITY, FREQ:= FREQCAGOLE, VOLT:= VOLTCAGOLE;
#
# CAHOLE : RFCAVITY, FREQ:= FREQCAHOLE, VOLT:= VOLTCAHOLE;
#
# MQR3OLE : MONITOR;
#
# QR3OLE : QUADRUPOLE, K1:= K1QR3OLE, L:= LQR3OLE;
#
# MQR4OLE : MONITOR;
#
# QR4OLE : QUADRUPOLE, K1:= K1QR4OLE, L:= LQR4OLE;
#
# MQR5OLE : MONITOR;
#
# QR5OLE : QUADRUPOLE, K1:= K1QR5OLE, L:= LQR5OLE;
#
# MQR6OLE : MONITOR;
#
# QR6OLE : QUADRUPOLE, K1:= K1QR6OLE, L:= LQR6OLE;
#
# QR7OLE : QUADRUPOLE, K1:= K1QR7OLE, L:= LQR7OLE;
#
# MQR7OLE : MONITOR;
#
# POHOLM : MARKER;
#
# BSWOLE : RBEND, ANGLE:= ANGLEBSWOLE, E1:=  .0000000000 * ANGLEBSWOLE, E2:=  .0000000000 * ANGLEBSWOLE, L:= LBSWOLE;
#
# QS2OLE : QUADRUPOLE, K1:= K1QS2OLE, L:= LQS2OLE;
#
# MQS2OLE : MONITOR;
#
# QS3OLE : QUADRUPOLE, K1:= K1QS3OLE, L:= LQS3OLE;
#
# MQS3OLE : MONITOR;
#
# MQSBOE2 : MONITOR;
#
# MQS4OE2 : MONITOR;
#
# SF2OLE : SEXTUPOLE, K2:= K2SF2OLE, L:= LSF2OLE;
#
# MQEAE37 : MONITOR;
#
# MQD5E37 : MONITOR;
#
# MQF6E19 : MONITOR;
#
# MQD5E38 : MONITOR;
#
# MQEAE38 : MONITOR;
#
# MQF4E31 : MONITOR;
#
# MQD3E31 : MONITOR;
#
# SD3OLE : SEXTUPOLE, K2:= K2SD3OLE, L:= LSD3OLE;
#
# MQF2E37 : MONITOR;
#
# MQD1E19 : MONITOR;
#
# MQF2E38 : MONITOR;
#
# MQD3E32 : MONITOR;
#
# MQF4E32 : MONITOR;
#
# SF4OLE : SEXTUPOLE, K2:= K2SF4OLE, L:= LSF4OLE;
#
# MQEAE39 : MONITOR;
#
# MQD5E39 : MONITOR;
#
# MQF6E20 : MONITOR;
#
# MQD5E40 : MONITOR;
#
# MQEAE40 : MONITOR;
#
# MQF4E33 : MONITOR;
#
# MQD3E33 : MONITOR;
#
# SD5OLE : SEXTUPOLE, K2:= K2SD5OLE, L:= LSD5OLE;
#
# MQF2E39 : MONITOR;
#
# MQD1E20 : MONITOR;
#
# MQF2E40 : MONITOR;
#
# MQD3E34 : MONITOR;
#
# MQF4E34 : MONITOR;
#
# SF6OLE : SEXTUPOLE, K2:= K2SF6OLE, L:= LSF6OLE;
#
# MQEAE41 : MONITOR;
#
# MQD5E41 : MONITOR;
#
# MQF6E21 : MONITOR;
#
# MQD5E42 : MONITOR;
#
# MQEAE42 : MONITOR;
#
# MQF4E35 : MONITOR;
#
# MQD3E35 : MONITOR;
#
# SD7OLE : SEXTUPOLE, K2:= K2SD7OLE, L:= LSD7OLE;
#
# MQF2E41 : MONITOR;
#
# MQD1E21 : MONITOR;
#
# MQF2E42 : MONITOR;
#
# MQT1OTE1 : MONITOR;
#
# QT1OTE : QUADRUPOLE, K1:= K1QT1OTE, L:= LQT1OTE;
#
# QT2OTE : QUADRUPOLE, K1:= K1QT2OTE, L:= LQT2OTE;
#
# MQT2OTE1 : MONITOR;
#
# SF8OTE : SEXTUPOLE, K2:= K2SF8OTE, L:= LSF8OTE;
#
# QTAOTE : QUADRUPOLE, K1:= K1QTAOTE, L:= LQTAOTE;
#
# MQTAOTE1 : MONITOR;
#
# QT3OTE : QUADRUPOLE, K1:= K1QT3OTE, L:= LQT3OTE;
#
# MQT3OTE1 : MONITOR;
#
# MQT4OTE1 : MONITOR;
#
# QT4OTE : QUADRUPOLE, K1:= K1QT4OTE, L:= LQT4OTE;
#
# MQTBOTE1 : MONITOR;
#
# QTBOTE : QUADRUPOLE, K1:= K1QTBOTE, L:= LQTBOTE;
#
# MQT5OTE : MONITOR;
#
# QT5OTE : QUADRUPOLE, K1:= K1QT5OTE, L:= LQT5OTE;
#
# MQTBOTE2 : MONITOR;
#
# MQT4OTE2 : MONITOR;
#
# MQT3OTE2 : MONITOR;
#
# MQTAOTE2 : MONITOR;
#
# MQT2OTE2 : MONITOR;
#
# MQT1OTE2 : MONITOR;
#
# SD7TRE : SEXTUPOLE, K2:= K2SD7TRE, L:= LSD7TRE;
#
# MQF2E43 : MONITOR;
#
# MQD1E22 : MONITOR;
#
# MQF2E44 : MONITOR;
#
# MQD3E36 : MONITOR;
#
# MQF4E36 : MONITOR;
#
# SF6TRE : SEXTUPOLE, K2:= K2SF6TRE, L:= LSF6TRE;
#
# MQEAE43 : MONITOR;
#
# MQD5E43 : MONITOR;
#
# MQF6E22 : MONITOR;
#
# MQD5E44 : MONITOR;
#
# MQEAE44 : MONITOR;
#
# MQF4E37 : MONITOR;
#
# MQD3E37 : MONITOR;
#
# SD5TRE : SEXTUPOLE, K2:= K2SD5TRE, L:= LSD5TRE;
#
# MQF2E45 : MONITOR;
#
# MQD1E23 : MONITOR;
#
# MQF2E46 : MONITOR;
#
# MQD3E38 : MONITOR;
#
# MQF4E38 : MONITOR;
#
# SF4TRE : SEXTUPOLE, K2:= K2SF4TRE, L:= LSF4TRE;
#
# MQEAE45 : MONITOR;
#
# MQD5E45 : MONITOR;
#
# MQF6E23 : MONITOR;
#
# MQD5E46 : MONITOR;
#
# MQEAE46 : MONITOR;
#
# MQF4E39 : MONITOR;
#
# MQD3E39 : MONITOR;
#
# SD3TRE : SEXTUPOLE, K2:= K2SD3TRE, L:= LSD3TRE;
#
# MQF2E47 : MONITOR;
#
# MQD1E24 : MONITOR;
#
# MQF2E48 : MONITOR;
#
# MQD3E40 : MONITOR;
#
# PTSURM : MARKER;
#
# MQF4E40 : MONITOR;
#
# QLA10RE : QUADRUPOLE, K1:= K1QLA10RE, L:= LQLA10RE;
#
# MQLA10RE : MONITOR;
#
# MQLA9RE : MONITOR;
#
# QLA9RE : QUADRUPOLE, K1:= K1QLA9RE, L:= LQLA9RE;
#
# BLA6RE : RBEND, ANGLE:= ANGLEBLA6RE, E1:=  .0000000000 * ANGLEBLA6RE, E2:=  .0000000000 * ANGLEBLA6RE, L:= LBLA6RE;
#
# QLA8RE : QUADRUPOLE, K1:= K1QLA8RE, L:= LQLA8RE;
#
# MQLA8RE : MONITOR;
#
# QLA7RE : QUADRUPOLE, K1:= K1QLA7RE, L:= LQLA7RE;
#
# MQLA7RE : MONITOR;
#
# QLA6RE : QUADRUPOLE, K1:= K1QLA6RE, L:= LQLA6RE;
#
# MQLA6RE : MONITOR;
#
# QLA5RE : QUADRUPOLE, K1:= K1QLA5RE, L:= LQLA5RE;
#
# MQLA5RE : MONITOR;
#
# BLA4RE : RBEND, ANGLE:= ANGLEBLA4RE, E1:=  .0000000000 * ANGLEBLA4RE, E2:=  .0000000000 * ANGLEBLA4RE, L:= LBLA4RE;
#
# QLA4RE : QUADRUPOLE, K1:= K1QLA4RE, L:= LQLA4RE;
#
# MQLA4RE : MONITOR;
#
# QLA3RE : QUADRUPOLE, K1:= K1QLA3RE, L:= LQLA3RE;
#
# MQLA3RE : MONITOR;
#
# BLA2RE : RBEND, ANGLE:= ANGLEBLA2RE, E1:=  .0000000000 * ANGLEBLA2RE, E2:=  .0000000000 * ANGLEBLA2RE, L:= LBLA2RE;
#
# QLA2RE : QUADRUPOLE, K1:= K1QLA2RE, L:= LQLA2RE;
#
# MQLA2RE : MONITOR;
#
# SLXTRE : SEXTUPOLE, K2:= K2SLXTRE, L:= LSLXTRE;
#
# QLX2RE : QUADRUPOLE, K1:= K1QLX2RE, L:= LQLX2RE;
#
# MQLX2RE1 : MONITOR;
#
# MQLX3RE1 : MONITOR;
#
# QLX3RE : QUADRUPOLE, K1:= K1QLX3RE, L:= LQLX3RE;
#
# BLX1RE : RBEND, ANGLE:= ANGLEBLX1RE, E1:=  .0000000000 * ANGLEBLX1RE, E2:=  .0000000000 * ANGLEBLX1RE, L:= LBLX1RE;
#
# QLX4RE : QUADRUPOLE, K1:= K1QLX4RE, L:= LQLX4RE;
#
# MQLX4RE : MONITOR;
#
# MQLX3RE2 : MONITOR;
#
# MQLX2RE2 : MONITOR;
#
# MQLB8RE : MONITOR;
#
# QLB8RE : QUADRUPOLE, K1:= K1QLB8RE, L:= LQLB8RE;
#
# QLB7RE : QUADRUPOLE, K1:= K1QLB7RE, L:= LQLB7RE;
#
# MQLB7RE : MONITOR;
#
# BLB2RE : RBEND, ANGLE:= ANGLEBLB2RE, E1:=  .0000000000 * ANGLEBLB2RE, E2:=  .0000000000 * ANGLEBLB2RE, L:= LBLB2RE;
#
# QLB4RE : QUADRUPOLE, K1:= K1QLB4RE, L:= LQLB4RE;
#
# MQLB4RE : MONITOR;
#
# QLB1RE : QUADRUPOLE, K1:= K1QLB1RE, L:= LQLB1RE;
#
# MQLB1RE : MONITOR;
#
# SLYTRE1 : SEXTUPOLE, K2:= K2SLYTRE1, L:= LSLYTRE1;
#
# QLY2RE : QUADRUPOLE, K1:= K1QLY2RE, L:= LQLY2RE;
#
# MQLY2RE1 : MONITOR;
#
# MQLY4RE1 : MONITOR;
#
# QLY4RE : QUADRUPOLE, K1:= K1QLY4RE, L:= LQLY4RE;
#
# BLY2RE : RBEND, ANGLE:= ANGLEBLY2RE, E1:=  .0000000000 * ANGLEBLY2RE, E2:=  .0000000000 * ANGLEBLY2RE, L:= LBLY2RE;
#
# QLY5RE : QUADRUPOLE, K1:= K1QLY5RE, L:= LQLY5RE;
#
# MQLY5RE : MONITOR;
#
# MQLY4RE2 : MONITOR;
#
# MQLY2RE2 : MONITOR;
#
# SLYTRE2 : SEXTUPOLE, K2:= K2SLYTRE2, L:= LSLYTRE2;
#
# MQLC7RE : MONITOR;
#
# QLC7RE : QUADRUPOLE, K1:= K1QLC7RE, L:= LQLC7RE;
#
# MQLC6RE : MONITOR;
#
# QLC6RE : QUADRUPOLE, K1:= K1QLC6RE, L:= LQLC6RE;
#
# MQLC5RE : MONITOR;
#
# QLC5RE : QUADRUPOLE, K1:= K1QLC5RE, L:= LQLC5RE;
#
# MQLC3RE : MONITOR;
#
# QLC3RE : QUADRUPOLE, K1:= K1QLC3RE, L:= LQLC3RE;
#
# QKCRE : QUADRUPOLE, L:= LQKCRE;
#
# BLC2RE : RBEND, ANGLE:= ANGLEBLC2RE, E1:=  .0000000000 * ANGLEBLC2RE, E2:=  .0000000000 * ANGLEBLC2RE, L:= LBLC2RE;
#
# QKBRE : QUADRUPOLE, L:= LQKBRE;
#
# QLC2RE : QUADRUPOLE, K1:= K1QLC2RE, L:= LQLC2RE;
#
# MQLC2RE : MONITOR;
#
# QKARE : QUADRUPOLE, L:= LQKARE;
#
# PIRR : MARKER;
#
# QC2RE : QUADRUPOLE, K1:= K1QC2RE, L:= LQC2RE;
#
# QC1RE : QUADRUPOLE, K1:= K1QC1RE, L:= LQC1RE;
#
# QC1RPE : QUADRUPOLE, K1:= K1QC1RPE, L:= LQC1RPE;
#
#
#
# ASCE: SEQUENCE, REFER = CENTRE, L = 3016.3146997061035;
#
# IP.1: IP, at = 0;
#
# QC1LPE.1: QC1LPE, at = .935;
#
# QC1LE.1: QC1LE, at = 1.4099999999999997;
#
# QC2LE.1: QC2LE, at = 2.6999999999999997;
#
# PIRL.1: PIRL, at = 4.000000848561241;
#
# QKALE.1: QKALE, at = 4.272200848561241;
#
# MQLC2LE.1: MQLC2LE, at = 5.675472212498846;
#
# QLC2LE.1: QLC2LE, at = 6.125472212498846;
#
# QKBLE.1: QKBLE, at = 6.827672212498847;
#
# BLC1LE.1: BLC1LE, at = 9.30549277990784;
#
# QKCLE.1: QKCLE, at = 11.788813347316832;
#
# QLC3LE.1: QLC3LE, at = 12.485513347316832;
#
# MQLC3LE.1: MQLC3LE, at = 12.935513347316833;
#
# QLC4LE.1: QLC4LE, at = 18.576101115571383;
#
# MQLC4LE.1: MQLC4LE, at = 19.026101115571382;
#
# MQLC5LE.1: MQLC5LE, at = 21.84684611557138;
#
# QLC5LE.1: QLC5LE, at = 22.29684611557138;
#
# QLC7LE.1: QLC7LE, at = 26.822086114995194;
#
# MQLC7LE.1: MQLC7LE, at = 27.272086114995194;
#
# SLYTLE1.1: SLYTLE1, at = 27.802086114995195;
#
# QLY1LE.1: QLY1LE, at = 28.882086114995197;
#
# MQLY1LE1.1: MQLY1LE1, at = 29.282086114995195;
#
# MQLY2LE1.1: MQLY2LE1, at = 34.43778611499519;
#
# QLY2LE.1: QLY2LE, at = 34.887786114995194;
#
# BLY1LE.1: BLY1LE, at = 38.06780786150992;
#
# QLY3LE.1: QLY3LE, at = 41.247829608024645;
#
# MQLY3LE.1: MQLY3LE, at = 41.69782960802464;
#
# BLY1LE.2: BLY1LE, at = 44.42785135453937;
#
# QLY2LE.2: QLY2LE, at = 47.607873101054096;
#
# MQLY2LE2.1: MQLY2LE2, at = 48.05787310105409;
#
# MQLY1LE2.1: MQLY1LE2, at = 53.21357310105409;
#
# QLY1LE.2: QLY1LE, at = 53.61357310105409;
#
# SLYTLE2.1: SLYTLE2, at = 54.693573101054085;
#
# MQLB1LE.1: MQLB1LE, at = 55.22357310105408;
#
# QLB1LE.1: QLB1LE, at = 55.673573101054075;
#
# MQLB2LE.1: MQLB2LE, at = 60.02351800039512;
#
# QLB2LE.1: QLB2LE, at = 60.47351800039512;
#
# BLB1LE.1: BLB1LE, at = 64.76045387770645;
#
# QLB3LE.1: QLB3LE, at = 68.2553633090906;
#
# MQLB3LE.1: MQLB3LE, at = 68.9853633090906;
#
# QLB4LE.1: QLB4LE, at = 76.72873068004539;
#
# MQLB4LE.1: MQLB4LE, at = 77.17873068004539;
#
# SLXTLE.1: SLXTLE, at = 77.6087306800454;
#
# MQLX1LE1.1: MQLX1LE1, at = 81.63545951549399;
#
# QLX1LE.1: QLX1LE, at = 82.085459515494;
#
# BLX2LE.1: BLX2LE, at = 85.06546059598458;
#
# QLX2LE.1: QLX2LE, at = 88.04546167647514;
#
# MQLX2LE.1: MQLX2LE, at = 88.49546167647514;
#
# BLX2LE.2: BLX2LE, at = 91.02546275696571;
#
# QLX1LE.2: QLX1LE, at = 94.00546383745629;
#
# MQLX1LE2.1: MQLX1LE2, at = 94.45546383745629;
#
# SLXTLE.2: SLXTLE, at = 98.48219267290489;
#
# MQLA2LE.1: MQLA2LE, at = 98.9121926729049;
#
# QLA2LE.1: QLA2LE, at = 99.3621926729049;
#
# QLA3LE.1: QLA3LE, at = 104.75017875618327;
#
# MQLA3LE.1: MQLA3LE, at = 105.20017875618328;
#
# MQLA4LE.1: MQLA4LE, at = 109.46811197793238;
#
# QLA4LE.1: QLA4LE, at = 109.91811197793238;
#
# BLA2LE.1: BLA2LE, at = 113.85457459385438;
#
# QLA5LE.1: QLA5LE, at = 118.49865377860166;
#
# MQLA5LE.1: MQLA5LE, at = 119.09865377860167;
#
# QLA6LE.1: QLA6LE, at = 129.03161396024728;
#
# MQLA6LE.1: MQLA6LE, at = 129.63161396024728;
#
# MQLA7LE.1: MQLA7LE, at = 133.74364655881627;
#
# QLA7LE.1: QLA7LE, at = 134.34364655881626;
#
# BLA4LE.1: BLA4LE, at = 138.5815470463758;
#
# QLA8LE.1: QLA8LE, at = 142.7054475339353;
#
# MQLA8LE.1: MQLA8LE, at = 143.15544753393533;
#
# BLA4LE.2: BLA4LE, at = 146.82934802149484;
#
# QLA9LE.1: QLA9LE, at = 151.06724850905437;
#
# MQLA9LE.1: MQLA9LE, at = 151.66724850905436;
#
# MQLA10LE.1: MQLA10LE, at = 155.13161326481537;
#
# QLA10LE.1: QLA10LE, at = 155.7316132648154;
#
# MQF4E1.1: MQF4E1, at = 159.75217727068798;
#
# PTSULM.1: PTSULM, at = 159.94456227068798;
#
# QF4E.1: QF4E, at = 160.45217727068797;
#
# QD3E.1: QD3E, at = 163.96395844411558;
#
# MQD3E1.1: MQD3E1, at = 164.5639584441156;
#
# SD3TLE.1: SD3TLE, at = 165.2729584441156;
#
# B2E.4: B2E, at = 170.6549626271588;
#
# QF2E.1: QF2E, at = 174.56386281198382;
#
# MQF2E1.1: MQF2E1, at = 175.0138628119838;
#
# QD1E.1: QD1E, at = 179.4536167152629;
#
# MQD1E1.1: MQD1E1, at = 180.15361671526293;
#
# MQF2E2.1: MQF2E2, at = 183.89337061854204;
#
# QF2E.2: QF2E, at = 184.34337061854205;
#
# B2E.5: B2E, at = 188.25227080336705;
#
# SD3TLE.2: SD3TLE, at = 193.63427498641028;
#
# MQD3E2.1: MQD3E2, at = 194.34327498641025;
#
# QD3E.2: QD3E, at = 194.94327498641024;
#
# SKBTLE.1: SKBTLE, at = 197.08905615983787;
#
# QF4E.2: QF4E, at = 198.45505615983785;
#
# MQF4E2.1: MQF4E2, at = 199.15505615983787;
#
# SF4TLE.1: SF4TLE, at = 199.50805615983788;
#
# QEAE.3: QEAE, at = 203.17562016571048;
#
# MQEAE3.1: MQEAE3, at = 203.7756201657105;
#
# QD5E.3: QD5E, at = 208.9270192450203;
#
# MQD5E3.1: MQD5E3, at = 209.5270192450203;
#
# B2E.6: B2E, at = 213.16491942984533;
#
# MQF6E2.1: MQF6E2, at = 216.83881961467034;
#
# QF6E.2: QF6E, at = 217.28881961467033;
#
# B2E.7: B2E, at = 221.41271979949533;
#
# MQD5E4.1: MQD5E4, at = 225.05061998432035;
#
# QD5E.4: QD5E, at = 225.65061998432037;
#
# MQEAE4.1: MQEAE4, at = 230.80201906363015;
#
# QEAE.4: QEAE, at = 231.40201906363018;
#
# SF4TLE.2: SF4TLE, at = 235.06958306950278;
#
# MQF4E3.1: MQF4E3, at = 235.4225830695028;
#
# QF4E.3: QF4E, at = 236.1225830695028;
#
# SKBTLE.2: SKBTLE, at = 237.4885830695028;
#
# QD3E.3: QD3E, at = 239.63436424293042;
#
# MQD3E3.1: MQD3E3, at = 240.2343642429304;
#
# SD5TLE.1: SD5TLE, at = 240.9433642429304;
#
# B2E.8: B2E, at = 246.3253684259736;
#
# QF2E.3: QF2E, at = 250.2342686107986;
#
# MQF2E3.1: MQF2E3, at = 250.68426861079863;
#
# QD1E.2: QD1E, at = 255.12402251407775;
#
# MQD1E2.1: MQD1E2, at = 255.82402251407774;
#
# MQF2E4.1: MQF2E4, at = 259.56377641735685;
#
# QF2E.4: QF2E, at = 260.01377641735684;
#
# B2E.9: B2E, at = 263.9226766021818;
#
# SD5TLE.2: SD5TLE, at = 269.304680785225;
#
# MQD3E4.1: MQD3E4, at = 270.013680785225;
#
# QD3E.4: QD3E, at = 270.613680785225;
#
# SKCTLE.1: SKCTLE, at = 272.75946195865265;
#
# QF4E.4: QF4E, at = 274.12546195865264;
#
# MQF4E4.1: MQF4E4, at = 274.8254619586526;
#
# SF6TLE.1: SF6TLE, at = 275.17846195865263;
#
# QEAE.5: QEAE, at = 278.8460259645252;
#
# MQEAE5.1: MQEAE5, at = 279.4460259645252;
#
# QD5E.5: QD5E, at = 284.597425043835;
#
# MQD5E5.1: MQD5E5, at = 285.197425043835;
#
# B2E.10: B2E, at = 288.83532522866;
#
# MQF6E3.1: MQF6E3, at = 292.509225413485;
#
# QF6E.3: QF6E, at = 292.959225413485;
#
# B2E.11: B2E, at = 297.08312559831;
#
# MQD5E6.1: MQD5E6, at = 300.721025783135;
#
# QD5E.6: QD5E, at = 301.321025783135;
#
# MQEAE6.1: MQEAE6, at = 306.4724248624448;
#
# QEAE.6: QEAE, at = 307.0724248624448;
#
# SF6TLE.2: SF6TLE, at = 310.73998886831737;
#
# MQF4E5.1: MQF4E5, at = 311.0929888683174;
#
# QF4E.5: QF4E, at = 311.79298886831737;
#
# SKCTLE.2: SKCTLE, at = 313.15898886831735;
#
# QD3E.5: QD3E, at = 315.30477004174503;
#
# MQD3E5.1: MQD3E5, at = 315.904770041745;
#
# SD7TLE.1: SD7TLE, at = 316.613770041745;
#
# B2E.12: B2E, at = 321.9957742247882;
#
# QF2E.5: QF2E, at = 325.90467440961316;
#
# MQF2E5.1: MQF2E5, at = 326.35467440961315;
#
# QD1E.3: QD1E, at = 330.79442831289225;
#
# MQD1E3.1: MQD1E3, at = 331.49442831289224;
#
# MQF2E6.1: MQF2E6, at = 335.23418221617135;
#
# QF2E.6: QF2E, at = 335.68418221617134;
#
# B2E.13: B2E, at = 339.5930824009963;
#
# SD7TLE.2: SD7TLE, at = 344.9750865840395;
#
# MQT1TNE1.1: MQT1TNE1, at = 345.6840865840395;
#
# QT1TNE.1: QT1TNE, at = 346.28408658403947;
#
# QT2TNE.1: QT2TNE, at = 350.1972937323912;
#
# MQT2TNE1.1: MQT2TNE1, at = 350.89183373239115;
#
# SF8TNE.1: SF8TNE, at = 351.2502937323911;
#
# QTATNE.1: QTATNE, at = 353.80929373239115;
#
# MQTATNE1.1: MQTATNE1, at = 354.4092937323911;
#
# QT3TNE.1: QT3TNE, at = 358.68210551140373;
#
# MQT3TNE1.1: MQT3TNE1, at = 359.2821055114037;
#
# B2E.14: B2E, at = 363.8040756028903;
#
# MQT4TNE1.1: MQT4TNE1, at = 367.4419757877153;
#
# QT4TNE.1: QT4TNE, at = 368.0419757877153;
#
# MQTBTNE1.1: MQTBTNE1, at = 371.4602121718543;
#
# QTBTNE.1: QTBTNE, at = 372.06021217185435;
#
# MQT5TNE.1: MQT5TNE, at = 375.47844855599334;
#
# QT5TNE.1: QT5TNE, at = 376.0784485559933;
#
# QTBTNE.2: QTBTNE, at = 380.0966849401324;
#
# MQTBTNE2.1: MQTBTNE2, at = 380.69668494013234;
#
# QT4TNE.2: QT4TNE, at = 384.1149213242714;
#
# MQT4TNE2.1: MQT4TNE2, at = 384.71492132427136;
#
# B2E.15: B2E, at = 388.3528215090964;
#
# MQT3TNE2.1: MQT3TNE2, at = 392.87479160058297;
#
# QT3TNE.2: QT3TNE, at = 393.47479160058293;
#
# MQTATNE2.1: MQTATNE2, at = 397.74760337959555;
#
# QTATNE.2: QTATNE, at = 398.3476033795955;
#
# SF8TNE.2: SF8TNE, at = 400.9066033795955;
#
# MQT2TNE2.1: MQT2TNE2, at = 401.2650633795955;
#
# QT2TNE.2: QT2TNE, at = 401.9596033795955;
#
# QT1TNE.2: QT1TNE, at = 405.8728105279472;
#
# MQT1TNE2.1: MQT1TNE2, at = 406.47281052794716;
#
# SD7NRE.1: SD7NRE, at = 407.18181052794716;
#
# B2E.16: B2E, at = 412.56381471099036;
#
# QF2E.7: QF2E, at = 416.47271489581533;
#
# MQF2E7.1: MQF2E7, at = 416.9227148958153;
#
# QD1E.4: QD1E, at = 421.3624687990944;
#
# MQD1E4.1: MQD1E4, at = 422.0624687990944;
#
# MQF2E8.1: MQF2E8, at = 425.8022227023735;
#
# QF2E.8: QF2E, at = 426.2522227023735;
#
# B2E.17: B2E, at = 430.1611228871985;
#
# SD7NRE.2: SD7NRE, at = 435.54312707024167;
#
# MQD3E6.1: MQD3E6, at = 436.25212707024167;
#
# QD3E.6: QD3E, at = 436.85212707024164;
#
# SKCNRE.1: SKCNRE, at = 438.99790824366926;
#
# QF4E.6: QF4E, at = 440.3639082436693;
#
# MQF4E6.1: MQF4E6, at = 441.0639082436693;
#
# SF6NRE.1: SF6NRE, at = 441.41690824366924;
#
# QEAE.7: QEAE, at = 445.0844722495419;
#
# MQEAE7.1: MQEAE7, at = 445.68447224954184;
#
# QD5E.7: QD5E, at = 450.8358713288517;
#
# MQD5E7.1: MQD5E7, at = 451.43587132885165;
#
# B2E.18: B2E, at = 455.07377151367666;
#
# MQF6E4.1: MQF6E4, at = 458.7476716985017;
#
# QF6E.4: QF6E, at = 459.19767169850167;
#
# B2E.19: B2E, at = 463.32157188332667;
#
# MQD5E8.1: MQD5E8, at = 466.9594720681517;
#
# QD5E.8: QD5E, at = 467.55947206815165;
#
# MQEAE8.1: MQEAE8, at = 472.7108711474615;
#
# QEAE.8: QEAE, at = 473.31087114746146;
#
# SF6NRE.2: SF6NRE, at = 476.9784351533341;
#
# MQF4E7.1: MQF4E7, at = 477.3314351533341;
#
# QF4E.7: QF4E, at = 478.0314351533341;
#
# ...
#
# QDWOE.2: QDWOE, at = 2232.4873939240797;
#
# MQFROE2.1: MQFROE2, at = 2241.2131939240794;
#
# QFROE.2: QFROE, at = 2241.9131939240797;
#
# MQDROE3.1: MQDROE3, at = 2250.6389939240794;
#
# QDROE.3: QDROE, at = 2251.3389939240797;
#
# MQFROE3.1: MQFROE3, at = 2260.0647939240794;
#
# PQFROI.1: PQFROI, at = 2260.2248339240796;
#
# QFROE.3: QFROE, at = 2260.7647939240796;
#
# MQDROE4.1: MQDROE4, at = 2269.4905939240793;
#
# QDROE.4: QDROE, at = 2270.1905939240796;
#
# MQFROE4.1: MQFROE4, at = 2278.9163939240793;
#
# QFROE.4: QFROE, at = 2279.6163939240796;
#
# MQDROE5.1: MQDROE5, at = 2288.3421939240793;
#
# QDROE.5: QDROE, at = 2289.0421939240796;
#
# CAAOLE.1: CAAOLE, at = 2292.2635939240795;
#
# CABOLE.1: CABOLE, at = 2295.3565939240793;
#
# MQFROE5.1: MQFROE5, at = 2297.7679939240793;
#
# QFROE.5: QFROE, at = 2298.4679939240796;
#
# CACOLE.1: CACOLE, at = 2301.6893939240795;
#
# CADOLE.1: CADOLE, at = 2304.7823939240793;
#
# MQDROE6.1: MQDROE6, at = 2307.1937939240793;
#
# QDROE.6: QDROE, at = 2307.8937939240795;
#
# CAEOLE.1: CAEOLE, at = 2311.1151939240794;
#
# CAFOLE.1: CAFOLE, at = 2314.2081939240793;
#
# MQR2OLE.1: MQR2OLE, at = 2316.6195939240793;
#
# QR2OLE.1: QR2OLE, at = 2317.3195939240795;
#
# CAGOLE.1: CAGOLE, at = 2320.5409939240794;
#
# CAHOLE.1: CAHOLE, at = 2323.6339939240793;
#
# MQR3OLE.1: MQR3OLE, at = 2326.0453939240792;
#
# QR3OLE.1: QR3OLE, at = 2326.7453939240795;
#
# MQR4OLE.1: MQR4OLE, at = 2335.471193924079;
#
# QR4OLE.1: QR4OLE, at = 2336.1711939240795;
#
# MQR5OLE.1: MQR5OLE, at = 2344.896993924079;
#
# QR5OLE.1: QR5OLE, at = 2345.5969939240795;
#
# MQR6OLE.1: MQR6OLE, at = 2356.618848666588;
#
# QR6OLE.1: QR6OLE, at = 2357.3188486665877;
#
# QR7OLE.1: QR7OLE, at = 2361.117248666588;
#
# MQR7OLE.1: MQR7OLE, at = 2361.7172486665877;
#
# POHOLM.1: POHOLM, at = 2365.6772486754394;
#
# BSWOLE.1: BSWOLE, at = 2367.127248666588;
#
# QS2OLE.1: QS2OLE, at = 2369.7761486577365;
#
# MQS2OLE.1: MQS2OLE, at = 2370.2261486577368;
#
# B2E.84: B2E, at = 2373.928948842562;
#
# QS3OLE.1: QS3OLE, at = 2377.996849027387;
#
# MQS3OLE.1: MQS3OLE, at = 2378.596849027387;
#
# MQSBOE2.1: MQSBOE2, at = 2381.146506337253;
#
# QSBOE.2: QSBOE, at = 2381.746506337253;
#
# QS4OE.2: QS4OE, at = 2384.5799439038706;
#
# MQS4OE2.1: MQS4OE2, at = 2385.1799439038705;
#
# SF2OLE.1: SF2OLE, at = 2385.5389439038704;
#
# QEAE.37: QEAE, at = 2389.206507909743;
#
# MQEAE37.1: MQEAE37, at = 2389.806507909743;
#
# QD5E.37: QD5E, at = 2394.9579069890524;
#
# MQD5E37.1: MQD5E37, at = 2395.5579069890523;
#
# B2E.85: B2E, at = 2399.1958071738773;
#
# MQF6E19.1: MQF6E19, at = 2402.8697073587023;
#
# QF6E.19: QF6E, at = 2403.3197073587025;
#
# B2E.86: B2E, at = 2407.4436075435274;
#
# MQD5E38.1: MQD5E38, at = 2411.0815077283523;
#
# QD5E.38: QD5E, at = 2411.6815077283522;
#
# MQEAE38.1: MQEAE38, at = 2416.832906807662;
#
# QEAE.38: QEAE, at = 2417.4329068076618;
#
# SF2OLE.2: SF2OLE, at = 2421.1004708135342;
#
# MQF4E31.1: MQF4E31, at = 2421.4534708135343;
#
# QF4E.31: QF4E, at = 2422.153470813534;
#
# QD3E.31: QD3E, at = 2425.6652519869617;
#
# MQD3E31.1: MQD3E31, at = 2426.2652519869616;
#
# SD3OLE.1: SD3OLE, at = 2426.9742519869615;
#
# B2E.87: B2E, at = 2432.356256170005;
#
# QF2E.37: QF2E, at = 2436.2651563548307;
#
# MQF2E37.1: MQF2E37, at = 2436.7151563548305;
#
# MQD1E19.1: MQD1E19, at = 2440.4549102581095;
#
# QD1E.19: QD1E, at = 2441.1549102581093;
#
# MQF2E38.1: MQF2E38, at = 2445.594664161389;
#
# QF2E.38: QF2E, at = 2446.044664161389;
#
# B2E.88: B2E, at = 2449.9535643462145;
#
# SD3OLE.2: SD3OLE, at = 2455.335568529258;
#
# MQD3E32.1: MQD3E32, at = 2456.044568529258;
#
# QD3E.32: QD3E, at = 2456.644568529258;
#
# QF4E.32: QF4E, at = 2460.1563497026855;
#
# MQF4E32.1: MQF4E32, at = 2460.8563497026853;
#
# SF4OLE.1: SF4OLE, at = 2461.2093497026854;
#
# QEAE.39: QEAE, at = 2464.876913708558;
#
# MQEAE39.1: MQEAE39, at = 2465.4769137085577;
#
# QD5E.39: QD5E, at = 2470.6283127878673;
#
# MQD5E39.1: MQD5E39, at = 2471.2283127878673;
#
# B2E.89: B2E, at = 2474.866212972692;
#
# MQF6E20.1: MQF6E20, at = 2478.540113157517;
#
# QF6E.20: QF6E, at = 2478.990113157517;
#
# B2E.90: B2E, at = 2483.1140133423423;
#
# MQD5E40.1: MQD5E40, at = 2486.7519135271673;
#
# QD5E.40: QD5E, at = 2487.351913527167;
#
# MQEAE40.1: MQEAE40, at = 2492.503312606477;
#
# QEAE.40: QEAE, at = 2493.1033126064767;
#
# SF4OLE.2: SF4OLE, at = 2496.770876612349;
#
# MQF4E33.1: MQF4E33, at = 2497.1238766123492;
#
# QF4E.33: QF4E, at = 2497.823876612349;
#
# QD3E.33: QD3E, at = 2501.3356577857767;
#
# MQD3E33.1: MQD3E33, at = 2501.9356577857766;
#
# SD5OLE.1: SD5OLE, at = 2502.644657785777;
#
# B2E.91: B2E, at = 2508.02666196882;
#
# QF2E.39: QF2E, at = 2511.935562153645;
#
# MQF2E39.1: MQF2E39, at = 2512.3855621536454;
#
# MQD1E20.1: MQD1E20, at = 2516.1253160569245;
#
# QD1E.20: QD1E, at = 2516.8253160569243;
#
# MQF2E40.1: MQF2E40, at = 2521.265069960204;
#
# QF2E.40: QF2E, at = 2521.7150699602043;
#
# B2E.92: B2E, at = 2525.6239701450295;
#
# SD5OLE.2: SD5OLE, at = 2531.0059743280726;
#
# MQD3E34.1: MQD3E34, at = 2531.714974328073;
#
# QD3E.34: QD3E, at = 2532.314974328073;
#
# QF4E.34: QF4E, at = 2535.8267555015004;
#
# MQF4E34.1: MQF4E34, at = 2536.5267555015002;
#
# SF6OLE.1: SF6OLE, at = 2536.8797555015003;
#
# QEAE.41: QEAE, at = 2540.547319507373;
#
# MQEAE41.1: MQEAE41, at = 2541.1473195073727;
#
# QD5E.41: QD5E, at = 2546.2987185866823;
#
# MQD5E41.1: MQD5E41, at = 2546.898718586682;
#
# B2E.93: B2E, at = 2550.536618771507;
#
# MQF6E21.1: MQF6E21, at = 2554.210518956332;
#
# QF6E.21: QF6E, at = 2554.6605189563325;
#
# B2E.94: B2E, at = 2558.7844191411573;
#
# MQD5E42.1: MQD5E42, at = 2562.4223193259822;
#
# QD5E.42: QD5E, at = 2563.022319325982;
#
# MQEAE42.1: MQEAE42, at = 2568.1737184052918;
#
# QEAE.42: QEAE, at = 2568.7737184052917;
#
# SF6OLE.2: SF6OLE, at = 2572.441282411164;
#
# MQF4E35.1: MQF4E35, at = 2572.794282411164;
#
# QF4E.35: QF4E, at = 2573.494282411164;
#
# QD3E.35: QD3E, at = 2577.0060635845916;
#
# MQD3E35.1: MQD3E35, at = 2577.6060635845915;
#
# SD7OLE.1: SD7OLE, at = 2578.3150635845914;
#
# B2E.95: B2E, at = 2583.697067767635;
#
# QF2E.41: QF2E, at = 2587.6059679524606;
#
# MQF2E41.1: MQF2E41, at = 2588.0559679524604;
#
# MQD1E21.1: MQD1E21, at = 2591.7957218557394;
#
# QD1E.21: QD1E, at = 2592.4957218557392;
#
# MQF2E42.1: MQF2E42, at = 2596.935475759019;
#
# QF2E.42: QF2E, at = 2597.385475759019;
#
# B2E.96: B2E, at = 2601.2943759438444;
#
# SD7OLE.2: SD7OLE, at = 2606.676380126888;
#
# MQT1OTE1.1: MQT1OTE1, at = 2607.385380126888;
#
# QT1OTE.1: QT1OTE, at = 2607.985380126888;
#
# QT2OTE.1: QT2OTE, at = 2611.9235465329457;
#
# MQT2OTE1.1: MQT2OTE1, at = 2612.6180865329457;
#
# SF8OTE.1: SF8OTE, at = 2612.9765465329456;
#
# QTAOTE.1: QTAOTE, at = 2615.5355465329453;
#
# MQTAOTE1.1: MQTAOTE1, at = 2616.135546532945;
#
# QT3OTE.1: QT3OTE, at = 2620.4512297604897;
#
# MQT3OTE1.1: MQT3OTE1, at = 2621.0512297604896;
#
# B2E.97: B2E, at = 2625.6538168142115;
#
# MQT4OTE1.1: MQT4OTE1, at = 2629.2917169990365;
#
# QT4OTE.1: QT4OTE, at = 2629.8917169990364;
#
# MQTBOTE1.1: MQTBOTE1, at = 2633.4802239978253;
#
# QTBOTE.1: QTBOTE, at = 2634.0802239978248;
#
# MQT5OTE.1: MQT5OTE, at = 2637.668730996614;
#
# QT5OTE.1: QT5OTE, at = 2638.268730996614;
#
# QTBOTE.2: QTBOTE, at = 2642.4572379954034;
#
# MQTBOTE2.1: MQTBOTE2, at = 2643.057237995403;
#
# QT4OTE.2: QT4OTE, at = 2646.645744994192;
#
# MQT4OTE2.1: MQT4OTE2, at = 2647.2457449941917;
#
# B2E.98: B2E, at = 2650.8836451790166;
#
# MQT3OTE2.1: MQT3OTE2, at = 2655.4862322327385;
#
# QT3OTE.2: QT3OTE, at = 2656.0862322327384;
#
# MQTAOTE2.1: MQTAOTE2, at = 2660.401915460283;
#
# QTAOTE.2: QTAOTE, at = 2661.001915460283;
#
# SF8OTE.2: SF8OTE, at = 2663.5609154602826;
#
# MQT2OTE2.1: MQT2OTE2, at = 2663.9193754602825;
#
# QT2OTE.2: QT2OTE, at = 2664.6139154602824;
#
# QT1OTE.2: QT1OTE, at = 2668.5520818663404;
#
# MQT1OTE2.1: MQT1OTE2, at = 2669.1520818663403;
#
# SD7TRE.1: SD7TRE, at = 2669.86108186634;
#
# B2E.99: B2E, at = 2675.2430860493837;
#
# QF2E.43: QF2E, at = 2679.1519862342093;
#
# MQF2E43.1: MQF2E43, at = 2679.601986234209;
#
# MQD1E22.1: MQD1E22, at = 2683.341740137488;
#
# QD1E.22: QD1E, at = 2684.041740137488;
#
# MQF2E44.1: MQF2E44, at = 2688.4814940407678;
#
# QF2E.44: QF2E, at = 2688.9314940407676;
#
# B2E.100: B2E, at = 2692.840394225593;
#
# SD7TRE.2: SD7TRE, at = 2698.2223984086368;
#
# MQD3E36.1: MQD3E36, at = 2698.9313984086366;
#
# QD3E.36: QD3E, at = 2699.5313984086365;
#
# QF4E.36: QF4E, at = 2703.043179582064;
#
# MQF4E36.1: MQF4E36, at = 2703.743179582064;
#
# SF6TRE.1: SF6TRE, at = 2704.096179582064;
#
# QEAE.43: QEAE, at = 2707.7637435879365;
#
# MQEAE43.1: MQEAE43, at = 2708.3637435879364;
#
# QD5E.43: QD5E, at = 2713.515142667246;
#
# MQD5E43.1: MQD5E43, at = 2714.115142667246;
#
# B2E.101: B2E, at = 2717.753042852071;
#
# MQF6E22.1: MQF6E22, at = 2721.426943036896;
#
# QF6E.22: QF6E, at = 2721.8769430368957;
#
# B2E.102: B2E, at = 2726.000843221721;
#
# MQD5E44.1: MQD5E44, at = 2729.638743406546;
#
# QD5E.44: QD5E, at = 2730.238743406546;
#
# MQEAE44.1: MQEAE44, at = 2735.3901424858554;
#
# QEAE.44: QEAE, at = 2735.9901424858554;
#
# SF6TRE.2: SF6TRE, at = 2739.657706491728;
#
# MQF4E37.1: MQF4E37, at = 2740.010706491728;
#
# QF4E.37: QF4E, at = 2740.7107064917277;
#
# QD3E.37: QD3E, at = 2744.2224876651553;
#
# MQD3E37.1: MQD3E37, at = 2744.822487665155;
#
# SD5TRE.1: SD5TRE, at = 2745.5314876651555;
#
# B2E.103: B2E, at = 2750.9134918481986;
#
# QF2E.45: QF2E, at = 2754.822392033024;
#
# MQF2E45.1: MQF2E45, at = 2755.272392033024;
#
# MQD1E23.1: MQD1E23, at = 2759.012145936303;
#
# QD1E.23: QD1E, at = 2759.712145936303;
#
# MQF2E46.1: MQF2E46, at = 2764.1518998395827;
#
# QF2E.46: QF2E, at = 2764.601899839583;
#
# B2E.104: B2E, at = 2768.510800024408;
#
# SD5TRE.2: SD5TRE, at = 2773.8928042074513;
#
# MQD3E38.1: MQD3E38, at = 2774.6018042074516;
#
# QD3E.38: QD3E, at = 2775.2018042074515;
#
# QF4E.38: QF4E, at = 2778.713585380879;
#
# MQF4E38.1: MQF4E38, at = 2779.413585380879;
#
# SF4TRE.1: SF4TRE, at = 2779.766585380879;
#
# QEAE.45: QEAE, at = 2783.4341493867514;
#
# MQEAE45.1: MQEAE45, at = 2784.0341493867513;
#
# QD5E.45: QD5E, at = 2789.185548466061;
#
# MQD5E45.1: MQD5E45, at = 2789.785548466061;
#
# B2E.105: B2E, at = 2793.423448650886;
#
# MQF6E23.1: MQF6E23, at = 2797.097348835711;
#
# QF6E.23: QF6E, at = 2797.547348835711;
#
# B2E.106: B2E, at = 2801.671249020536;
#
# MQD5E46.1: MQD5E46, at = 2805.309149205361;
#
# QD5E.46: QD5E, at = 2805.909149205361;
#
# MQEAE46.1: MQEAE46, at = 2811.0605482846704;
#
# QEAE.46: QEAE, at = 2811.6605482846703;
#
# SF4TRE.2: SF4TRE, at = 2815.328112290543;
#
# MQF4E39.1: MQF4E39, at = 2815.681112290543;
#
# QF4E.39: QF4E, at = 2816.3811122905427;
#
# QD3E.39: QD3E, at = 2819.8928934639703;
#
# MQD3E39.1: MQD3E39, at = 2820.49289346397;
#
# SD3TRE.1: SD3TRE, at = 2821.20189346397;
#
# B2E.107: B2E, at = 2826.5838976470136;
#
# QF2E.47: QF2E, at = 2830.492797831839;
#
# MQF2E47.1: MQF2E47, at = 2830.942797831839;
#
# MQD1E24.1: MQD1E24, at = 2834.682551735118;
#
# QD1E.24: QD1E, at = 2835.382551735118;
#
# MQF2E48.1: MQF2E48, at = 2839.8223056383977;
#
# QF2E.48: QF2E, at = 2840.2723056383975;
#
# B2E.108: B2E, at = 2844.181205823223;
#
# SD3TRE.2: SD3TRE, at = 2849.5632100062667;
#
# MQD3E40.1: MQD3E40, at = 2850.2722100062665;
#
# QD3E.40: QD3E, at = 2850.8722100062664;
#
# QF4E.40: QF4E, at = 2854.383991179694;
#
# PTSURM.1: PTSURM, at = 2854.891606179694;
#
# MQF4E40.1: MQF4E40, at = 2855.083991179694;
#
# QLA10RE.1: QLA10RE, at = 2859.1045551855664;
#
# MQLA10RE.1: MQLA10RE, at = 2859.7045551855663;
#
# MQLA9RE.1: MQLA9RE, at = 2863.9595666464897;
#
# QLA9RE.1: QLA9RE, at = 2864.5595666464897;
#
# BLA6RE.1: BLA6RE, at = 2868.797466693119;
#
# QLA8RE.1: QLA8RE, at = 2872.921366739748;
#
# MQLA8RE.1: MQLA8RE, at = 2873.3713667397483;
#
# BLA6RE.2: BLA6RE, at = 2877.0452667863774;
#
# QLA7RE.1: QLA7RE, at = 2881.283166833007;
#
# MQLA7RE.1: MQLA7RE, at = 2881.8831668330067;
#
# QLA6RE.1: QLA6RE, at = 2889.828661447845;
#
# MQLA6RE.1: MQLA6RE, at = 2890.428661447845;
#
# QLA5RE.1: QLA5RE, at = 2893.989123466029;
#
# MQLA5RE.1: MQLA5RE, at = 2894.589123466029;
#
# BLA4RE.1: BLA4RE, at = 2901.0980395299375;
#
# QLA4RE.1: QLA4RE, at = 2905.3111605133936;
#
# MQLA4RE.1: MQLA4RE, at = 2905.7611605133934;
#
# QLA3RE.1: QLA3RE, at = 2911.2641279553054;
#
# MQLA3RE.1: MQLA3RE, at = 2911.7141279553057;
#
# BLA2RE.1: BLA2RE, at = 2915.273369058934;
#
# QLA2RE.1: QLA2RE, at = 2920.528087257102;
#
# MQLA2RE.1: MQLA2RE, at = 2920.978087257102;
#
# SLXTRE.1: SLXTRE, at = 2921.4080872571017;
#
# QLX2RE.1: QLX2RE, at = 2922.8880872571017;
#
# MQLX2RE1.1: MQLX2RE1, at = 2923.338087257102;
#
# MQLX3RE1.1: MQLX3RE1, at = 2925.485597991543;
#
# QLX3RE.1: QLX3RE, at = 2925.9355979915426;
#
# BLX1RE.1: BLX1RE, at = 2928.915598782125;
#
# QLX4RE.1: QLX4RE, at = 2931.8955995727074;
#
# MQLX4RE.1: MQLX4RE, at = 2932.345599572707;
#
# BLX1RE.2: BLX1RE, at = 2934.8756003632893;
#
# QLX3RE.2: QLX3RE, at = 2937.8556011538712;
#
# MQLX3RE2.1: MQLX3RE2, at = 2938.3056011538715;
#
# MQLX2RE2.1: MQLX2RE2, at = 2940.4531118883124;
#
# QLX2RE.2: QLX2RE, at = 2940.903111888312;
#
# SLXTRE.2: SLXTRE, at = 2942.3831118883127;
#
# MQLB8RE.1: MQLB8RE, at = 2942.8131118883125;
#
# QLB8RE.1: QLB8RE, at = 2943.263111888313;
#
# QLB7RE.1: QLB7RE, at = 2947.6610008371313;
#
# MQLB7RE.1: MQLB7RE, at = 2948.3910008371313;
#
# BLB2RE.1: BLB2RE, at = 2951.6070794231255;
#
# QLB4RE.1: QLB4RE, at = 2957.411573488381;
#
# MQLB4RE.1: MQLB4RE, at = 2957.8615734883806;
#
# QLB1RE.1: QLB1RE, at = 2960.54187335194;
#
# MQLB1RE.1: MQLB1RE, at = 2960.99187335194;
#
# SLYTRE1.1: SLYTRE1, at = 2961.5218733519396;
#
# QLY2RE.1: QLY2RE, at = 2962.60187335194;
#
# MQLY2RE1.1: MQLY2RE1, at = 2963.00187335194;
#
# MQLY4RE1.1: MQLY4RE1, at = 2968.2575733519398;
#
# QLY4RE.1: QLY4RE, at = 2968.7075733519396;
#
# BLY2RE.1: BLY2RE, at = 2971.887595094857;
#
# QLY5RE.1: QLY5RE, at = 2975.067616837774;
#
# MQLY5RE.1: MQLY5RE, at = 2975.517616837774;
#
# BLY2RE.2: BLY2RE, at = 2978.247638580691;
#
# QLY4RE.2: QLY4RE, at = 2981.4276603236076;
#
# MQLY4RE2.1: MQLY4RE2, at = 2981.877660323608;
#
# MQLY2RE2.1: MQLY2RE2, at = 2987.1333603236076;
#
# QLY2RE.2: QLY2RE, at = 2987.5333603236077;
#
# SLYTRE2.1: SLYTRE2, at = 2988.6133603236076;
#
# MQLC7RE.1: MQLC7RE, at = 2989.143360323608;
#
# QLC7RE.1: QLC7RE, at = 2989.593360323608;
#
# MQLC6RE.1: MQLC6RE, at = 2993.5686003208098;
#
# QLC6RE.1: QLC6RE, at = 2994.01860032081;
#
# MQLC5RE.1: MQLC5RE, at = 2997.28934532081;
#
# QLC5RE.1: QLC5RE, at = 2997.7393453208097;
#
# MQLC3RE.1: MQLC3RE, at = 3003.379933089625;
#
# QLC3RE.1: QLC3RE, at = 3003.8299330896252;
#
# QKCRE.1: QKCRE, at = 3004.532133089625;
#
# BLC2RE.1: BLC2RE, at = 3007.009953652606;
#
# QKBRE.1: QKBRE, at = 3009.487774215587;
#
# QLC2RE.1: QLC2RE, at = 3010.1899742155865;
#
# MQLC2RE.1: MQLC2RE, at = 3010.639974215587;
#
# QKARE.1: QKARE, at = 3012.0424987333963;
#
# PIRR.1: PIRR, at = 3012.314698733396;
#
# QC2RE.1: QC2RE, at = 3013.389699706104;
#
# QC1RE.1: QC1RE, at = 3014.9046997061037;
#
# QC1RPE.1: QC1RPE, at = 3015.3796997061036;
#
# IP.2: IP, at = 3016.3146997061035;
#
# ENDSEQUENCE;
#
# enter Twiss module
#
# iteration:   1 error:   0.000000E+00 deltap:   0.000000E+00
# orbit:   0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00
# ++++++ warning: TWCLORB:  Longitudinal plane might be unstable. Try change lag with 0.5. More information with the debug flag on.
#
# ++++++ table: summ
#
#              length              orbit5                alfa             gammatr
# 3016.314699706129431  -0.000000000000000   0.000458134428809  46.720075387290322
#
#                  q1                 dq1             betxmax               dxmax
#  45.605695297130936  -0.585328311197600 433.597678035253693   0.834592884009531
#
#               dxrms              xcomax              xcorms                  q2
#   0.400100952592379   0.000000000000000   0.000000000000000  43.678269681571095
#
#                 dq2             betymax               dymax               dyrms
#  -2.137867159556104 1447.992588108123300   0.000000000000000   0.000000000000000
#
#              ycomax              ycorms              deltap             synch_1
#   0.000000000000000   0.000000000000000   0.000000000000000   0.000000000000000
#
#             synch_2             synch_3             synch_4             synch_5
#   0.000000000000000   0.000000000000000   0.000000000000000   0.000000000000000
#
#             synch_6             synch_8              nflips               dqmin
#   0.000000000000000   0.000000000000000   0.000000000000000   0.000000000000000
#
#         dqmin_phase
#  -2.140447564926907
# Converting sequence "asce":   0%|          | 0/2475 [00:00<?, ?it/s]
# Line Built from MADX Sequence

# %% [markdown]
# ## Slicing

# %%
# define strategy for elements and perform slicing
slicing_strategies = [
    Strategy(slicing=Teapot(1)),  # Default catch-all as in MAD-X
    Strategy(slicing=Teapot(4), element_type=xt.Bend),
    Strategy(slicing=Teapot(5), element_type=xt.Quadrupole),
    Strategy(slicing=Teapot(4), element_type=xt.Sextupole),
]

ler.discard_tracker()
her.discard_tracker()
print("Slicing thick elements...")
ler.slice_thick_elements(slicing_strategies)
her.slice_thick_elements(slicing_strategies)
# Out:
# Slicing thick elements...
# Slicing line:   0%|          | 0/2629 [00:00<?, ?it/s]
# Slicing line:   0%|          | 0/2475 [00:00<?, ?it/s]

# %% [markdown]
# ## Build Reference Particles

# %%
ler_ref_particle = xp.Particles(
    mass0   = xp.ELECTRON_MASS_EV,
    q0      = 1,
    p0c     = ler_params['p0c']
    )
her_ref_particle = xp.Particles(
    mass0   = xp.ELECTRON_MASS_EV,
    q0      = -1,
    p0c     = her_params['p0c']
    )
ler.particle_ref = ler_ref_particle
her.particle_ref = her_ref_particle

ler.build_tracker()
her.build_tracker()
ler.config.XTRACK_USE_EXACT_DRIFTS = True
her.config.XTRACK_USE_EXACT_DRIFTS = True
# Out:
# Found suitable prebuilt kernel `default_only_xtrack`.
# Found suitable prebuilt kernel `default_only_xtrack`.

# %% [markdown]
# ## Correct RF

# %%
ler_table = ler.get_table()
ler_cavities = ler_table.rows[ler_table.element_type=='Cavity']

for nn in ler_cavities.name:
    ler.element_refs[nn].lag = 180

# %%
her_table = her.get_table()
her_cavities = her_table.rows[her_table.element_type=='Cavity']

for nn in her_cavities.name:
    her.element_refs[nn].lag = 180

# %% [markdown]
# ## Twiss in XSuite

# %%
ler_tw_4d = ler.twiss(eneloss_and_damping=False, method="4d")
print(f"LER: {(ler_tw_4d.qx, ler_tw_4d.qy)}")
her_tw_4d = her.twiss(eneloss_and_damping=False, method="4d")
print(f"HER: {(her_tw_4d.qx, her_tw_4d.qy)}")
# Out:
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# LER: (44.61091643171956, 46.248745180309996)
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# HER: (45.600806796500564, 43.67092339546591)

# %% [markdown]
# ## Configure Radiation

# %%
ler.configure_radiation(model='mean')
ler.compensate_radiation_energy_loss()

her.configure_radiation(model='mean')
her.compensate_radiation_energy_loss()
# Out:
# Compensating energy loss.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Share energy loss among cavities (repeat until energy loss is zero)
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Energy loss: 376761.869 eV
# Energy loss: 63.033 eV
# Energy loss: 0.011 eV
#
#   - Set delta_taper
#   - Restore cavity voltage and frequency. Set cavity lag
# Compensating energy loss.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Share energy loss among cavities (repeat until energy loss is zero)
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Energy loss: 2089654.724 eV
# Energy loss: 1509.096 eV
# Energy loss: 1.090 eV
# Energy loss: 0.001 eV
#
#   - Set delta_taper
#   - Restore cavity voltage and frequency. Set cavity lag

# %% [markdown]
# ## Vertical Emittance Matching

# %%
# TODO Do this with sextupole offset tuning

# %% [markdown]
# ## Twiss

# %%
ler_tw_rad = ler.twiss(eneloss_and_damping=True, method="6d")
print(f"LER: {(ler_tw_rad['eq_gemitt_x'], ler_tw_rad['eq_gemitt_y'])}")
# Out:
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# LER: (5.696751003226023e-09, 5.198292435005103e-13)

# %%
her_tw_rad = her.twiss(eneloss_and_damping=True, method="6d")
print(f"HER: {(her_tw_rad['eq_gemitt_x'], her_tw_rad['eq_gemitt_y'])}")
# Out:
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# HER: (5.402063336979289e-09, 2.191428230209451e-37)

# %% [markdown]
# ### HER

# %%
print((her_params['beta_x'], her_params['beta_y']))
print((min(her_tw_rad['betx']), min(her_tw_rad['bety'])))

fig, ax1 = plt.subplots()

ax1.set_xlabel('Component', c='b')
ax1.set_ylabel('Beta_x', c='b')
ax1.plot(her_tw_rad['betx'], c='b')
ax1.tick_params(axis='y', color='b')

ax2 = ax1.twinx()
ax2.set_ylabel('Beta_y', c='orange')
ax2.plot(her_tw_rad['bety'], c='orange')
ax2.tick_params(axis='y', color='orange')

plt.show()

fig, ax1 = plt.subplots()

ax1.set_xlabel('Component', c='b')
ax1.set_ylabel('Dx', c='b')
ax1.plot(her_tw_rad['dx'], c='b')
ax1.tick_params(axis='y', color='b')

ax2 = ax1.twinx()
ax2.set_ylabel('Dy', c='orange')
ax2.plot(her_tw_rad['dy'], c='orange')
ax2.tick_params(axis='y', color='orange')

plt.show()
# Out:
# (0.06, 0.001)
# (0.06751166849488763, 0.0011786797367039188)

# %% [markdown]
# ### LER

# %%
print((ler_params['beta_x'], ler_params['beta_y']))
print((min(ler_tw_rad['betx']), min(ler_tw_rad['bety'])))

fig, ax1 = plt.subplots()

ax1.set_xlabel('Component', c='b')
ax1.set_ylabel('Beta_x', c='b')
ax1.plot(ler_tw_rad['betx'], c='b')
ax1.tick_params(axis='y', color='b')

ax2 = ax1.twinx()
ax2.set_ylabel('Beta_y', c='orange')
ax2.plot(ler_tw_rad['bety'], c='orange')
ax2.tick_params(axis='y', color='orange')

plt.show()

fig, ax1 = plt.subplots()

ax1.set_xlabel('Component', c='b')
ax1.set_ylabel('Dx', c='b')
ax1.plot(ler_tw_rad['dx'], c='b')
ax1.tick_params(axis='y', color='b')

ax2 = ax1.twinx()
ax2.set_ylabel('Dy', c='orange')
ax2.plot(ler_tw_rad['dy'], c='orange')
ax2.tick_params(axis='y', color='orange')

plt.show()
# Out:
# (0.08, 0.001)
# (0.07074241907486278, 0.0012068272261438803)

# %% [markdown]
# ## Generate Particles

# %%
# electrons = xp.generate_matched_gaussian_bunch(
#     num_particles               = n_macroparticles,
#     total_intensity_particles   = her_params['bunch_intensity'],
#     nemitt_x                    = her_tw_rad['eq_nemitt_x'],
#     nemitt_y                    = her_tw_rad['eq_nemitt_y'],
#     sigma_z                     = np.sqrt(her_tw_rad['bets0'] * her_tw_rad['eq_gemitt_zeta']),
#     line                        = her
# )   
# electrons.name = "electrons"
# electrons._init_random_number_generator() # pylint:disable=protected-access

# positrons = xp.generate_matched_gaussian_bunch(
#     num_particles               = n_macroparticles,
#     total_intensity_particles   = ler_params['bunch_intensity'],
#     nemitt_x                    = ler_tw_rad['eq_nemitt_x'],
#     nemitt_y                    = ler_tw_rad['eq_nemitt_y'],
#     sigma_z                     = np.sqrt(ler_tw_rad['bets0'] * ler_tw_rad['eq_gemitt_zeta']),
#     line                        = ler
# )   
# positrons.name = "positrons"
# positrons._init_random_number_generator() # pylint:disable=protected-access

# %% [markdown]
# # FOR NOW USE VERTICAL EMIT FROM LER FOR BOTH BECAUSE OF ISSUE WITH VERTICAL

# %%
electrons = xp.generate_matched_gaussian_bunch(
    num_particles               = n_macroparticles,
    total_intensity_particles   = her_params['bunch_intensity'],
    nemitt_x                    = her_tw_rad['eq_nemitt_x'],
    nemitt_y                    = ler_tw_rad['eq_nemitt_y'],
    sigma_z                     = np.sqrt(her_tw_rad['bets0'] * her_tw_rad['eq_gemitt_zeta']),
    line                        = her
)   
electrons.name = "electrons"
electrons._init_random_number_generator() # pylint:disable=protected-access

positrons = xp.generate_matched_gaussian_bunch(
    num_particles               = n_macroparticles,
    total_intensity_particles   = ler_params['bunch_intensity'],
    nemitt_x                    = ler_tw_rad['eq_nemitt_x'],
    nemitt_y                    = ler_tw_rad['eq_nemitt_y'],
    sigma_z                     = np.sqrt(ler_tw_rad['bets0'] * ler_tw_rad['eq_gemitt_zeta']),
    line                        = ler
)   
positrons.name = "positrons"
positrons._init_random_number_generator() # pylint:disable=protected-access

# %% [markdown]
# ## Add Beam Beam Elements

# %% [markdown]
# ### Slicer

# %%
ler_slicer = xf.TempSlicer(
    n_slices    = n_slices,
    sigma_z     = np.sqrt(ler_tw_rad['bets0'] * ler_tw_rad['eq_gemitt_zeta']), 
    mode        = "shatilov"
)
her_slicer = xf.TempSlicer(
    n_slices    = n_slices,
    sigma_z     = np.sqrt(her_tw_rad['bets0'] * her_tw_rad['eq_gemitt_zeta']),
    mode        = "shatilov"
)
# Out:
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.

# %% [markdown]
# ## Pipeline

# %%
pipeline_manager = xt.PipelineManager()

pipeline_manager.add_particles('electrons',0)
pipeline_manager.add_particles('positrons',0)

pipeline_manager.add_element('IP')

electrons.init_pipeline('electrons')
positrons.init_pipeline('positrons')

# %% [markdown]
# ### Update Configurations

# %%
config_IP_her = xf.ConfigForUpdateBeamBeamBiGaussian3D(
   pipeline_manager        = pipeline_manager,
   element_name            = 'IP',
   partner_particles_name  = 'positrons',
   slicer                  = her_slicer,
   update_every            = 1,
)

config_IP_ler = xf.ConfigForUpdateBeamBeamBiGaussian3D(
   pipeline_manager        = pipeline_manager,
   element_name            = 'IP',
   partner_particles_name  = 'electrons',
   slicer                  = ler_slicer,
   update_every            = 1,
)

# %% [markdown]
# ### Beam Beam Elements

# %%
bbeam_ler = xf.BeamBeamBiGaussian3D(
    _context            = context,
    other_beam_q0       = electrons.q0,
    phi                 = ler_params['phi'],
    alpha               = 0,
    config_for_update   = config_IP_ler,
    flag_luminosity     = 1,
)
bbeam_her = xf.BeamBeamBiGaussian3D(
    _context            = context,
    other_beam_q0       = positrons.q0,
    phi                 = her_params['phi'],
    alpha               = 0,
    config_for_update   = config_IP_her,
    flag_luminosity     = 1,
)

# %% [markdown]
# ### Insert BB Elements

# %%
ler.discard_tracker()
her.discard_tracker()

ler.insert_element(
    index   = 'ip.2',
    element = bbeam_ler,
    name    = f'beambeam_ler'
)

her.insert_element(
    index   = 'ip.2',
    element = bbeam_her,
    name    = f'beambeam_her'
)

# %% [markdown]
# ## Build Trackers

# %%
ler.build_tracker(
    _context                = context,
    use_prebuilt_kernels    = False
)
her.build_tracker(
    _context                = context,
    use_prebuilt_kernels    = False
)
# Out:
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.

# %% [markdown]
# ## Configure Radiation

# %%
ler.configure_radiation(
    model               = 'quantum',
    model_beamstrahlung = 'quantum'
)
her.configure_radiation(
    model               = 'quantum',
    model_beamstrahlung = 'quantum'
)

# %% [markdown]
# ## Build Multitracker

# %%
branch_electrons    = xt.PipelineBranch(her, electrons)
branch_positrons    = xt.PipelineBranch(ler, positrons)
multitracker        = xt.PipelineMultiTracker(branches=[branch_electrons, branch_positrons])

# %% [markdown]
# ## Create Tracking Records

# %%
record_electrons = {
    "turn": [],
    "alive": [],
    "luminosity": [],
    "photon_power": [],
    "x_av": [],
    "px_av": [],
    "y_av": [],
    "py_av": [],
    "z_av": [],
    "delta_av": [],
    "x_std": [],
    "px_std": [],
    "y_std": [],
    "py_std": [],
    "z_std": [],
    "delta_std": [],
    'emit_x':[],
    'emit_y':[],
    'emit_z':[],
    'u_bs':[]
}

record_positrons = {
    "turn": [],
    "alive": [],
    "luminosity": [],
    "photon_power": [],
    "x_av": [],
    "px_av": [],
    "y_av": [],
    "py_av": [],
    "z_av": [],
    "delta_av": [],
    "x_std": [],
    "px_std": [],
    "y_std": [],
    "py_std": [],
    "z_std": [],
    "delta_std": [],
    'emit_x':[],
    'emit_y':[],
    'emit_z':[],
    'u_bs':[]
}

# %% [markdown]
# ## Scaling Functions

# %%
def power_scale(energy, params):
    power = (
        energy *
        cst.e * # Convert to J
        1E-3 * # Convert to kJ
        params['n_bunches'] * # Bunches per train
        ( cst.c / params['circumference'] ) * # Crossings per second
        ( params['bunch_intensity'] / n_macroparticles )
    )
    return power

def lumi_scale(crossing_luminosity, params):
    luminosity = (
        crossing_luminosity * 
        1E-4 * #m^-2 -> cm^-2
        params['n_bunches'] * # Bunches per train
        ( cst.c / params['circumference'] ) * #times each bunch passes the IP in 1s
        1E-34
    )
    return luminosity

# %% [markdown]
# ## Initial Values

# %%
def number_alive(particles):
    return np.sum(particles.state[particles.state==1])

def averages(particles):
    x_av     = np.mean(particles.x[particles.state==1]    , axis=0)
    px_av    = np.mean(particles.px[particles.state==1]   , axis=0)
    y_av     = np.mean(particles.y[particles.state==1]    , axis=0)
    py_av    = np.mean(particles.py[particles.state==1]   , axis=0)
    z_av     = np.mean(particles.zeta[particles.state==1] , axis=0)
    delta_av = np.mean(particles.delta[particles.state==1], axis=0)
    return (x_av, px_av, y_av, py_av, z_av, delta_av)

def standard_deviations(particles):
    x_std     = np.std(particles.x[particles.state==1]    , axis=0)
    px_std    = np.std(particles.px[particles.state==1]   , axis=0)
    y_std     = np.std(particles.y[particles.state==1]    , axis=0)
    py_std    = np.std(particles.py[particles.state==1]   , axis=0)
    z_std     = np.std(particles.zeta[particles.state==1] , axis=0)
    delta_std = np.std(particles.delta[particles.state==1], axis=0)
    return (x_std, px_std, y_std, py_std, z_std, delta_std)

def emittances(particles):
    emit_x = np.sqrt(
        np.mean(( particles.x[particles.state==1] -  np.mean(particles.x[particles.state==1], axis=0))**2, axis=0) *\
        np.mean((particles.px[particles.state==1] - np.mean(particles.px[particles.state==1], axis=0))**2, axis=0) -\
        np.mean(( particles.x[particles.state==1] -  np.mean(particles.x[particles.state==1], axis=0)) *\
        (particles.px[particles.state==1] - np.mean(particles.px[particles.state==1], axis=0)), axis=0)**2
    )
    emit_y = np.sqrt(
        np.mean(( particles.y[particles.state==1] -  np.mean(particles.y[particles.state==1], axis=0))**2, axis=0) *\
        np.mean((particles.py[particles.state==1] - np.mean(particles.py[particles.state==1], axis=0))**2, axis=0) -\
        np.mean(( particles.y[particles.state==1] -  np.mean(particles.y[particles.state==1], axis=0)) *\
        (particles.py[particles.state==1] - np.mean(particles.py[particles.state==1], axis=0)), axis=0)**2
    )
    emit_z = np.sqrt(
        np.mean(( particles.zeta[particles.state==1] -  np.mean(particles.zeta[particles.state==1], axis=0))**2, axis=0) *\
        np.mean((particles.delta[particles.state==1] - np.mean(particles.delta[particles.state==1], axis=0))**2, axis=0) -\
        np.mean(( particles.zeta[particles.state==1] -  np.mean(particles.zeta[particles.state==1], axis=0)) *\
        (particles.delta[particles.state==1] - np.mean(particles.delta[particles.state==1], axis=0)), axis=0)**2
    )
    return (emit_x, emit_y, emit_z)

def append_to_records(record, turn, alive, average, stds, emit, luminosity, photon_power, bs_per_turn):
    record["turn"].append(turn)
    record["alive"].append(alive)
    record["x_av"].append(average[0])
    record["px_av"].append(average[1])
    record["y_av"].append(average[2])
    record["py_av"].append(average[3])
    record["z_av"].append(average[4])
    record["delta_av"].append(average[5])
    record["x_std"].append(stds[0])
    record["px_std"].append(stds[1])
    record["y_std"].append(stds[2])
    record["py_std"].append(stds[3])
    record["z_std"].append(stds[4])
    record["delta_std"].append(stds[5])
    record["emit_x"].append(emit[0])
    record["emit_y"].append(emit[1])
    record["emit_z"].append(emit[2])
    record["luminosity"].append(luminosity)
    record["photon_power"].append(photon_power)
    record["u_bs"].append(bs_per_turn)

# %%
append_to_records(
    record          = record_electrons,
    turn            = 0,
    alive           = number_alive(electrons),
    average         = averages(electrons),
    stds            = standard_deviations(electrons),
    emit            = emittances(electrons),
    luminosity      = 0,
    photon_power    = 0,
    bs_per_turn     = 0
)

append_to_records(
    record          = record_positrons,
    turn            = 0,
    alive           = number_alive(positrons),
    average         = averages(positrons),
    stds            = standard_deviations(positrons),
    emit            = emittances(positrons),
    luminosity      = 0,
    photon_power    = 0,
    bs_per_turn     = 0
)

# %% [markdown]
# ## Track

# %%
for turn in range(n_turns):
    print(f"Turn: {turn+1}")

    radiation_record_electrons = her.start_internal_logging_for_elements_of_type(
        xf.BeamBeamBiGaussian3D,
        capacity={
            "beamstrahlungtable": int(n_macroparticles),
            "bhabhatable": int(0),
            "lumitable": int(n_turns),
    })
    radiation_record_positrons = ler.start_internal_logging_for_elements_of_type(
        xf.BeamBeamBiGaussian3D,
        capacity={
            "beamstrahlungtable": int(n_macroparticles),
            "bhabhatable": int(0),
            "lumitable": int(n_turns),
    })
    # track for 1 period
    multitracker.track(num_turns=1, turn_by_turn_monitor=True)

    ler.stop_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D)
    her.stop_internal_logging_for_elements_of_type(xf.BeamBeamBiGaussian3D)

    append_to_records(
        record          = record_electrons,
        turn            = turn + 1,
        alive           = number_alive(electrons),
        average         = averages(electrons),
        stds            = standard_deviations(electrons),
        emit            = emittances(electrons),
        luminosity      = lumi_scale(radiation_record_electrons.lumitable.luminosity[turn], params=her_params),
        photon_power    = power_scale(np.sum(radiation_record_electrons.beamstrahlungtable.photon_energy), params=her_params),
        bs_per_turn     = np.sum(radiation_record_electrons.beamstrahlungtable.photon_energy) / (1E9 * n_macroparticles)
    )

    append_to_records(
        record          = record_positrons,
        turn            = turn + 1,
        alive           = number_alive(positrons),
        average         = averages(positrons),
        stds            = standard_deviations(positrons),
        emit            = emittances(positrons),
        luminosity      = lumi_scale(radiation_record_positrons.lumitable.luminosity[turn], params=ler_params),
        photon_power    = power_scale(np.sum(radiation_record_positrons.beamstrahlungtable.photon_energy), params=ler_params),
        bs_per_turn     = np.sum(radiation_record_positrons.beamstrahlungtable.photon_energy) / (1E9 * n_macroparticles)
    )

    # Delete tracker records before next period
    ler.tracker._init_io_buffer()
    her.tracker._init_io_buffer()
# Out:
# Turn: 1
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# 4693533c00d649d08fc820f85d6ec73b.c:8711:12: warning: variable 'gamma' set but not used [-Wunused-but-set-variable]
#     double gamma          = energy / m0;     // [1]
#            ^
# 4693533c00d649d08fc820f85d6ec73b.c:8979:9: warning: variable 'i' set but not used [-Wunused-but-set-variable]
#     int i=0;
#         ^
# 4693533c00d649d08fc820f85d6ec73b.c:9071:12: warning: unused variable 'e_loss_primary_tot' [-Wunused-variable]
#     double e_loss_primary_tot = 0.0;  // [GeV] total energy lost by the macroparticle
#            ^
# 4693533c00d649d08fc820f85d6ec73b.c:9068:62: warning: variable 'ps_e_prime' set but not used [-Wunused-but-set-variable]
#     double e_e_prime, px_e_prime, py_e_prime, pzeta_e_prime, ps_e_prime, pt_e_prime;  // [GeV, 1, 1, 1, 1, 1] scattered primary
#                                                              ^
# 4693533c00d649d08fc820f85d6ec73b.c:9324:21: warning: variable 'lumi_table_index' set but not used [-Wunused-but-set-variable]
#         RecordIndex lumi_table_index               = NULL;
#                     ^
# 5 warnings generated.
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# ld: warning: -pie being ignored. It is only used when linking a main executable
# Done compiling ContextCpu kernels.
# Turn: 2
# Turn: 3
# Turn: 4
# Turn: 5
# Turn: 6
# Turn: 7
# Turn: 8
# Turn: 9
# Turn: 10
# Turn: 11
# Turn: 12
# Turn: 13
# Turn: 14
# Turn: 15
# Turn: 16
# Turn: 17
# Turn: 18
# Turn: 19
# Turn: 20
# Turn: 21
# Turn: 22
# Turn: 23
# Turn: 24
# Turn: 25
# Turn: 26
# Turn: 27
# Turn: 28
# Turn: 29
# Turn: 30
# Turn: 31
# Turn: 32
# Turn: 33
# Turn: 34
# Turn: 35
# Turn: 36
# Turn: 37
# Turn: 38
# Turn: 39
# Turn: 40
# Turn: 41
# Turn: 42
# Turn: 43
# Turn: 44
# Turn: 45
# Turn: 46
# Turn: 47
# Turn: 48
# Turn: 49
# Turn: 50
# Turn: 51
# Turn: 52
# Turn: 53
# Turn: 54
# Turn: 55
# Turn: 56
# Turn: 57
# Turn: 58
# Turn: 59
# Turn: 60
# Turn: 61
# Turn: 62
# Turn: 63
# Turn: 64
# Turn: 65
# Turn: 66
# Turn: 67
# Turn: 68
# Turn: 69
# Turn: 70
# Turn: 71
# Turn: 72
# Turn: 73
# Turn: 74
# Turn: 75
# Turn: 76
# Turn: 77
# Turn: 78
# Turn: 79
# Turn: 80
# Turn: 81
# Turn: 82
# Turn: 83
# Turn: 84
# Turn: 85
# Turn: 86
# Turn: 87
# Turn: 88
# Turn: 89
# Turn: 90
# Turn: 91
# Turn: 92
# Turn: 93
# Turn: 94
# Turn: 95
# Turn: 96
# Turn: 97
# Turn: 98
# Turn: 99
# Turn: 100

# %% [markdown]
# ## Plotting

# %%
fig, axs = plt.subplots(1, 5, figsize=(16, 4), layout='constrained', sharex=True, sharey=False)

sigma_x_her     = np.sqrt(her_params['beta_x'] * her_params['physemit_x'])
sigma_px_her    = np.sqrt(her_params['physemit_x'] / her_params['beta_x'])
sigma_x_ler     = np.sqrt(ler_params['beta_x'] * ler_params['physemit_x'])
sigma_px_ler    = np.sqrt(ler_params['physemit_x'] / ler_params['beta_x'])

axs[0].plot(record_electrons["turn"], record_electrons["x_av"], label="electrons", c='b')
axs[0].plot(record_positrons["turn"], record_positrons["x_av"], label="positrons", c='r')
axs[0].axhline(y=0, xmin=0, xmax=n_turns+1)
axs[0].axhline(y = sigma_x_her, xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[0].axhline(y = -sigma_x_her, xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[0].axhline(y = sigma_x_ler, xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[0].axhline(y = -sigma_x_ler, xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[0].set_ylabel('x')

axs[1].plot(record_electrons["turn"], record_electrons["px_av"], label="electrons", c='b')
axs[1].plot(record_positrons["turn"], record_positrons["px_av"], label="positrons", c='r')
axs[1].axhline(y=0, xmin=0, xmax=n_turns+1)
axs[1].axhline(y = sigma_px_her, xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[1].axhline(y = -sigma_px_her, xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[1].axhline(y = sigma_px_ler, xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[1].axhline(y = -sigma_px_ler, xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[1].set_ylabel('px')

axs[2].plot(record_electrons["turn"], record_electrons["x_std"], label="electrons", c='b')
axs[2].plot(record_positrons["turn"], record_positrons["x_std"], label="positrons", c='r')
axs[2].axhline(y = sigma_x_her, xmin=0, xmax=n_turns+1, c='b')
axs[2].axhline(y = sigma_x_ler, xmin=0, xmax=n_turns+1, c='r')
axs[2].set_ylabel('Sigma x')

axs[3].plot(record_electrons["turn"], record_electrons["px_std"], label="electrons", c='b')
axs[3].plot(record_positrons["turn"], record_positrons["px_std"], label="positrons", c='r')
axs[3].axhline(y = sigma_px_her, xmin=0, xmax=n_turns+1, c='b')
axs[3].axhline(y = sigma_px_ler, xmin=0, xmax=n_turns+1, c='r')
axs[3].set_ylabel('Sigma px')

axs[4].plot(record_electrons["turn"], record_electrons["emit_x"], label="electrons", c='b')
axs[4].plot(record_positrons["turn"], record_positrons["emit_x"], label="positrons", c='r')
axs[4].axhline(y = her_params['physemit_x'], xmin=0, xmax=n_turns+1, c='b')
axs[4].axhline(y = ler_params['physemit_x'], xmin=0, xmax=n_turns+1, c='r')
axs[4].set_ylabel('Emittance x')

fig.legend(
    axs,
    labels=['Electrons', 'Positrons'],
    loc=(0.85,0.00),
    ncols=2
)

fig.supxlabel('Turns')
plt.show()
# Out:
# /var/folders/vw/g5f93yf13pv2lpspzd_rzsfh0000gn/T/ipykernel_73243/3601494800.py:44: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(

# %%
fig, axs = plt.subplots(1, 5, figsize=(16, 4), layout='constrained', sharex=True, sharey=False)

sigma_y_her     = np.sqrt(her_params['beta_y'] * her_params['physemit_y'])
sigma_py_her    = np.sqrt(her_params['physemit_y'] / her_params['beta_y'])
sigma_y_ler     = np.sqrt(ler_params['beta_y'] * ler_params['physemit_y'])
sigma_py_ler    = np.sqrt(ler_params['physemit_y'] / ler_params['beta_y'])

axs[0].plot(record_electrons["turn"], record_electrons["y_av"], label="electrons", c='b')
axs[0].plot(record_positrons["turn"], record_positrons["y_av"], label="positrons", c='r')
axs[0].axhline(y=0, xmin=0, xmax=n_turns+1)
axs[0].axhline(y = sigma_y_her, xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[0].axhline(y = -sigma_y_her, xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[0].axhline(y = sigma_y_ler, xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[0].axhline(y = -sigma_y_ler, xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[0].set_ylabel('y')

axs[1].plot(record_electrons["turn"], record_electrons["py_av"], label="electrons", c='b')
axs[1].plot(record_positrons["turn"], record_positrons["py_av"], label="positrons", c='r')
axs[1].axhline(y=0, xmin=0, xmax=n_turns+1)
axs[1].axhline(y = sigma_py_her, xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[1].axhline(y = -sigma_py_her, xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[1].axhline(y = sigma_py_ler, xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[1].axhline(y = -sigma_py_ler, xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[1].set_ylabel('py')

axs[2].plot(record_electrons["turn"], record_electrons["y_std"], label="electrons", c='b')
axs[2].plot(record_positrons["turn"], record_positrons["y_std"], label="positrons", c='r')
axs[2].axhline(y = np.sqrt(her_params['beta_y'] * her_params['physemit_y']), xmin=0, xmax=n_turns+1, c='b')
axs[2].axhline(y = np.sqrt(ler_params['beta_y'] * ler_params['physemit_y']), xmin=0, xmax=n_turns+1, c='r')
axs[2].set_ylabel('Sigma y')

axs[3].plot(record_electrons["turn"], record_electrons["py_std"], label="electrons", c='b')
axs[3].plot(record_positrons["turn"], record_positrons["py_std"], label="positrons", c='r')
axs[3].axhline(y = np.sqrt(her_params['physemit_y'] / her_params['beta_y']), xmin=0, xmax=n_turns+1, c='b')
axs[3].axhline(y = np.sqrt(ler_params['physemit_y'] / ler_params['beta_y']), xmin=0, xmax=n_turns+1, c='r')
axs[3].set_ylabel('Sigma py')

axs[4].plot(record_electrons["turn"], record_electrons["emit_y"], label="electrons", c='b')
axs[4].plot(record_positrons["turn"], record_positrons["emit_y"], label="positrons", c='r')
axs[4].axhline(y=her_params['physemit_y'], xmin=0, xmax=n_turns+1, c='b')
axs[4].axhline(y=ler_params['physemit_y'], xmin=0, xmax=n_turns+1, c='r')
axs[4].set_ylabel('Emittance y')

fig.legend(
    axs,
    labels=['Electrons', 'Positrons'],
    loc=(0.85,0.0),
    ncols=2
)

fig.supxlabel('Turns')
plt.show()
# Out:
# /var/folders/vw/g5f93yf13pv2lpspzd_rzsfh0000gn/T/ipykernel_73243/67895466.py:44: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(

# %%
fig, axs = plt.subplots(1, 5, figsize=(16, 4), layout='constrained', sharex=True, sharey=False)

axs[0].plot(record_electrons["turn"], record_electrons["z_av"], label="electrons", c='b')
axs[0].plot(record_positrons["turn"], record_positrons["z_av"], label="positrons", c='r')
axs[0].axhline(y=0, xmin=0, xmax=n_turns+1)
axs[0].axhline(y = her_params['sigma_z'], xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[0].axhline(y = -her_params['sigma_z'], xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[0].axhline(y = ler_params['sigma_z'], xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[0].axhline(y = -ler_params['sigma_z'], xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[0].set_ylabel('z')

axs[1].plot(record_electrons["turn"], record_electrons["delta_av"], label="electrons", c='b')
axs[1].plot(record_positrons["turn"], record_positrons["delta_av"], label="positrons", c='r')
axs[1].axhline(y=0, xmin=0, xmax=n_turns+1)
axs[1].axhline(y = her_params['sigma_z'], xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[1].axhline(y = -her_params['sigma_z'], xmin=0, xmax=n_turns+1, linestyle='--', c='b')
axs[1].axhline(y = ler_params['sigma_z'], xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[1].axhline(y = -ler_params['sigma_z'], xmin=0, xmax=n_turns+1, linestyle='--', c='r')
axs[1].set_ylabel('pz')

axs[2].plot(record_electrons["turn"], record_electrons["z_std"], label="electrons", c='b')
axs[2].plot(record_positrons["turn"], record_positrons["z_std"], label="positrons", c='r')
axs[2].axhline(y = her_params['sigma_z'], xmin=0, xmax=n_turns+1, c='b')
axs[2].axhline(y = ler_params['sigma_z'], xmin=0, xmax=n_turns+1, c='r')
axs[2].set_ylabel('Sigma z')

axs[3].plot(record_electrons["turn"], record_electrons["delta_std"], label="electrons", c='b')
axs[3].plot(record_positrons["turn"], record_positrons["delta_std"], label="positrons", c='r')
axs[3].set_ylabel('Sigma pz')

axs[4].plot(record_electrons["turn"], record_electrons["emit_z"], label="electrons", c='b')
axs[4].plot(record_positrons["turn"], record_positrons["emit_z"], label="positrons", c='r')
axs[4].set_ylabel('Emittance z')

fig.legend(
    axs,
    labels=['Electrons', 'Positrons'],
    loc=(0.85,0.0),
    ncols=2
)

fig.supxlabel('Turns')
plt.show()
# Out:
# /var/folders/vw/g5f93yf13pv2lpspzd_rzsfh0000gn/T/ipykernel_73243/3207864270.py:35: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 4), layout='constrained', sharex=True, sharey=False)
axs[0].plot(record_electrons["turn"], record_electrons["luminosity"], label="electrons", c='b')
axs[0].plot(record_positrons["turn"], record_positrons["luminosity"], label="positrons", c='r')
axs[0].set_ylabel('Luminosity [$10^34 cm^-2 s^-1$]')

axs[1].plot(record_electrons["turn"], record_electrons["photon_power"], label="electrons", c='b')
axs[1].plot(record_positrons["turn"], record_positrons["photon_power"], label="positrons", c='r')
axs[1].set_ylabel('Photon Power')

axs[2].plot(record_electrons["turn"], record_electrons["alive"], label="electrons", c='b')
axs[2].plot(record_positrons["turn"], record_positrons["alive"], label="positrons", c='r')
axs[2].set_ylabel('Alive')

fig.legend(
    axs,
    labels=['Electrons', 'Positrons'],
    loc=(0.85,0.0),
    ncols=2
)

fig.supxlabel('Turns')
plt.show()
# Out:
# /var/folders/vw/g5f93yf13pv2lpspzd_rzsfh0000gn/T/ipykernel_73243/1867391388.py:14: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(
